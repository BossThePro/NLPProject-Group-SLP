# %% [markdown]
# Test file for Pronoun swap

# %%
def read_iob2_file_wPOS(path):
    """
    Read provided Universal NER iob2 file
    
    :param path: path to read from
    :returns: list with sequences of words, NER labels and POS tags for each sentence
    """
    data = []
    current_words = []
    current_ner_tags = []
    current_pos_tag = []

    for line in open(path, encoding='utf-8'):
        line = line.strip()

        if line:
            if line[0] == '#':
                continue # skip comments
            tok = line.split(' ')
            #print(tok)
            current_words.append(tok[1])
            current_ner_tags.append(tok[2])
            current_pos_tag.append(tok[3])
        else:
            if current_words:  # skip empty lines
                data.append((current_words, current_ner_tags,current_pos_tag))
            current_words = []
            current_ner_tags = []
            current_pos_tag = []

    # check for last one
    if current_ner_tags != []:
        data.append((current_words, current_ner_tags,current_pos_tag))
    return data

female_dominated_dict = {
    "he" : "she",
    "his" : "hers",
    "him" : "her",
    "himself" : "herself",
    "they" : "she",
    "them" : "her",
    "theirs" : "his"
    }


male_dominated_dict = {
    "she" : "he",
    "hers" : "his",
    "her" : "him",
    "herself" : "himself",
    "they" : "he",
    "them" : "him",
    "theirs" : "his"
    }

gender_neutral_dict = {
    "he" : "they",
    "she" : "they",
    "him" : "them",
    "hers" : "them",
    "his" : "theirs",
    "her" : "theirs",
    "himself" : "themself",
    "herself" : "themself"
    }

def total_pronoun_swap(data, transform_dict):
    """Swaps the pronouns in a given conll file parsed using the read_iob2_file_wPOS function 
    Parameters
    ----------
    data : list 
        Pass the data returned from the parser function, should be a list ex. [([words],[NER tags],[POS tags]),.....]
    
    transform_dict : dict
        a dict which maps the pronouns that you would like to transfrom some helpful examples are provided above such as \
        gender_neutral_dict which trasfroms all pronouns into gender neutral terms
    Returns
    -------
    swapped_data : list 
        A list in the same format as the input, however with the pronous replaced based on the provided dict 
    Notes
    -----
    """
    
    change = 0
    for instance in data:
        for i in range(len(instance[2])):
            if (instance[2][i] == "PRP" or instance[2][i] == "PRP$"):
                  word_to_swap = instance[0][i]
                  swap_to = transform_dict.get(word_to_swap.casefold(),word_to_swap)
                  instance[0][i] = swap_to
                  change += 1

    print(f"Changed {change} tokens")
    return data

# %%
data_dev = read_iob2_file(r"..\data\test_conll.iob2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data_dev = read_iob2_file(r"..\data\test_conll.iob2")
#
# NameError: name 'read_iob2_file' is not defined

# %%
female_dominated_dict = {
    "he" : "she",
    "his" : "hers",
    "him" : "her",
    "himself" : "herself",
    "they" : "she",
    "them" : "her",
    "theirs" : "his"
    }


male_dominated_dict = {
    "she" : "he",
    "hers" : "his",
    "her" : "him",
    "herself" : "himself",
    "they" : "he",
    "them" : "him",
    "theirs" : "his"
    }

gender_neutral_dict = {
    "he" : "they",
    "she" : "they",
    "him" : "them",
    "hers" : "them",
    "his" : "theirs",
    "her" : "theirs",
    "himself" : "themself",
    "herself" : "themself"
    }

# %%
def total_pronoun_swap(data, transform_dict):

    change = 0
    for instance in data:
        for i in range(len(instance[2])):
            if (instance[2][i] == "PRP" or instance[2][i] == "PRP$"):
                  word_to_swap = instance[0][i]
                  swap_to = transform_dict.get(word_to_swap.casefold(),word_to_swap)
                  instance[0][i] = swap_to
                  change += 1

    print(f"Changed {change} tokens")
    return data

# %%
swapped_data = total_pronoun_swap(data_dev,gender_neutral_dict)
# Out:
# Changed 901 tokens

# %%
def category_pronoun_swap(data):

    change = 0
    for instance in data:
        for i in range(len(instance[2])):
            if (instance[2][i] == "PRP" or instance[2][i] == "PRP$"):
                  word_to_swap = instance[0][i]
                  swap_to = gender_neutral_dict.get(word_to_swap.casefold(),word_to_swap)
                  instance[0][i] = swap_to
                  change += 1

    print(f"Changed {change} tokens")
    return data

# %% [markdown]
# """Swap for Gendered Names"""

# %%
#read the file using same function as above
data_dev = read_iob2_file_wPOS(r"..\data\test_conll.iob2")

# %%
data_dev[2]
# Out:
# (['AL-AIN', ',', 'United', 'Arab', 'Emirates', '1996-12-06'],
#  ['B-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O'],
#  ['NNP', ',', 'NNP', 'NNP', 'NNPS', 'CD'])

# %%
count = 0
for i in data_dev:
    for j in i[1]:
        if j == "B-PER":
            count += 1

print(count)
# Out:
# 1617

# %% [markdown]
# Ideas to replace names with:
# 1) Female/Male names from the united states (easy to find)
# 2) Female/Male names from all over the world  (harder to find)
# 3) If we can find some frequency distribution as well (so how often those names occur in the real world),
#     we can assign based off of that, instead of randomly
#
# Since for this experiment we are just looking at how gender effects the biases in NER models, I think just using the gendered names from the US is ok
#
# Dealing with middle names so I-PER: Maybe a list of last names
#
# My opinion: Find the top 1000 female first names and top 1000 male first names in the US, and also find the top 1000 last names (not gender specific as last names usually arent), then all the B-PER are replaced with first names at random, and all thee I-PER are given a random last name (or we can just keep the I-PER as is)
#
# Plan:
# 1) Get top 1000 female names in the US
# 2) Get top 1000 male names in the US
# 3) Get top 1000 last names in the US
# 4) Code should replace all the names from one of the above 3 lists

# %%
import random

# %%
def create_name_dict(data,gender="female"):
    name_dict = {}

    lst_names_1 = ["Malik","Taha","matthew","Maat","matt","Ta","Ma","Lik"]
    lst_names_2 = ["M","Ta","mhew","Mt","att","a","Ma","Lk"]

    for instance in data:

        for i in range(len(instance[1])):

            if instance[1][i] == "B-PER":
                first_name = instance[0][i]
                replacement = random.choice(lst_names_1)

                if first_name not in name_dict.keys():
                    name_dict[first_name] = replacement
                    

            elif instance[1][i] == "I-PER": #another implementation could just be to keep the I-PER as they are (preferred)
                after_name = instance[0][i]
                replacement = random.choice(lst_names_2)

                if after_name not in name_dict.keys():
                    name_dict[after_name] = replacement
                    

    return name_dict

# %%
import pandas as pd

'''def create_gender_name_dict(data,path="../data/gender_names/top_female_names.csv"):
    """Create a dictionary where each first name in the original dataset (key) gets a random value from a csv file \
        with names from only one gender, defaulted to a file with all female names
    ----------
    data : list 
        Pass the data returned from the parser function, should be a list ex. [([words],[NER tags],[POS tags]),.....]\
        here POS tags are optional 
    
    path : str
        the path to a csv file which includes the replacement names, default is "../data/gender_names/top_female_names.csv" \
        to get all male names change "female" to "male" in the file path
    Returns
    -------
    name_dict : dict
        A dict which for each name in the original dataset gets a random new name from the provided csv file
    Notes
    -----
    Currently you can only have unique keys but not values, since our dataset has about 1600 B-PER, but the csv files only\
    have 1000 names so there will be distinct key that will have the same value

    The code does not create keys for I-PERs, since these are mostly middle names or last names, and traditioally those \
    aren't gender specific (or highly dominated by male names), so our focus becomes first names
    """

    name_dict = {}
    df = pd.read_csv(path)

    for instance in data:

        for i in range(len(instance[1])):

            if instance[1][i] == "B-PER":
                first_name = instance[0][i]

                replacement = random.choice(df["Female Names"]) #change this and then drop replacement

                if first_name not in name_dict.keys():
                    name_dict[first_name] = replacement
                    
    return name_dict'''
                
                
def gender_name_swap(data,name_dict):
    """Based on the name_dict provided changes all the instances of B-PER using in the data using the name_dict
    ----------
    data : list 
        Pass the data returned from the parser function, should be a list ex. [([words],[NER tags],[POS tags]),.....]\
        here POS tags are optional 
    
    name_dict : dict
        a dict returned from the create_gender_name_dict function, that has all the original names as keys and new \
        names as values
    Returns
    -------
    data : list 
        A list in the same format as the input, however with the names replaced based on the provided dict 
    Notes
    -----
    """
    
    swap_data = copy.deepcopy(data)

    for instance in swap_data:

        for i in range(len(instance[1])):
            if instance[1][i] == "B-PER":
                print(f"Changed {instance[0][i]} to {name_dict[instance[0][i]]}")
                instance[0][i] = name_dict[instance[0][i]]
    
    return swap_data

# %%
def create_gender_name_dict(data,path="../data/gender_names/top_female_names.csv"):
    """Create a dictionary where each first name in the original dataset (key) gets a random value from a csv file \
        with names from only one gender, defaulted to a file with all female names
    ----------
    data : list 
        Pass the data returned from the parser function, should be a list ex. [([words],[NER tags],[POS tags]),.....]\
        here POS tags are optional 
    
    path : str
        the path to a csv file which includes the replacement names, default is "../data/gender_names/top_female_names.csv" \
        to get all male names change "female" to "male" in the file path
    Returns
    -------
    name_dict : dict
        A dict which for each name in the original dataset gets a random new name from the provided csv file
    Notes
    -----
    Currently you can only have unique keys but not values, since our dataset has about 1600 B-PER, but the csv files only\
    have 1000 names so there will be distinct key that will have the same value

    The code does not create keys for I-PERs, since these are mostly middle names or last names, and traditioally those \
    aren't gender specific (or highly dominated by male names), so our focus becomes first names
    """

    name_dict = {}
    df = pd.read_csv(path)
    name_index = 0

    if path == "../data/gender_names/top_female_names.csv":
        replacement_pool = df["Female Names"].tolist()
    else:
        replacement_pool = df["Male Names"].tolist()

    random.shuffle(replacement_pool)

    for instance in data:

        for i in range(len(instance[1])):

            if instance[1][i] == "B-PER":
                first_name = instance[0][i]

                if first_name not in name_dict.keys():
                    name_dict[first_name] = replacement_pool[name_index]
                    name_index += 1
                    
    return name_dict

# %%
#This cell is mainly to get the top 1000 names list doesnt need to be run again

import requests
from bs4 import BeautifulSoup
import re 
import pandas as pd

def scrape_names(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    names_list_element = soup.find('ol')

    top_1000_names = [li.text.strip() for li in names_list_element.find_all('li')]

    top_1000_names = re.findall(r'[A-Z][a-z]+',top_1000_names[0])

    return top_1000_names

top_1000_female_names = scrape_names("https://www.whattoexpect.com/baby-names/list/top-baby-names-for-girls/")
top_1000_male_names = scrape_names("https://www.whattoexpect.com/baby-names/list/top-baby-names-for-boys/")

df_female = pd.DataFrame(top_1000_female_names,columns=["Female Names"])
df_male = pd.DataFrame(top_1000_male_names,columns=["Male Names"])

df_female.to_csv("../data/gender_names/top_female_names.csv",index=False)
df_male.to_csv("../data/gender_names/top_male_names.csv",index=False)

# %%
import pandas as pd
import random
import copy

# %%
#TESTING THE CODE with female names
data_dev = read_iob2_file_wPOS(r"..\data\test_conll.iob2")
male_dict = create_gender_name_dict(data_dev,"../data/gender_names/top_male_names.csv") #leaving path to default

# %%
swapped_data = gender_name_swap(data_dev,male_dict)
# Out:
# Changed CHINA to Charlie
# Changed Nadim to Mark
# Changed Igor to King
# Changed Oleg to Rene
# Changed Takuya to Vincent
# Changed Hiroshige to Uriah
# Changed Salem to Walker
# Changed Hassan to Cyrus
# Changed Bitar to Mateo
# Changed Nader to Kai
# Changed Bitar to Mateo
# Changed Shu to Armani
# Changed CUTTITTA to Aurelio
# Changed Marcello to Makai
# Changed Cuttitta to Raphael
# Changed George to Jose
# Changed Stefano to Ryatt
# Changed Coste to Boone
# Changed Corrado to Caleb
# Changed Cuttitta to Raphael
# Changed Coste to Boone
# Changed Coste to Boone
# Changed Javier to Kenai
# Changed Paolo to Nasir
# Changed Marcello to Makai
# Changed Ivan to Onyx
# Changed Leandro to Aidan
# Changed Diego to Ares
# Changed Francesco to Kyle
# Changed Alessandro to Martin
# Changed Orazio to Cairo
# Changed Andrea to Boston
# Changed Massimo to Santos
# Changed Carlo to Issac
# Changed Walter to Dennis
# Changed Franco to Jaziel
# Changed Carlo to Issac
# Changed Massimo to Santos
# Changed Giambatista to Kyson
# Changed Gianluca to Ivan
# Changed Nicola to Felipe
# Changed Alessandro to Martin
# Changed Andrea to Boston
# Changed Takuya to Vincent
# Changed Salem to Walker
# Changed Hassan to Cyrus
# Changed Bitar to Mateo
# Changed Nader to Kai
# Changed Ammar to Teddy
# Changed Kenichi to Jamir
# Changed Bitar to Mateo
# Changed Kazuyoshi to Ronan
# Changed Takagi to Bridger
# Changed Bitar to Mateo
# Changed Miura to William
# Changed Bitar to Mateo
# Changed Naoki to Aaron
# Changed Kenichi to Jamir
# Changed Hiroshige to Uriah
# Changed Naoki to Aaron
# Changed Masami to Francis
# Changed Norio to Marvin
# Changed Motohiro to Reuben
# Changed Masakiyo to Emery
# Changed Yasuto to Riley
# Changed Takuya to Vincent
# Changed Hiroshi to Gian
# Changed Kazuyoshi to Ronan
# Changed Hiroaki to Mohamed
# Changed Masayuki to Gunnar
# Changed Salem to Walker
# Changed Bachar to Kash
# Changed Hassan to Cyrus
# Changed Tarek to Frederick
# Changed Ammar to Teddy
# Changed Louay to Oliver
# Changed Nihad to Conrad
# Changed Mohammed to Briar
# Changed Ali to Yousef
# Changed Abdul to Gage
# Changed Ammar to Teddy
# Changed Khaled to Adrian
# Changed Nader to Kai
# Changed Jesper to Noel
# Changed Andrei to Yisroel
# Changed Ryan to Lance
# Changed Jean-Luc to Jordan
# Changed Korneilus to Hayes
# Changed Jeremie to Cash
# Changed Jim to Kaden
# Changed Dominick to Steven
# Changed Johann to Cayden
# Changed Troy to Derek
# Changed Tatjana to Simon
# Changed Candice to Phillip
# Changed Minna to Koda
# Changed Tae to Dante
# Changed Ann to Donald
# Changed Donna to Brooks
# Changed Liz to Zen
# Changed Elena to Guillermo
# Changed Ljudmila to Alexander
# Changed Katleen to Ari
# Changed Hassan to Cyrus
# Changed Takuya to Vincent
# Changed Nader to Kai
# Changed Shkvyrin to Russell
# Changed Shatskikh to Rafael
# Changed Saeed to Elian
# Changed Zahoor to Quincy
# Changed Cairns to Yehuda
# Changed Ijaz to Tristan
# Changed Spearman to Leonardo
# Changed Vaughan to Jahmir
# Changed Inzamamul to Valentin
# Changed Germon to Nelson
# Changed Astle to Van
# Changed Wasim to Azai
# Changed Harris to Saint
# Changed Shahid to Cole
# Changed Harris to Saint
# Changed Moin to Tobias
# Changed Astle to Van
# Changed Harris to Saint
# Changed Waqar to Spencer
# Changed Germon to Nelson
# Changed Harris to Saint
# Changed Saqlain to Thaddeus
# Changed Harris to Saint
# Changed Mushtaq to Declan
# Changed Salim to Mitchell
# Changed Doull to Emiliano
# Changed Kennedy to Edgar
# Changed Cairns to Yehuda
# Changed Vaughan to Jahmir
# Changed Harris to Saint
# Changed Astle to Van
# Changed B. to Rodrigo
# Changed Moin to Tobias
# Changed Waqar to Spencer
# Changed C. to Angelo
# Changed Moin to Tobias
# Changed Wasim to Azai
# Changed A. to Corey
# Changed Ijaz to Tristan
# Changed Saqlain to Thaddeus
# Changed S. to Marshall
# Changed Afridi to Jase
# Changed C. to Angelo
# Changed Saqlain to Thaddeus
# Changed N. to Kaizen
# Changed Ijaz to Tristan
# Changed Salim to Mitchell
# Changed C. to Angelo
# Changed Wasim to Azai
# Changed L. to Josue
# Changed Afridi to Jase
# Changed J. to Riggs
# Changed Moin to Tobias
# Changed Wasim to Azai
# Changed S. to Marshall
# Changed M. to Emerson
# Changed Waqar to Spencer
# Changed R. to Baker
# Changed Wasim to Azai
# Changed Waqar to Spencer
# Changed Saqlain to Thaddeus
# Changed Mushtaq to Declan
# Changed Shahid to Cole
# Changed Salim to Mitchell
# Changed Ijaz to Tristan
# Changed BLINKER to Kairo
# Changed Reggie to Tommy
# Changed Blinker to Grey
# Changed Blinker to Grey
# Changed BOWYER to Darian
# Changed Lee to Adam
# Changed Bowyer to Greyson
# Changed Bowyer to Greyson
# Changed Bowyer to Greyson
# Changed LITTLE to Colsen
# Changed CAMPESE to Asaiah
# Changed Robert to Westley
# Changed Jason to Ozias
# Changed Little to Abraham
# Changed Daniel to Jace
# Changed Owen to Pierce
# Changed Daniel to Jace
# Changed David to Aryan
# Changed Campese to Franklin
# Changed Rob to Kason
# Changed Campo to Calvin
# Changed Andrew to Tomas
# Changed Tim to Noe
# Changed Tony to Paul
# Changed Ian to Alberto
# Changed Norm to Tate
# Changed Tim to Noe
# Changed Nigel to Caiden
# Changed Allan to Lachlan
# Changed Gregor to Alistair
# Changed Tony to Paul
# Changed Rob to Kason
# Changed Rob to Kason
# Changed Scott to Gianni
# Changed Neil to Chandler
# Changed Dale to Jameson
# Changed Ian to Alberto
# Changed Craig to Edison
# Changed Darren to Jairo
# Changed Norm to Tate
# Changed Nick to Eddie
# Changed Matthew to Felix
# Changed Joe to Alex
# Changed Daniel to Jace
# Changed Tim to Noe
# Changed David to Aryan
# Changed Pat to Jiraiya
# Changed Sam to Coleson
# Changed Michael to Colton
# Changed David to Aryan
# Changed Owen to Pierce
# Changed David to Aryan
# Changed Tim to Noe
# Changed Andrew to Tomas
# Changed Marco to Rome
# Changed Dan to Leandro
# Changed Des to Mathew
# Changed Mark to Ledger
# Changed Steve to Luka
# Changed Nick to Eddie
# Changed Justin to Romeo
# Changed Andrew to Tomas
# Changed Mark to Ledger
# Changed Mark to Ledger
# Changed Hennie to Hector
# Changed Andrew to Tomas
# Changed Schalk to Rey
# Changed Desvonde to Daniel
# Changed Botes to Noah
# Changed Greg to Julius
# Changed Clinton to Jakari
# Changed Brett to Moses
# Changed Hugh to Silas
# Changed Adilson to Ira
# Changed Sammy to Soren
# Changed Trevor to Alden
# Changed Don to Levi
# Changed Dion to Nathanael
# Changed Steve to Luka
# Changed Ian to Alberto
# Changed Anghel to Jaxton
# Changed Valentin to Clayton
# Changed Viorel to Caden
# Changed Liviu to Creed
# Changed Iordanescu to Alijah
# Changed Adrian to Bodie
# Changed Bogdan to Preston
# Changed Florin to Camden
# Changed Dan to Leandro
# Changed Daniel to Jace
# Changed Anton to Rowen
# Changed Cornel to Madden
# Changed Liviu to Creed
# Changed Tibor to Keegan
# Changed Iulian to Salem
# Changed Gheorghe to Wyatt
# Changed Gheorghe to Wyatt
# Changed Constantin to Conner
# Changed Valentin to Clayton
# Changed Basarab to August
# Changed Dorinel to Kyrie
# Changed Ovidiu to Cohen
# Changed Ioan to Camilo
# Changed Gheorghe to Wyatt
# Changed Ionel to Jacob
# Changed Viorel to Caden
# Changed LARA to Avery
# Changed Robert to Westley
# Changed Brian to Maximo
# Changed Lara to Ulises
# Changed Greg to Julius
# Changed Blewett to Carlo
# Changed Stuart to Bodhi
# Changed Lara to Ulises
# Changed Shane to Izael
# Changed Clive to Trey
# Changed Lara to Ulises
# Changed Lara to Ulises
# Changed Geoff to Axton
# Changed Ian to Alberto
# Changed Shivnarine to Marcellus
# Changed Chanderpaul to Ronald
# Changed S. to Marshall
# Changed Healy to Moshe
# Changed Gillespie to Uriel
# Changed R. to Baker
# Changed M. to Emerson
# Changed Gillespie to Uriel
# Changed B. to Rodrigo
# Changed Warne to Gerardo
# Changed Moody to Cason
# Changed S. to Marshall
# Changed Healy to Moshe
# Changed Blewett to Carlo
# Changed C. to Angelo
# Changed J. to Riggs
# Changed Moody to Cason
# Changed J. to Riggs
# Changed Blewett to Carlo
# Changed Warne to Gerardo
# Changed N. to Kaizen
# Changed M. to Emerson
# Changed K. to Caspian
# Changed Warne to Gerardo
# Changed C. to Angelo
# Changed C. to Angelo
# Changed Reiffel to Robert
# Changed Gillespie to Uriel
# Changed Moody to Cason
# Changed Blewett to Carlo
# Changed Warne to Gerardo
# Changed M. to Emerson
# Changed M. to Emerson
# Changed McLean to Rex
# Changed M. to Emerson
# Changed Murray to Andre
# Changed Benjamin to Remi
# Changed R. to Baker
# Changed McLean to Rex
# Changed G. to Harlan
# Changed M. to Emerson
# Changed Murray to Andre
# Changed Hooper to Forest
# Changed S. to Marshall
# Changed Hooper to Forest
# Changed T. to Memphis
# Changed I. to Kobe
# Changed P. to Cassian
# Changed S. to Marshall
# Changed J. to Riggs
# Changed Ambrose to Easton
# Changed Walsh to Dario
# Changed Benjamin to Remi
# Changed Hooper to Forest
# Changed McLean to Rex
# Changed Shivnarine to Marcellus
# Changed Greg to Julius
# Changed David to Aryan
# Changed Shaun to Jericho
# Changed Michael to Colton
# Changed LARA to Avery
# Changed Brian to Maximo
# Changed Lara to Ulises
# Changed Ian to Alberto
# Changed Tom to Ace
# Changed Shane to Izael
# Changed Courtney to Jay
# Changed Lara to Ulises
# Changed Clive to Trey
# Changed Lara to Ulises
# Changed Geoff to Axton
# Changed Lloyd to Eiden
# Changed Lara to Ulises
# Changed Healy to Moshe
# Changed Lara to Ulises
# Changed Lara to Ulises
# Changed Courtney to Jay
# Changed Mark to Ledger
# Changed Mark to Ledger
# Changed Ricky to Aldo
# Changed Greg to Julius
# Changed Michael to Colton
# Changed Stuart to Bodhi
# Changed Tom to Ace
# Changed Ian to Alberto
# Changed Paul to Arden
# Changed Shane to Izael
# Changed Jason to Ozias
# Changed Glenn to Eduardo
# Changed Sherwin to Truett
# Changed Robert to Westley
# Changed Brian to Maximo
# Changed Shivnarine to Marcellus
# Changed Carl to Myles
# Changed Jimmy to Waylon
# Changed Junior to Mac
# Changed Nixon to Nolan
# Changed Kenneth to Arjun
# Changed Curtly to Casen
# Changed Courtney to Jay
# Changed Roland to Bode
# Changed Chen to Loyal
# Changed Martin to Christopher
# Changed Dong to Karter
# Changed Thomas to Collin
# Changed Indra to Eli
# Changed Ong to Abdiel
# Changed Sun to Alfred
# Changed Rashid to Isael
# Changed Hermawan to Reid
# Changed Soren to Javier
# Changed Allan to Lachlan
# Changed Poul-Erik to Franco
# Changed Budi to Lukas
# Changed Hu to Campbell
# Changed Fung to Dax
# Changed Indra to Eli
# Changed Wijaya to Adriel
# Changed Sun to Alfred
# Changed Allan to Lachlan
# Changed Gong to Archie
# Changed Mia to Santino
# Changed Ye to Henry
# Changed Meiluawati to Ismael
# Changed Camilla to Diego
# Changed Wang to Jayden
# Changed Susi to Langston
# Changed Han to Nico
# Changed Susi to Langston
# Changed Camilla to Diego
# Changed Ye to Henry
# Changed Gong to Archie
# Changed Aly to Nash
# Changed Mohamed to Malachi
# Changed Marshall to Tucker
# Changed Jason to Ozias
# Changed Paul to Arden
# Changed Jim to Kaden
# Changed Tony to Paul
# Changed Ray to Troy
# Changed Quentin to Jagger
# Changed Faulk to Zander
# Changed Justin to Romeo
# Changed Harbaugh to Darwin
# Changed Justin to Romeo
# Changed Kerwin to Ryder
# Changed Marvin to Titus
# Changed Troy to Derek
# Changed Faulk to Zander
# Changed Ty to Kayson
# Changed Ricky to Aldo
# Changed PACE to Samson
# Changed Orlando to Hendrix
# Changed Pace to Khalil
# Changed Pace to Khalil
# Changed Pace to Khalil
# Changed Cornell to Enzo
# Changed Juan to Atreus
# Changed Jared to Khai
# Changed Vince to Rayan
# Changed Japhet to Arturo
# Changed Claude to Khaza
# Changed Jocelyn to Kenzo
# Changed Gourvennec to Joel
# Changed Christophe to Christian
# Changed Bruno to Milo
# Changed Paul to Arden
# Changed Phil to Antonio
# Changed Konterman to Taylor
# Changed Van to Agustin
# Changed Stickroth to Walter
# Changed Wosz to Dominick
# Changed Kirsten to Cristian
# Changed Ramelow to Damari
# Changed Bode to Fernando
# Changed Bormirow to Raul
# Changed Reich to Emilio
# Changed Carl to Myles
# Changed Mulder to Enoch
# Changed Goran to Azaiah
# Changed Mark to Ledger
# Changed Yevgeny to Winston
# Changed Jim to Kaden
# Changed WEAH to Gavin
# Changed COSTA to Chozen
# Changed Joao to Zev
# Changed Jorge to Ander
# Changed Georg to Halo
# Changed Costa to Kylan
# Changed Vitor to Otto
# Changed Rui to Shiloh
# Changed Paulinho to Bo
# Changed Sergio to Yeshua
# Changed Joao to Zev
# Changed Oceano to Harry
# Changed Fernando to Ayan
# Changed Helder to Augustine
# Changed Dimas to Xavier
# Changed Carlos to Wes
# Changed Rui to Shiloh
# Changed Jose to Francisco
# Changed Luis to Wesley
# Changed Paulo to Darren
# Changed Jose to Francisco
# Changed Antonio to Elio
# Changed Joao to Zev
# Changed Paulo to Darren
# Changed Rui to Shiloh
# Changed Jorge to Ander
# Changed William to Chase
# Changed Davor to Wilson
# Changed Ronaldo to Arlo
# Changed Pedrag to Israel
# Changed Luis to Wesley
# Changed Raul to Jax
# Changed Juan to Atreus
# Changed Fernando to Ayan
# Changed Giovanni to Rory
# Changed Victor to Callan
# Changed Guillermo to Emir
# Changed Amor to Zane
# Changed Jose to Francisco
# Changed Roger to Harvey
# Changed Manolo to Edwin
# Changed Gheorghe to Wyatt
# Changed Popescu to Gustavo
# Changed Roberto to Frank
# Changed JosepGuardiola to Kiaan
# Changed Fernando to Ayan
# Changed Ivan to Onyx
# Changed laPena to Hamza
# Changed Luis to Wesley
# Changed Luis to Wesley
# Changed Enrique to Murphy
# Changed Fernando to Ayan
# Changed AbelardoFernandez to Joe
# Changed Carlos to Wes
# Changed Sergi to Brock
# Changed Rafael to Cain
# Changed Albert to Judson
# Changed Ferrer to Omar
# Changed Chendo to Sawyer
# Changed Miguel to Alfonso
# Changed Laurent to Atticus
# Changed ARMANDO to Miguel
# Changed Javier to Kenai
# Changed Armando to Heath
# Changed Armando to Heath
# Changed Jose to Francisco
# Changed HAVELANGE to Ambrose
# Changed WEAH to Gavin
# Changed Joao to Zev
# Changed George to Jose
# Changed Jorge to Ander
# Changed Weah to Forrest
# Changed Costa to Kylan
# Changed Havelange to Alfredo
# Changed Costa to Kylan
# Changed Weah to Forrest
# Changed Weah to Forrest
# Changed Costa to Kylan
# Changed Costa to Kylan
# Changed Costa to Kylan
# Changed Weah to Forrest
# Changed Weah to Forrest
# Changed Kennet to Conor
# Changed Igor to King
# Changed Ramon to Cooper
# Changed Dietmar to Tatum
# Changed Daniele to Wilder
# Changed Lorenzo to Roy
# Changed Emiliano to Jaiden
# Changed Milan to Beau
# Changed Fausto to Rhodes
# Changed Pierluigi to Alvin
# Changed Pavel to Jaime
# Changed Paolo to Nasir
# Changed Abel to Benjamin
# Changed Marco to Rome
# Changed Francesco to Kyle
# Changed George to Jose
# Changed Roberto to Frank
# Changed Dejan to Jake
# Changed Oliver to Yitzchok
# Changed Roberto to Frank
# Changed Eugenio to Krew
# Changed Mario to Ronnie
# Changed Daniel to Jace
# Changed Fabio to Ashton
# Changed Nestor to Santiago
# Changed Filippo to Jones
# Changed Dimas to Xavier
# Changed Alessandro to Martin
# Changed Alen to Alexis
# Changed Roberto to Frank
# Changed Pierre to Aiden
# Changed Marcelo to River
# Changed Joceyln to Azariah
# Changed Ivan to Onyx
# Changed Eric to Jack
# Changed Ron to Remy
# Changed Jacques to Jalen
# Changed Harper to Joey
# Changed Chadler to Jerry
# Changed Juan to Atreus
# Changed Dejan to Jake
# Changed Zoran to Vihaan
# Changed EYLES to Jrue
# Changed Rodney to Anakin
# Changed Mark to Ledger
# Changed Eyles to Jeremiah
# Changed Peter to Zakai
# Changed Simon to Callahan
# Changed Nicol to Enrique
# Changed Nicol to Enrique
# Changed Peter to Zakai
# Changed Simon to Callahan
# Changed Rodney to Anakin
# Changed Mark to Ledger
# Changed Nicol to Enrique
# Changed Eyles to Jeremiah
# Changed DURBAN to Jedidiah
# Changed Nelson to Ayden
# Changed Bala to Michael
# Changed Mangosuthu to Graham
# Changed HAVEL to Saul
# Changed ALBRIGHT to Maverick
# Changed Klara to Jamison
# Changed Vaclav to Jayson
# Changed Madeleine to Kolter
# Changed Havel to Jeremias
# Changed Madeleine to Kolter
# Changed Havel to Jeremias
# Changed Havel to Jeremias
# Changed Albright to Travis
# Changed Havel to Jeremias
# Changed Albright to Travis
# Changed Marie to Bradley
# Changed Albright to Travis
# Changed Albright to Travis
# Changed Josef to Musa
# Changed Albright to Travis
# Changed Karel to Jackson
# Changed Albright to Travis
# Changed Emil to Ford
# Changed Constantinescu to Chris
# Changed Marko to Elisha
# Changed Josef to Musa
# Changed Zieleniec to Lorenzo
# Changed Vaclav to Jayson
# Changed Klaus to Gideon
# Changed Margaret to Sam
# Changed Zieleniec to Lorenzo
# Changed Klaus to Gideon
# Changed Klaus to Gideon
# Changed Klaus to Gideon
# Changed Marcin to Yosef
# Changed Dariusz to Salvatore
# Changed Rosati to Ramon
# Changed Alfonse to Hank
# Changed Rosati to Ramon
# Changed Rosati to Ramon
# Changed Rosati to Ramon
# Changed Rosati to Ramon
# Changed Steven to Colin
# Changed Jean to Hassan
# Changed Van to Agustin
# Changed Boxmeer to Tanner
# Changed Van to Agustin
# Changed Van to Agustin
# Changed Boxmeer to Tanner
# Changed Van to Agustin
# Changed Boxmeer to Tanner
# Changed Van to Agustin
# Changed HAVEL to Saul
# Changed Vaclav to Jayson
# Changed Havel to Jeremias
# Changed Ladlislav to Maddox
# Changed Havel to Jeremias
# Changed Havel to Jeremias
# Changed Havel to Jeremias
# Changed Edna to Thomas
# Changed Ian to Alberto
# Changed Lang to Joziah
# Changed Lang to Joziah
# Changed Major to Damian
# Changed John to Aarav
# Changed John to Aarav
# Changed Gorst to Alejandro
# Changed Major to Damian
# Changed Gorst to Alejandro
# Changed Gorst to Alejandro
# Changed Major to Damian
# Changed Gorst to Alejandro
# Changed Gorst to Alejandro
# Changed Sherwin to Truett
# Changed Shivnarine to Marcellus
# Changed Gilbert to Zymir
# Changed Joan to Kenneth
# Changed Brendan to Ricardo
# Changed Marc to Zachariah
# Changed A. to Corey
# Changed Cooke to Amos
# Changed Piniel to Iker
# Changed Robert to Westley
# Changed Jonathan to Tyson
# Changed Maurice to Atlas
# Changed Baril to Sutton
# Changed Laurent to Atticus
# Changed Doug to Stetson
# Changed Young to Raymond
# Changed Baril to Sutton
# Changed Baril to Sutton
# Changed Abdou to Lee
# Changed Moustapha to Roger
# Changed Diouf to Justin
# Changed Boutros to Archer
# Changed Diouf to Justin
# Changed Moustapha to Roger
# Changed Raphael to Keith
# Changed Jacques to Jalen
# Changed David to Aryan
# Changed Christophe to Christian
# Changed Ange-Felix to Asher
# Changed Grelombe to Harrison
# Changed Patasse to Rhys
# Changed Dofora to Shawn
# Changed Patasse to Rhys
# Changed Chirac to Ali
# Changed Blaise to Jamie
# Changed Patasse to Rhys
# Changed Patasse to Rhys
# Changed Patasse to Rhys
# Changed Patasse to Rhys
# Changed Baruch to Cruz
# Changed Meyers to Huxley
# Changed Meyers to Huxley
# Changed Sali to Makari
# Changed Buza to Trenton
# Changed Berisha to Marcelo
# Changed Oscar to Xander
# Changed Buza to Trenton
# Changed Qazim to Lucas
# Changed Buza to Trenton
# Changed Gjonaj to Kolson
# Changed Aleksander to Brandon
# Changed John to Aarav
# Changed Kwasniewski to Carter
# Changed Oscar to Xander
# Changed Dariusz to Salvatore
# Changed Rosati to Ramon
# Changed Kwasniewski to Carter
# Changed Lynnley to Gatlin
# Changed Alexander to Azrael
# Changed Konstantin to Zahir
# Changed Livshits to Kabir
# Changed Livshits to Kabir
# Changed Christopher to Orion
# Changed Chernyshev to Royal
# Changed Livshits to Kabir
# Changed Chernyshev to Royal
# Changed Albright to Travis
# Changed Madeleine to Kolter
# Changed Bill to Emory
# Changed Igor to King
# Changed Albright to Travis
# Changed Clinton to Jakari
# Changed Boris to Chosen
# Changed Clinton to Jakari
# Changed Yeltsin to Paxton
# Changed Ivanov to Cesar
# Changed Albright to Travis
# Changed Yeltsin to Paxton
# Changed Boris to Chosen
# Changed Yegor to Lionel
# Changed Yeltsin to Paxton
# Changed Yeltsin to Paxton
# Changed Mikhail to Waylen
# Changed Yeltsin to Paxton
# Changed Renat to Fletcher
# Changed Yeltsin to Paxton
# Changed Frantisek to Massimo
# Changed Gaulieder to Roland
# Changed Vladimir to Alonso
# Changed Gaulieder to Roland
# Changed Sandor to Lucien
# Changed Sandor to Lucien
# Changed Greenspan to Andrew
# Changed Greenspan to Andrew
# Changed Alan to Grant
# Changed Greenspan to Andrew
# Changed Carlos to Wes
# Changed Ponce to Landen
# Changed Simona to Omari
# Changed Farid to Luca
# Changed Hakme to Vicente
# Changed Ivo to Allen
# Changed Hakme to Vicente
# Changed Oswaldo to Rowdy
# Changed Claudia to Finn
# Changed Saldanha to Idris
# Changed Chris to Knox
# Changed SANTIAGO to Evander
# Changed Eduardo to Blaze
# Changed Aninat to Shmuel
# Changed Aninat to Shmuel
# Changed Aninat to Shmuel
# Changed Roger to Harvey
# Changed Belo to Jared
# Changed Carlos to Wes
# Changed Belo to Jared
# Changed Jose to Francisco
# Changed Ramos to Mason
# Changed Ali to Yousef
# Changed Ramos to Mason
# Changed Alatas to Sincere
# Changed Ramos to Mason
# Changed Belo to Jared
# Changed Ramos to Mason
# Changed Alatas to Sincere
# Changed Belo to Jared
# Changed Belo to Jared
# Changed Alatas to Sincere
# Changed Alatas to Sincere
# Changed Belo to Jared
# Changed Helmut to Hugo
# Changed Kohl to Zamir
# Changed Belo to Jared
# Changed Vithoon to Braylon
# Changed Aung to Zion
# Changed Suu to Dutton
# Changed Suu to Dutton
# Changed Aung to Zion
# Changed Suu to Dutton
# Changed Bill to Emory
# Changed Michel to Rylan
# Changed Jordan to Quinn
# Changed Jordan to Quinn
# Changed Jordan to Quinn
# Changed Bill to Emory
# Changed Richard to Jayceon
# Changed K.J. to Mack
# Changed Matthew to Felix
# Changed Matthew to Felix
# Changed Matthew to Felix
# Changed George to Jose
# Changed Yasuo to Royce
# Changed Eisuke to Rudy
# Changed Sakakibara to Zeke
# Changed Robert to Westley
# Changed Rubin to Magnus
# Changed Hank to Ian
# Changed Rubin to Magnus
# Changed Sakakibara to Zeke
# Changed Sakakibara to Zeke
# Changed Note to Ahmed
# Changed Takao to Marcel
# Changed Sakakibara to Zeke
# Changed Sakakibara to Zeke
# Changed Sakakibara to Zeke
# Changed Mr to Roberto
# Changed Sakakibara to Zeke
# Changed Matsushita to Jude
# Changed Matsushita to Jude
# Changed Yasuhito to Kannon
# Changed Taisuke to Koen
# Changed Antoine to Kaiden
# Changed Lahd to Leif
# Changed Lahd to Leif
# Changed Lahd to Leif
# Changed Lahd to Leif
# Changed Lahd to Leif
# Changed Lahd to Leif
# Changed Shimon to Mohammed
# Changed Lahd to Leif
# Changed Peres to Tyler
# Changed Benjamin to Remi
# Changed Etian to Jasiah
# Changed Saqr to Ezra
# Changed Lahd to Leif
# Changed John to Aarav
# Changed Glenn to Eduardo
# Changed Mills to Jason
# Changed Lester to Kane
# Changed Mills to Jason
# Changed Eugene to Shepherd
# Changed God to Major
# Changed Allah to Mohammad
# Changed Mohammed to Briar
# Changed God to Major
# Changed Mills to Jason
# Changed Mills to Jason
# Changed Yuhanna to Koa
# Changed Mills to Jason
# Changed Mills to Jason
# Changed Morris to Leonidas
# Changed Mills to Jason
# Changed Mills to Jason
# Changed Michael to Colton
# Changed Lester to Kane
# Changed Lester to Kane
# Changed Mills to Jason
# Changed Lawhon to Emmanuel
# Changed Frederick to Colten
# Changed Darrel to Nikolas
# Changed Dennis to Pedro
# Changed Voeks to Abdullah
# Changed Voeks to Abdullah
# Changed Voeks to Abdullah
# Changed H to Leo
# Changed McGregor to Fisher
# Changed Clinton to Jakari
# Changed Clinton to Jakari
# Changed Mike to Karim
# Changed Clinton to Jakari
# Changed Michael to Colton
# Changed Cornwell to Yaakov
# Changed Don to Levi
# Changed Rieck to Jaxson
# Changed Evelyn to Valentino
# Changed Boutros to Archer
# Changed Kofi to Anders
# Changed Ahmedou to Wesson
# Changed Amara to Marcus
# Changed Hamid to Josiah
# Changed Paolo to Nasir
# Changed Joseph to Ridge
# Changed Boutros-Ghali to Kayden
# Changed Boutros-Ghali to Kayden
# Changed Mussolini to Otis
# Changed Alessandra to Reign
# Changed Benito to Richard
# Changed Gianfranco to Charles
# Changed Fini to Houston
# Changed Mussolini to Otis
# Changed Giuseppe to Samir
# Changed Mussolini to Otis
# Changed Sophia to Esteban
# Changed Mussolini to Otis
# Changed Santa to Miller
# Changed Santa to Miller
# Changed Saint to Pablo
# Changed Suraj to Wade
# Changed Rama to Kingston
# Changed William to Chase
# Changed William to Chase
# Changed Stephen to Oscar
# Changed Clarke to Kellan
# Changed Major to Damian
# Changed Kenneth to Arjun
# Changed John to Aarav
# Changed Major to Damian
# Changed Major to Damian
# Changed Clarke to Kellan
# Changed Major to Damian
# Changed Major to Damian
# Changed Clarke to Kellan
# Changed David to Aryan
# Changed Snow to Elias
# Changed Snow to Elias
# Changed Arafat to Lawson
# Changed Netanyahu to Matthias
# Changed Yasser to Denver
# Changed Benjamin to Remi
# Changed Hosni to Westyn
# Changed Arafat to Lawson
# Changed Netanyahu to Matthias
# Changed Mubarak to Tony
# Changed Arafat to Lawson
# Changed Nabil to Krue
# Changed Arafat to Lawson
# Changed Netanyahu to Matthias
# Changed Arafat to Lawson
# Changed Rdainah to James
# Changed Arafat to Lawson
# Changed Mubarak to Tony
# Changed Arafat to Lawson
# Changed Netanyahu to Matthias
# Changed Mubarak to Tony
# Changed Osama to Leon
# Changed Ahmed to Kolton
# Changed Abdel-Rahman to John
# Changed Kesers to Jon
# Changed Karabuluts to Cassius
# Changed David to Aryan
# Changed Nicholas to Devon
# Changed Mohammed to Briar
# Changed Burns to Sean
# Changed Rashid to Isael
# Changed Clinton to Jakari
# Changed Burns to Sean
# Changed Mahammad to Louis
# Changed Rashid to Isael
# Changed Rashid to Isael
# Changed Rashid to Isael
# Changed Abu to Peyton
# Changed Rashid to Isael
# Changed Rashid to Isael
# Changed Mike to Karim
# Changed Cito to Jonah
# Changed Cito to Jonah
# Changed Stephen to Oscar
# Changed Elif to Tripp
# Changed James to Marcos
# Changed Consumer to Noa
# Changed Gundegma to Legend
# Changed Alexander to Azrael
# Changed Marc to Zachariah
# Changed Tim to Noe
# Changed Mohamed to Malachi
# Changed Benchaou to Gabriel
# Changed Benchaou to Gabriel
# Changed Oscar to Xander
# Changed Scalfaro to Malakai
# Changed Scalfaro to Malakai
# Changed Scalfaro to Malakai
# Changed Umberto to Maximus
# Changed Soeren to Ermias
# Changed John to Aarav
# Changed Rosemary to Augustus
# Changed Clarke to Kellan
# Changed Kenneth to Arjun
# Changed Tony to Paul
# Changed Marlow to Ellis
# Changed Kenneth to Arjun
# Changed Marlow to Ellis
# Changed Clarke to Kellan
# Changed Clarke to Kellan
# Changed John to Aarav
# Changed Major to Damian
# Changed Clarke to Kellan
# Changed Michael to Colton
# Changed Edwina to Lennon
# Changed Clarke to Kellan
# Changed Chris to Knox
# Changed Laurie to Alessio
# Changed Alexander to Azrael
# Changed Pamela to Andres
# Changed Paul to Arden
# Changed Tony to Paul
# Changed Leszic to Jaylen
# Changed Michael to Colton
# Changed Crofts to Jorge
# Changed Grove to Kyro
# Changed Grove to Kyro
# Changed Betcher to Ameer
# Changed Bolger to Sebastian
# Changed Nats to Damon
# Changed Jim to Kaden
# Changed Bolger to Sebastian
# Changed Peters to Azael
# Changed Nat to Byron
# Changed Lab to Brodie
# Changed Winston to Maximiliano
# Changed Peters to Azael
# Changed Helen to Bryce
# Changed Peters to Azael
# Changed John to Aarav
# Changed John to Aarav
# Changed Bob to Devin
# Changed Halverson to Elliot
# Changed John to Aarav
# Changed Fraser to Logan
# Changed Halverson to Elliot
# Changed Langmore to Beckham
# Changed Inge to Desmond
# Changed Langmore to Beckham
# Changed Fraser to Logan
# Changed Paul to Arden
# Changed Shimpei to Bryan
# Changed Nukaya to Blake
# Changed Umar to Nehemiah
# Changed Umar to Nehemiah
# Changed Umar to Nehemiah
# Changed PT to Mathias
# Changed Suharto to Sage
# Changed Sigit to Ignacio
# Changed Panutan to Julian
# Changed Suharto to Sage
# Changed Siti to Zachary
# Changed Ramthan to Eliel
# Changed Desmond to Jett
# Changed Mickey to Alan
# Changed Derek to Jimmy
# Changed Tan to Rhett
# Changed Supple to Izaiah
# Changed Supple to Izaiah
# Changed Tan to Rhett
# Changed Tan to Rhett
# Changed Supple to Izaiah
# Changed Hisao to Sterling
# Changed Horinouchi to Douglas
# Changed Horinouchi to Douglas
# Changed Svetlana to Jesus
# Changed Gladishiva to Zaire
# Changed Svetlana to Jesus
# Changed Pernila to Landon
# Changed Carole to Juan
# Changed Hilde to Santana
# Changed Isolde to Colby
# Changed Warwara to Patrick
# Changed Madlen to Niko
# Changed Florence to Erik
# Changed Katja to Reed
# Changed Martina to Louie
# Changed Stefanie to Adan
# Changed Bibiana to Muhammad
# Changed Barbara to Eliseo
# Changed Sybille to Trevor
# Changed Katharina to Brycen
# Changed Leatitia to Zain
# Changed Renate to Austin
# Changed Marianne to Joaquin
# Changed Heidi to Dominic
# Changed Spela to Jasper
# Changed Shannon to Deacon
# Changed Regine to Zaiden
# Changed Anita to Ruben
# Changed Megan to Chaim
# Changed Hilary to Lochlan
# Changed Catherine to Phoenix
# Changed Michaela to Leroy
# Changed Alexandra to Zayn
# Changed Ingeborg to Mylo
# Changed Monika to Trace
# Changed Svetlana to Jesus
# Changed Pernilla to Killian
# Changed Carole to Juan
# Changed Pat to Jiraiya
# Changed Scott to Gianni
# Changed Donna to Brooks
# Changed Mike to Karim
# Changed Kelli to Bruno
# Changed Tiger to Zechariah
# Changed Beth to Rayden
# Changed Davis to Hezekiah
# Changed Renate to Austin
# Changed Goetschl to Ariel
# Changed Katja to Reed
# Changed Renate to Austin
# Changed Carole to Juan
# Changed Pernilla to Killian
# Changed Heidi to Dominic
# Changed Regina to Corbin
# Changed Alexandra to Zayn
# Changed Isolde to Colby
# Changed Ingeborg to Mylo
# Changed Megan to Chaim
# Changed Warwara to Patrick
# Changed Masnada to Laith
# Changed Picabo to Junior
# Changed Stefanie to Adan
# Changed Miriam to Casey
# Changed Bibiana to Muhammad
# Changed Hilde to Santana
# Changed Barbara to Eliseo
# Changed Kate to Alec
# Changed Svetlana to Jesus
# Changed Regine to Zaiden
# Changed Katja to Reed
# Changed Pernilla to Killian
# Changed Hide to Kylen
# Changed Anita to Ruben
# Changed Isolde to Colby
# Changed Heidi to Dominic
# Changed Warwara to Patrick
# Changed Renate to Austin
# Changed Carole to Juan
# Changed Svetlana to Jesus
# Changed Masnada to Laith
# Changed Deborah to Rowan
# Changed Martina to Louie
# Changed Alexandra to Zayn
# Changed Urska to Ty
# Changed Claudia to Finn
# Changed Sabina to Clark
# Changed Barbara to Eliseo
# Changed Stefanie to Adan
# Changed Miriam to Casey
# Changed Pernilla to Killian
# Changed Hilde to Santana
# Changed Svetland to Nathaniel
# Changed Warwara to Patrick
# Changed Florence to Erik
# Changed Katja to Reed
# Changed Isolde to Colby
# Changed Carole to Juan
# Changed Martina to Louie
# Changed Anita to Ruben
# Changed Heidi to Dominic
# Changed Madlen to Niko
# Changed Barbara to Eliseo
# Changed Katharina to Brycen
# Changed Stefanie to Adan
# Changed Leatitia to Zain
# Changed Bibiana to Muhammad
# Changed Miriam to Casey
# Changed Marianne to Joaquin
# Changed Alexandra to Zayn
# Changed Renate to Austin
# Changed Katja to Reed
# Changed Isolde to Colby
# Changed Alexandra to Zayn
# Changed Megan to Chaim
# Changed Miriam to Casey
# Changed Stefanie to Adan
# Changed Ingeborg to Mylo
# Changed Florence to Erik
# Changed Regina to Corbin
# Changed Heidi to Dominic
# Changed Warwara to Patrick
# Changed Barbara to Eliseo
# Changed Hilde to Santana
# Changed Martina to Louie
# Changed Pernilla to Killian
# Changed Svetlana to Jesus
# Changed Anita to Ruben
# Changed Spela to Jasper
# Changed Regine to Zaiden
# Changed Kate to Alec
# Changed Bibiana to Muhammad
# Changed Hilary to Lochlan
# Changed Catherine to Phoenix
# Changed Carole to Juan
# Changed Brigitte to Luke
# Changed Sybille to Trevor
# Changed Grete to Beckett
# Changed Patrizia to Colson
# Changed Alessandra to Reign
# Changed Vadim to Clay
# Changed Frode to Shane
# Changed Ole to Yahya
# Changed Sven to Nicolas
# Changed Ricco to Seth
# Changed Fischer to Amir
# Changed Pavel to Jaime
# Changed Sashurin to Reece
# Changed Olga to Ocean
# Changed Svetlana to Jesus
# Changed Gunn to Bryson
# Changed Simone to Arthur
# Changed Petra to Briggs
# Changed Behle to Dimitri
# Changed Paramygina to Kyren
# Changed Greiner-Petter-Memm to Layton
# Changed Renate to Austin
# Changed Katja to Reed
# Changed Islode to Quinton
# Changed Brian to Maximo
# Changed Shimer to Hugh
# Changed Randy to Seven
# Changed Guenther to Cillian
# Changed Antonio to Elio
# Changed Pierre to Aiden
# Changed Dave to Karson
# Changed Jim to Kaden
# Changed Garrett to Azriel
# Changed Cuo to Kylo
# Changed Xu to Kieran
# Changed Alexis to Ezekiel
# Changed Sebastien to Nikolai
# Changed Blanc to Brayden
# Changed Foucras to Meir
# Changed Jeff to Chance
# Changed Veronica to Henrik
# Changed Karin to Drew
# Changed Evelyne to Ayaan
# Changed Brian to Maximo
# Changed Randy to Seven
# Changed Guenther to Cillian
# Changed Antonio to Elio
# Changed Pierre to Aiden
# Changed Dave to Karson
# Changed Sepp to Miles
# Changed Thomas to Collin
# Changed Reto to Kareem
# Changed Guido to Kingsley
# Changed Dirk to Kyler
# Changed Jakobs to Remington
# Changed Jiri to Ronin
# Changed Pavel to Jaime
# Changed Hubert to Malik
# Changed Erwin to Daxton
# Changed Sean to Damien
# Changed Dean to Kian
# Changed Jim to Kaden
# Changed Garrett to Azriel
# Changed Hines to Roman
# Changed Hannes to Ezrah
# Changed Georg to Halo
# Changed WOOLMER to Armando
# Changed Bob to Devin
# Changed Woolmer to Messiah
# Changed Woolmer to Messiah
# Changed Woolmer to Messiah
# Changed Tony to Paul
# Changed Clarence to Evren
# Changed Woolmer to Messiah
# Changed Woolmer to Messiah
# Changed Woolmer to Messiah
# Changed Alexis to Ezekiel
# Changed Sebastien to Nikolai
# Changed Jeff to Chance
# Changed Eric to Jack
# Changed Christian to Erick
# Changed Alexandre to Melvin
# Changed Ales to Alessandro
# Changed Andy to Davis
# Changed Trace to Cameron
# Changed Dmitri to Jefferson
# Changed Veronica to Henrik
# Changed Karin to Drew
# Changed Evelyne to Ayaan
# Changed Caroline to Maximilian
# Changed Jacqui to Gunner
# Changed Marie to Bradley
# Changed Dan to Leandro
# Changed Kristie to Cade
# Changed Xu to Kieran
# Changed Hilde to Santana
# Changed Takanobu to Orlando
# Changed Kazuyoshi to Ronan
# Changed Andreas to Aziel
# Changed Dieter to Garrett
# Changed Ari-Pekka to Theodore
# Changed Reinhard to Elijah
# Changed Noriaki to Johnny
# Changed Hiroya to Philip
# Changed Jani to Harold
# Changed Kristian to Elliott
# Changed Thoma to Kase
# Changed Brenden to Neo
# Changed Goldberger to Isaias
# Changed Okabe to Yusuf
# Changed Funaki to Nazir
# Changed Saitoh to Izan
# Changed Espen to Rohan
# Changed Nikkola to Sergio
# Changed Soininen to Benny
# Changed Primoz to Bennett
# Changed Fung to Dax
# Changed Indra to Eli
# Changed Sun to Alfred
# Changed Allan to Lachlan
# Changed Susi to Langston
# Changed Camilla to Diego
# Changed Ye to Henry
# Changed Gong to Archie
# Changed Horii to Ephraim
# Changed Jaegal to Stephen
# Changed Grunde to Bjorn
# Changed Shimizu to Leland
# Changed Sergey to Curtis
# Changed Yamakage to Eugene
# Changed Casey to Isaiah
# Changed Sylvain to Truce
# Changed Kim to Holden
# Changed Inoue to Eden
# Changed Xuc to Dangelo
# Changed Svetlana to Jesus
# Changed Franziska to Aries
# Changed Okazaki to Dash
# Changed Shimazaki to Boden
# Changed Marianne to Joaquin
# Changed Jin to Casper
# Changed Alena to Misael
# Changed Chris to Knox
# Changed Anke to Dustin
# Changed Sylvain to Truce
# Changed Sergey to Curtis
# Changed Jan to Manuel
# Changed Grunde to Bjorn
# Changed Lee to Adam
# Changed Inoue to Eden
# Changed Gerard to Avi
# Changed Kim to Holden
# Changed Jeremy to Ben
# Changed Miyabe to Finnegan
# Changed Franziska to Aries
# Changed Kusunose to Castiel
# Changed Marianne to Joaquin
# Changed Anka to Bellamy
# Changed Becky to Jireh
# Changed Shimazaki to Boden
# Changed Oksana to Jesse
# Changed Sammiya to Anthony
# Changed Chris to Knox
# Changed Xue to Abram
# Changed Bernd to Aron
# Changed Billy to Prince
# Changed Pierre to Aiden
# Changed Paul to Arden
# Changed Paul to Arden
# Changed Ally to Kashton
# Changed Andreas to Aziel
# Changed Dean to Kian
# Changed Brian to Maximo
# Changed Darren to Jairo
# Changed Peter to Zakai
# Changed Gerry to Stanley
# Changed Colin to Abel
# Changed Robert to Westley
# Changed Winters to Quentin
# Changed Paolo to Nasir
# Changed Ian to Alberto
# Changed Fabrizio to Sonny
# Changed Alan to Grant
# Changed Matthew to Felix
# Changed Dwight to Wells
# Changed Les to Bruce
# Changed Efan to Brixton
# Changed Gianluca to Ivan
# Changed Robbie to Kamari
# Changed Les to Bruce
# Changed Marcus to Eithan
# Changed Gary to Grayson
# Changed Chris to Knox
# Changed Sutton to Barrett
# Changed Robbie to Kamari
# Changed Steve to Luka
# Changed Peter to Zakai
# Changed Millar to Ernesto
# Changed Miller to Jesiah
# Changed Rowson to Kyaire
# Changed Olafsson to Ricky
# Changed Davies to Cody
# Changed Ross to Julio
# Changed Hay to Imran
# Changed Ferguson to Sevyn
# Changed McCoist to Hayden
# Changed Laudrup to Landyn
# Changed Wright to Lane
# Changed Jackson to Flynn
# Changed McGinlay to Ryland
# Changed CAMPESE to Asaiah
# Changed David to Aryan
# Changed Francois to Jayce
# Changed Michael to Colton
# Changed Philippe to Nixon
# Changed Campese to Franklin
# Changed Nick to Eddie
# Changed Campese to Franklin
# Changed David to Aryan
# Changed Adams to Colter
# Changed Vieira to Ray
# Changed Sturridge to Oakley
# Changed Powell to Tru
# Changed Zola to Brady
# Changed Vialli to Malcolm
# Changed Branch to Bear
# Changed Kanchelskis to Griffin
# Changed Whelan to Parker
# Changed Sheringham to Liam
# Changed Sinton to Yael
# Changed Marshall to Tucker
# Changed Sutton to Barrett
# Changed Whittingham to Everest
# Changed Townsend to Lucca
# Changed Melville to Kaleb
# Changed Ekoku to Giovanni
# Changed Holdsworth to Julien
# Changed VIEIRA to Kameron
# Changed Patrick to Teo
# Changed Dean to Kian
# Changed Darryl to Shimon
# Changed Tony to Paul
# Changed Guy to Alvaro
# Changed Efan to Brixton
# Changed Dean to Kian
# Changed CAMPESE to Asaiah
# Changed David to Aryan
# Changed Campese to Franklin
# Changed Matthew to Felix
# Changed Matthew to Felix
# Changed Joe to Alex
# Changed David to Aryan
# Changed Tim to Noe
# Changed Burke to Joseph
# Changed Burke to Joseph
# Changed Alan to Grant
# Changed Scott to Gianni
# Changed Rob to Kason
# Changed Mark to Ledger
# Changed Des to Mathew
# Changed Nick to Eddie
# Changed Clinton to Jakari
# Changed Mark to Ledger
# Changed Justin to Romeo
# Changed Steve to Luka
# Changed Brett to Moses
# Changed Hugh to Silas
# Changed Greg to Julius
# Changed Mark to Ledger
# Changed Murless to Callum
# Changed Trevor to Alden
# Changed Schalk to Rey
# Changed Merwe to Ibrahim
# Changed Hennie to Hector
# Changed Andrew to Tomas
# Changed Sean to Damien
# Changed Glen to Ryan
# Changed Nic to Tadeo
# Changed Dion to Nathanael
# Changed Fourie to Mauricio
# Changed Steven to Colin
# Changed Bradford to Zavier
# Changed Andrew to Tomas
# Changed Desvonde to Daniel
# Changed Astrit to Dakota
# Changed Eduard to Salvador
# Changed Hafizi to Amias
# Changed Artur to Zayne
# Changed Hafizi to Amias
# Changed Blendi to Albert
# Changed Armir to Dorian
# Changed Rudi to Finnley
# Changed Saimir to Kaisen
# Changed Arjan to Cedric
# Changed Ilir to Kayce
# Changed Afrim to Adonis
# Changed Nevil to Jonas
# Changed Arjan to Cedric
# Changed Bledar to Emmitt
# Changed Altin to Jaxxon
# Changed Sokol to Jettson
# Changed Ervin to Dane
# Changed Altin to Jaxxon
# Changed Viktor to Kaiser
# Changed Fatmir to Eric
# Changed Erjon to Jaxon
# Changed JONES to Aspen
# Changed Dean to Kian
# Changed Jones to Dawson
# Changed David to Aryan
# Changed Shaun to Jericho
# Changed Michael to Colton
# Changed Jones to Dawson
# Changed Shane to Izael
# Changed Laurie to Alessio
# Changed Harper to Joey
# Changed David to Aryan
# Changed Shaun to Jericho
# Changed Pace to Khalil
# Changed Ian to Alberto
# Changed Michael to Colton
# Changed David to Aryan
# Changed Shaun to Jericho
# Changed Dean to Kian
# Changed Kim to Holden
# Changed Hwang to Kaison
# Changed Ko to Samuel
# Changed Ronny to Axel
# Changed Kim to Holden
# Changed Widodo to Zyair
# Changed Hendro to Kade
# Changed Hendro to Kade
# Changed Agung to Benicio
# Changed Suwandi to Maurice
# Changed Yeyen to Stefan
# Changed Aples to Jaden
# Changed Sudiriman to Owen
# Changed Widodo to Zyair
# Changed Ronny to Axel
# Changed Bima to Gael
# Changed Chris to Knox
# Changed Francis to Derrick
# Changed Marzuki to Zyaire
# Changed Kim to Holden
# Changed Kim to Holden
# Changed Huh to Khalid
# Changed Roh to Colt
# Changed Sin to Avyaan
# Changed Kim to Holden
# Changed Ko to Samuel
# Changed Ha to Zyon
# Changed Hwang to Kaison
# Changed Lee to Adam
# Changed Yoo to Lennox
# Changed Kim to Holden
# Changed Hassan to Cyrus
# Changed Adnan to Legacy
# Changed Bakhit to Dereck
# Changed Jassem to Duke
# Changed Kim to Holden
# Changed Hwang to Kaison
# Changed Koo to Moises
# Changed Jeon to Shepard
# Changed Ronny to Axel
# Changed Widodo to Zyair
# Changed BURE to Calum
# Changed Pavel to Jaime
# Changed Garry to Jensen
# Changed Bure to Peter
# Changed Galley to Evan
# Changed Galley to Evan
# Changed Bure to Peter
# Changed Galley to Evan
# Changed Brian to Maximo
# Changed Bure to Peter
# Changed Burke to Joseph
# Changed Bure to Peter
# Changed SCHULZ to Kevin
# Changed RIBALTA to Dillon
# Changed Axel to Milan
# Changed Jose to Francisco
# Changed Davor to Wilson
# Changed Predrag to Mustafa
# Changed Davor to Wilson
# Changed Predrag to Mustafa
# Changed Suker to Shlomo
# Changed Mijatovic to Kohen
# Changed Clarence to Evren
# Changed Ronaldo to Arlo
# Changed Marcelo to River
# Changed Zeljko to Edward
# Changed Vampeta to Lawrence
# Changed Luc to Grady
# Changed CHARLTON to Jonathan
# Changed Jack to Vance
# Changed Charlton to Eren
# Changed Peggy to Jasiel
# Changed Dick to Micah
# Changed Charlton to Eren
# Changed Charlton to Eren
# Changed Charlton to Eren
# Changed Bobby to Wylder

# %%
data_dev[0][0][7]
# Out:
# 'CHINA'

# %%
def recomplie_data(data,file_path):
    with open (file_path, "w") as F:
        for line in data:
            for i in range(len(line[0])):
                F.write(f"{i+1} {line[0][i]} {line[1][i]} {line[2][i]}\n")
            F.write("\n")

# %%
recomplie_data(swapped_data,"../data/gender_names/female_names_test_conll.iob2")

# %%
unique_bper = {}

for i in data_dev:
    for j in range(len(i[0])):
        if i[1][j] == "B-PER":
            if i[0][j] not in unique_bper.keys():
                unique_bper[i[0][j]] = 1
            else:
                unique_bper[i[0][j]] += 1

# %%
len(unique_bper)
# Out:
# 570
