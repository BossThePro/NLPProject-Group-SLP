# %% [markdown]
# Test file for Pronoun swap

# %%
def read_iob2_file_wPOS(path):
    """
    Read provided Universal NER iob2 file
    
    :param path: path to read from
    :returns: list with sequences of words, NER labels and POS tags for each sentence
    """
    data = []
    current_words = []
    current_ner_tags = []
    current_pos_tag = []

    for line in open(path, encoding='utf-8'):
        line = line.strip()

        if line:
            if line[0] == '#':
                continue # skip comments
            tok = line.split(' ')
            #print(tok)
            current_words.append(tok[1])
            current_ner_tags.append(tok[2])
            current_pos_tag.append(tok[3])
        else:
            if current_words:  # skip empty lines
                data.append((current_words, current_ner_tags,current_pos_tag))
            current_words = []
            current_ner_tags = []
            current_pos_tag = []

    # check for last one
    if current_ner_tags != []:
        data.append((current_words, current_ner_tags,current_pos_tag))
    return data

female_dominated_dict = {
    "he" : "she",
    "his" : "hers",
    "him" : "her",
    "himself" : "herself",
    "they" : "she",
    "them" : "her",
    "theirs" : "his"
    }


male_dominated_dict = {
    "she" : "he",
    "hers" : "his",
    "her" : "him",
    "herself" : "himself",
    "they" : "he",
    "them" : "him",
    "theirs" : "his"
    }

gender_neutral_dict = {
    "he" : "they",
    "she" : "they",
    "him" : "them",
    "hers" : "them",
    "his" : "theirs",
    "her" : "theirs",
    "himself" : "themself",
    "herself" : "themself"
    }

def total_pronoun_swap(data, transform_dict):
    """Swaps the pronouns in a given conll file parsed using the read_iob2_file_wPOS function 
    Parameters
    ----------
    data : list 
        Pass the data returned from the parser function, should be a list ex. [([words],[NER tags],[POS tags]),.....]
    
    transform_dict : dict
        a dict which maps the pronouns that you would like to transfrom some helpful examples are provided above such as \
        gender_neutral_dict which trasfroms all pronouns into gender neutral terms
    Returns
    -------
    swapped_data : list 
        A list in the same format as the input, however with the pronous replaced based on the provided dict 
    Notes
    -----
    """
    
    change = 0
    for instance in data:
        for i in range(len(instance[2])):
            if (instance[2][i] == "PRP" or instance[2][i] == "PRP$"):
                  word_to_swap = instance[0][i]
                  swap_to = transform_dict.get(word_to_swap.casefold(),word_to_swap)
                  instance[0][i] = swap_to
                  change += 1

    print(f"Changed {change} tokens")
    return data

# %%
data_dev = read_iob2_file(r"..\data\test_conll.iob2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data_dev = read_iob2_file(r"..\data\test_conll.iob2")
#
# NameError: name 'read_iob2_file' is not defined

# %%
female_dominated_dict = {
    "he" : "she",
    "his" : "hers",
    "him" : "her",
    "himself" : "herself",
    "they" : "she",
    "them" : "her",
    "theirs" : "his"
    }


male_dominated_dict = {
    "she" : "he",
    "hers" : "his",
    "her" : "him",
    "herself" : "himself",
    "they" : "he",
    "them" : "him",
    "theirs" : "his"
    }

gender_neutral_dict = {
    "he" : "they",
    "she" : "they",
    "him" : "them",
    "hers" : "them",
    "his" : "theirs",
    "her" : "theirs",
    "himself" : "themself",
    "herself" : "themself"
    }

# %%
def total_pronoun_swap(data, transform_dict):

    change = 0
    for instance in data:
        for i in range(len(instance[2])):
            if (instance[2][i] == "PRP" or instance[2][i] == "PRP$"):
                  word_to_swap = instance[0][i]
                  swap_to = transform_dict.get(word_to_swap.casefold(),word_to_swap)
                  instance[0][i] = swap_to
                  change += 1

    print(f"Changed {change} tokens")
    return data

# %%
swapped_data = total_pronoun_swap(data_dev,gender_neutral_dict)
# Out:
# Changed 901 tokens

# %%
def category_pronoun_swap(data):

    change = 0
    for instance in data:
        for i in range(len(instance[2])):
            if (instance[2][i] == "PRP" or instance[2][i] == "PRP$"):
                  word_to_swap = instance[0][i]
                  swap_to = gender_neutral_dict.get(word_to_swap.casefold(),word_to_swap)
                  instance[0][i] = swap_to
                  change += 1

    print(f"Changed {change} tokens")
    return data

# %% [markdown]
# """Swap for Gendered Names"""

# %%
#read the file using same function as above
data_dev = read_iob2_file_wPOS(r"..\data\test_conll.iob2")

# %%
data_dev[2]
# Out:
# (['AL-AIN', ',', 'United', 'Arab', 'Emirates', '1996-12-06'],
#  ['B-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O'],
#  ['NNP', ',', 'NNP', 'NNP', 'NNPS', 'CD'])

# %%
count = 0
for i in data_dev:
    for j in i[1]:
        if j == "B-PER":
            count += 1

print(count)
# Out:
# 1617

# %% [markdown]
# Ideas to replace names with:
# 1) Female/Male names from the united states (easy to find)
# 2) Female/Male names from all over the world  (harder to find)
# 3) If we can find some frequency distribution as well (so how often those names occur in the real world),
#     we can assign based off of that, instead of randomly
#
# Since for this experiment we are just looking at how gender effects the biases in NER models, I think just using the gendered names from the US is ok
#
# Dealing with middle names so I-PER: Maybe a list of last names
#
# My opinion: Find the top 1000 female first names and top 1000 male first names in the US, and also find the top 1000 last names (not gender specific as last names usually arent), then all the B-PER are replaced with first names at random, and all thee I-PER are given a random last name (or we can just keep the I-PER as is)
#
# Plan:
# 1) Get top 1000 female names in the US
# 2) Get top 1000 male names in the US
# 3) Get top 1000 last names in the US
# 4) Code should replace all the names from one of the above 3 lists

# %%
import random

# %%
def create_name_dict(data,gender="female"):
    name_dict = {}

    lst_names_1 = ["Malik","Taha","matthew","Maat","matt","Ta","Ma","Lik"]
    lst_names_2 = ["M","Ta","mhew","Mt","att","a","Ma","Lk"]

    for instance in data:

        for i in range(len(instance[1])):

            if instance[1][i] == "B-PER":
                first_name = instance[0][i]
                replacement = random.choice(lst_names_1)

                if first_name not in name_dict.keys():
                    name_dict[first_name] = replacement
                    

            elif instance[1][i] == "I-PER": #another implementation could just be to keep the I-PER as they are (preferred)
                after_name = instance[0][i]
                replacement = random.choice(lst_names_2)

                if after_name not in name_dict.keys():
                    name_dict[after_name] = replacement
                    

    return name_dict

# %%
import pandas as pd

def create_gender_name_dict(data,path="../data/gender_names/top_female_names.csv"):
    """Create a dictionary where each first name in the original dataset (key) gets a random value from a csv file \
        with names from only one gender, defaulted to a file with all female names
    ----------
    data : list 
        Pass the data returned from the parser function, should be a list ex. [([words],[NER tags],[POS tags]),.....]\
        here POS tags are optional 
    
    path : str
        the path to a csv file which includes the replacement names, default is "../data/gender_names/top_female_names.csv" \
        to get all male names change "female" to "male" in the file path
    Returns
    -------
    name_dict : dict
        A dict which for each name in the original dataset gets a random new name from the provided csv file
    Notes
    -----
    Currently you can only have unique keys but not values, since our dataset has about 1600 B-PER, but the csv files only\
    have 1000 names so there will be distinct key that will have the same value

    The code does not create keys for I-PERs, since these are mostly middle names or last names, and traditioally those \
    aren't gender specific (or highly dominated by male names), so our focus becomes first names
    """

    name_dict = {}
    df = pd.read_csv(path)

    for instance in data:

        for i in range(len(instance[1])):

            if instance[1][i] == "B-PER":
                first_name = instance[0][i]

                replacement = random.choice(df["Female Names"]) #change this and then drop replacement

                if first_name not in name_dict.keys():
                    name_dict[first_name] = replacement
                    
    return name_dict
                
                
def gender_name_swap(data,name_dict):
    """Based on the name_dict provided changes all the instances of B-PER using in the data using the name_dict
    ----------
    data : list 
        Pass the data returned from the parser function, should be a list ex. [([words],[NER tags],[POS tags]),.....]\
        here POS tags are optional 
    
    name_dict : dict
        a dict returned from the create_gender_name_dict function, that has all the original names as keys and new \
        names as values
    Returns
    -------
    data : list 
        A list in the same format as the input, however with the names replaced based on the provided dict 
    Notes
    -----
    """
    
    for instance in data:

        for i in range(len(instance[1])):
            if instance[1][i] == "B-PER":
                instance[0][i] = name_dict[instance[0][i]]
    
    return data

# %%
def create_gender_name_dict(data,path="../data/gender_names/top_female_names.csv"):
    """Create a dictionary where each first name in the original dataset (key) gets a random value from a csv file \
        with names from only one gender, defaulted to a file with all female names
    ----------
    data : list 
        Pass the data returned from the parser function, should be a list ex. [([words],[NER tags],[POS tags]),.....]\
        here POS tags are optional 
    
    path : str
        the path to a csv file which includes the replacement names, default is "../data/gender_names/top_female_names.csv" \
        to get all male names change "female" to "male" in the file path
    Returns
    -------
    name_dict : dict
        A dict which for each name in the original dataset gets a random new name from the provided csv file
    Notes
    -----
    Currently you can only have unique keys but not values, since our dataset has about 1600 B-PER, but the csv files only\
    have 1000 names so there will be distinct key that will have the same value

    The code does not create keys for I-PERs, since these are mostly middle names or last names, and traditioally those \
    aren't gender specific (or highly dominated by male names), so our focus becomes first names
    """

    name_dict = {}
    df = pd.read_csv(path)
    name_index = 0

    if path == "../data/gender_names/top_female_names.csv":
        replacement_pool = df["Female Names"].tolist()
    else:
        replacement_pool = df["Male Names"].tolist()

    random.shuffle(replacement_pool)

    for instance in data:

        for i in range(len(instance[1])):

            if instance[1][i] == "B-PER":
                first_name = instance[0][i]

                if first_name not in name_dict.keys():
                    name_dict[first_name] = replacement_pool[name_index]
                    name_index += 1
                    
    return name_dict

# %%
#This cell is mainly to get the top 1000 names list doesnt need to be run again

import requests
from bs4 import BeautifulSoup
import re 
import pandas as pd

def scrape_names(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    names_list_element = soup.find('ol')

    top_1000_names = [li.text.strip() for li in names_list_element.find_all('li')]

    top_1000_names = re.findall(r'[A-Z][a-z]+',top_1000_names[0])

    return top_1000_names

top_1000_female_names = scrape_names("https://www.whattoexpect.com/baby-names/list/top-baby-names-for-girls/")
top_1000_male_names = scrape_names("https://www.whattoexpect.com/baby-names/list/top-baby-names-for-boys/")

df_female = pd.DataFrame(top_1000_female_names,columns=["Female Names"])
df_male = pd.DataFrame(top_1000_male_names,columns=["Male Names"])

df_female.to_csv("../data/gender_names/top_female_names.csv",index=False)
df_male.to_csv("../data/gender_names/top_male_names.csv",index=False)

# %%
import pandas as pd
import random

# %%
#TESTING THE CODE with female names
data_dev = read_iob2_file_wPOS(r"..\data\test_conll.iob2")
female_dict = create_gender_name_dict(data_dev) #leaving path to default
swapped_data = gender_name_swap(data_dev,female_dict)

# %%
def recomplie_data(data,file_path):
    with open (file_path, "w") as F:
        for line in data:
            for i in range(len(line[0])):
                F.write(f"{i+1} {line[0][i]} {line[1][i]} {line[2][i]}\n")
            F.write("\n")

# %%
recomplie_data(swapped_data,"../data/gender_names/female_names_test_conll.iob2")

# %%
def recomplie_data_print(data):
    for line in data:
        for i in range(len(line[0])):
            print(f"{i+1} {line[0][i]} {line[1][i]} {line[2][i]}")
        print("\n")

# %%
recomplie_data_print(swapped_data)
# Out:
# 1 SOCCER O NN
# 2 - O :
# 3 JAPAN B-LOC NNP
# 4 GET O VB
# 5 LUCKY O NNP
# 6 WIN O NNP
# 7 , O ,
# 8 Vienna B-PER NNP
# 9 IN O IN
# 10 SURPRISE O DT
# 11 DEFEAT O NN
# 12 . O .
#
#
# 1 Calliope B-PER NNP
# 2 Ladki I-PER NNP
#
#
# 1 AL-AIN B-LOC NNP
# 2 , O ,
# 3 United B-LOC NNP
# 4 Arab I-LOC NNP
# 5 Emirates I-LOC NNPS
# 6 1996-12-06 O CD
#
#
# 1 Japan B-LOC NNP
# 2 began O VBD
# 3 the O DT
# 4 defence O NN
# 5 of O IN
# 6 their O PRP$
# 7 Asian B-MISC JJ
# 8 Cup I-MISC NNP
# 9 title O NN
# 10 with O IN
# 11 a O DT
# 12 lucky O JJ
# 13 2-1 O CD
# 14 win O VBP
# 15 against O IN
# 16 Syria B-LOC NNP
# 17 in O IN
# 18 a O DT
# 19 Group O NNP
# 20 C O NNP
# 21 championship O NN
# 22 match O NN
# 23 on O IN
# 24 Friday O NNP
# 25 . O .
#
#
# 1 But O CC
# 2 China B-LOC NNP
# 3 saw O VBD
# 4 their O PRP$
# 5 luck O NN
# 6 desert O VB
# 7 them O PRP
# 8 in O IN
# 9 the O DT
# 10 second O NN
# 11 match O NN
# 12 of O IN
# 13 the O DT
# 14 group O NN
# 15 , O ,
# 16 crashing O VBG
# 17 to O TO
# 18 a O DT
# 19 surprise O NN
# 20 2-0 O CD
# 21 defeat O NN
# 22 to O TO
# 23 newcomers O NNS
# 24 Uzbekistan B-LOC NNP
# 25 . O .
#
#
# 1 China B-LOC NNP
# 2 controlled O VBD
# 3 most O JJS
# 4 of O IN
# 5 the O DT
# 6 match O NN
# 7 and O CC
# 8 saw O VBD
# 9 several O JJ
# 10 chances O NNS
# 11 missed O VBD
# 12 until O IN
# 13 the O DT
# 14 78th O JJ
# 15 minute O NN
# 16 when O WRB
# 17 Uzbek B-MISC NNP
# 18 striker O NN
# 19 Aura B-PER JJ
# 20 Shkvyrin I-PER NNP
# 21 took O VBD
# 22 advantage O NN
# 23 of O IN
# 24 a O DT
# 25 misdirected O JJ
# 26 defensive O JJ
# 27 header O NN
# 28 to O TO
# 29 lob O VB
# 30 the O DT
# 31 ball O NN
# 32 over O IN
# 33 the O DT
# 34 advancing O VBG
# 35 Chinese B-MISC JJ
# 36 keeper O NN
# 37 and O CC
# 38 into O IN
# 39 an O DT
# 40 empty O JJ
# 41 net O NN
# 42 . O .
#
#
# 1 Lavender B-PER NNP
# 2 Shatskiku I-PER NNP
# 3 made O VBD
# 4 sure O JJ
# 5 of O IN
# 6 the O DT
# 7 win O VBP
# 8 in O IN
# 9 injury O NN
# 10 time O NN
# 11 , O ,
# 12 hitting O VBG
# 13 an O DT
# 14 unstoppable O JJ
# 15 left O VBD
# 16 foot O NN
# 17 shot O NN
# 18 from O IN
# 19 just O RB
# 20 outside O IN
# 21 the O DT
# 22 area O NN
# 23 . O .
#
#
# 1 The O DT
# 2 former O JJ
# 3 Soviet B-MISC JJ
# 4 republic O NN
# 5 was O VBD
# 6 playing O VBG
# 7 in O IN
# 8 an O DT
# 9 Asian B-MISC NNP
# 10 Cup I-MISC NNP
# 11 finals O NNS
# 12 tie O NN
# 13 for O IN
# 14 the O DT
# 15 first O JJ
# 16 time O NN
# 17 . O .
#
#
# 1 Despite O IN
# 2 winning O VBG
# 3 the O DT
# 4 Asian B-MISC JJ
# 5 Games I-MISC NNPS
# 6 title O NN
# 7 two O CD
# 8 years O NNS
# 9 ago O RB
# 10 , O ,
# 11 Uzbekistan B-LOC NNP
# 12 are O VBP
# 13 in O IN
# 14 the O DT
# 15 finals O NNS
# 16 as O IN
# 17 outsiders O NNS
# 18 . O .
#
#
# 1 Two O CD
# 2 goals O NNS
# 3 from O IN
# 4 defensive O JJ
# 5 errors O NNS
# 6 in O IN
# 7 the O DT
# 8 last O JJ
# 9 six O CD
# 10 minutes O NNS
# 11 allowed O VBD
# 12 Japan B-LOC NNP
# 13 to O TO
# 14 come O VB
# 15 from O IN
# 16 behind O NN
# 17 and O CC
# 18 collect O VB
# 19 all O DT
# 20 three O CD
# 21 points O NNS
# 22 from O IN
# 23 their O PRP$
# 24 opening O NN
# 25 meeting O NN
# 26 against O IN
# 27 Syria B-LOC NNP
# 28 . O .
#
#
# 1 Sierra B-PER NNP
# 2 Takagi I-PER NNP
# 3 scored O VBD
# 4 the O DT
# 5 winner O NN
# 6 in O IN
# 7 the O DT
# 8 88th O JJ
# 9 minute O NN
# 10 , O ,
# 11 rising O VBG
# 12 to O TO
# 13 head O VB
# 14 a O DT
# 15 Mckinley B-PER NNP
# 16 Yanagimoto I-PER NNP
# 17 cross O VB
# 18 towards O IN
# 19 the O DT
# 20 Syrian B-MISC JJ
# 21 goal O NN
# 22 which O WDT
# 23 goalkeeper O VBD
# 24 Itzel B-PER NNP
# 25 Bitar I-PER NNP
# 26 appeared O VBD
# 27 to O TO
# 28 have O VB
# 29 covered O VBN
# 30 but O CC
# 31 then O RB
# 32 allowed O VBN
# 33 to O TO
# 34 slip O VB
# 35 into O IN
# 36 the O DT
# 37 net O NN
# 38 . O .
#
#
# 1 It O PRP
# 2 was O VBD
# 3 the O DT
# 4 second O JJ
# 5 costly O JJ
# 6 blunder O NN
# 7 by O IN
# 8 Syria B-LOC NNP
# 9 in O IN
# 10 four O CD
# 11 minutes O NNS
# 12 . O .
#
#
# 1 Defender O NNP
# 2 Giselle B-PER NNP
# 3 Abbas I-PER NNP
# 4 rose O VBD
# 5 to O TO
# 6 intercept O VB
# 7 a O DT
# 8 long O JJ
# 9 ball O NN
# 10 into O IN
# 11 the O DT
# 12 area O NN
# 13 in O IN
# 14 the O DT
# 15 84th O JJ
# 16 minute O NN
# 17 but O CC
# 18 only O RB
# 19 managed O VBD
# 20 to O TO
# 21 divert O VB
# 22 it O PRP
# 23 into O IN
# 24 the O DT
# 25 top O JJ
# 26 corner O NN
# 27 of O IN
# 28 Josephine B-PER NN
# 29 's O POS
# 30 goal O NN
# 31 . O .
#
#
# 1 Khloe B-PER NNP
# 2 Jokhadar I-PER NNP
# 3 had O VBD
# 4 given O VBN
# 5 Syria B-LOC NNP
# 6 the O DT
# 7 lead O NN
# 8 with O IN
# 9 a O DT
# 10 well-struck O NN
# 11 header O NN
# 12 in O IN
# 13 the O DT
# 14 seventh O JJ
# 15 minute O NN
# 16 . O .
#
#
# 1 Japan B-LOC NNP
# 2 then O RB
# 3 laid O VBD
# 4 siege O NN
# 5 to O TO
# 6 the O DT
# 7 Syrian B-MISC JJ
# 8 penalty O NN
# 9 area O NN
# 10 for O IN
# 11 most O JJS
# 12 of O IN
# 13 the O DT
# 14 game O NN
# 15 but O CC
# 16 rarely O RB
# 17 breached O VBD
# 18 the O DT
# 19 Syrian B-MISC JJ
# 20 defence O NN
# 21 . O .
#
#
# 1 Josephine B-PER NN
# 2 pulled O VBD
# 3 off O RP
# 4 fine O JJ
# 5 saves O VBZ
# 6 whenever O WRB
# 7 they O PRP
# 8 did O VBD
# 9 . O .
#
#
# 1 Japan B-LOC NNP
# 2 coach O NN
# 3 Giovanna B-PER NNP
# 4 Kamo I-PER NNP
# 5 said O VBD
# 6 : O :
# 7 ' O ''
# 8 ' O POS
# 9 The O DT
# 10 Syrian B-MISC JJ
# 11 own O JJ
# 12 goal O NN
# 13 proved O VBD
# 14 lucky O JJ
# 15 for O IN
# 16 us O PRP
# 17 . O .
#
#
# 1 The O DT
# 2 Syrians B-MISC NNPS
# 3 scored O VBD
# 4 early O JJ
# 5 and O CC
# 6 then O RB
# 7 played O VBN
# 8 defensively O RB
# 9 and O CC
# 10 adopted O VBD
# 11 long O RB
# 12 balls O VBZ
# 13 which O WDT
# 14 made O VBD
# 15 it O PRP
# 16 hard O JJ
# 17 for O IN
# 18 us O PRP
# 19 . O .
# 20 ' O ''
#
#
# 1 ' O ''
#
#
# 1 Japan B-LOC NNP
# 2 , O ,
# 3 co-hosts O VBZ
# 4 of O IN
# 5 the O DT
# 6 World B-MISC NNP
# 7 Cup I-MISC NNP
# 8 in O IN
# 9 2002 O CD
# 10 and O CC
# 11 ranked O VBD
# 12 20th O JJ
# 13 in O IN
# 14 the O DT
# 15 world O NN
# 16 by O IN
# 17 FIFA B-ORG NNP
# 18 , O ,
# 19 are O VBP
# 20 favourites O JJ
# 21 to O TO
# 22 regain O VB
# 23 their O PRP$
# 24 title O NN
# 25 here O RB
# 26 . O .
#
#
# 1 Hosts O NNPS
# 2 UAE B-LOC NNP
# 3 play O NN
# 4 Kuwait B-LOC NNP
# 5 and O CC
# 6 South B-LOC NNP
# 7 Korea I-LOC NNP
# 8 take O VBP
# 9 on O IN
# 10 Indonesia B-LOC NNP
# 11 on O IN
# 12 Saturday O NNP
# 13 in O IN
# 14 Group O NNP
# 15 A O NNP
# 16 matches O VBZ
# 17 . O .
#
#
# 1 All O DT
# 2 four O CD
# 3 teams O NNS
# 4 are O VBP
# 5 level O NN
# 6 with O IN
# 7 one O CD
# 8 point O NN
# 9 each O DT
# 10 from O IN
# 11 one O CD
# 12 game O NN
# 13 . O .
#
#
# 1 RUGBY B-ORG NNP
# 2 UNION I-ORG NN
# 3 - O :
# 4 Rosalyn B-PER NNP
# 5 BACK O NNP
# 6 FOR O IN
# 7 ITALY B-LOC JJ
# 8 AFTER O NNP
# 9 A O NNP
# 10 YEAR O NNP
# 11 . O .
#
#
# 1 ROME B-LOC VB
# 2 1996-12-06 O CD
#
#
# 1 Italy B-LOC NNP
# 2 recalled O VBD
# 3 Myla B-PER NNP
# 4 Cuttitta I-PER NNP
#
#
# 1 on O IN
# 2 Friday O NNP
# 3 for O IN
# 4 their O PRP$
# 5 friendly O JJ
# 6 against O IN
# 7 Scotland B-LOC NNP
# 8 at O IN
# 9 Murrayfield B-LOC NNP
# 10 more O JJR
# 11 than O IN
# 12 a O DT
# 13 year O NN
# 14 after O IN
# 15 the O DT
# 16 30-year-old O JJ
# 17 wing O NN
# 18 announced O VBD
# 19 he O PRP
# 20 was O VBD
# 21 retiring O VBG
# 22 following O VBG
# 23 differences O NNS
# 24 over O IN
# 25 selection O NN
# 26 . O .
#
#
# 1 River B-PER NNP
# 2 , O ,
# 3 who O WP
# 4 trainer O NN
# 5 Jayleen B-PER NNP
# 6 Coste I-PER NNP
# 7 said O VBD
# 8 was O VBD
# 9 certain O JJ
# 10 to O TO
# 11 play O VB
# 12 on O IN
# 13 Saturday O NNP
# 14 week O NN
# 15 , O ,
# 16 was O VBD
# 17 named O VBN
# 18 in O IN
# 19 a O DT
# 20 21-man O JJ
# 21 squad O NN
# 22 lacking O VBG
# 23 only O RB
# 24 two O CD
# 25 of O IN
# 26 the O DT
# 27 team O NN
# 28 beaten O VBN
# 29 54-21 O JJ
# 30 by O IN
# 31 England B-LOC NNP
# 32 at O IN
# 33 Twickenham B-LOC NNP
# 34 last O JJ
# 35 month O NN
# 36 . O .
#
#
# 1 Angel B-PER NNP
# 2 Bordon I-PER NNP
# 3 is O VBZ
# 4 out O RP
# 5 through O IN
# 6 illness O NN
# 7 and O CC
# 8 Virginia B-PER NNP
# 9 said O VBD
# 10 he O PRP
# 11 had O VBD
# 12 dropped O VBN
# 13 back O RB
# 14 row O NN
# 15 Jaycee B-PER NNP
# 16 Covi I-PER NNP
# 17 , O ,
# 18 who O WP
# 19 had O VBD
# 20 been O VBN
# 21 recalled O VBD
# 22 for O IN
# 23 the O DT
# 24 England B-LOC NNP
# 25 game O NN
# 26 after O IN
# 27 five O CD
# 28 years O NNS
# 29 out O IN
# 30 of O IN
# 31 the O DT
# 32 national O JJ
# 33 team O NN
# 34 . O .
#
#
# 1 River B-PER NNP
# 2 announced O VBD
# 3 his O PRP$
# 4 retirement O NN
# 5 after O IN
# 6 the O DT
# 7 1995 B-MISC CD
# 8 World I-MISC NNP
# 9 Cup I-MISC NNP
# 10 , O ,
# 11 where O WRB
# 12 he O PRP
# 13 took O VBD
# 14 issue O NN
# 15 with O IN
# 16 being O VBG
# 17 dropped O VBN
# 18 from O IN
# 19 the O DT
# 20 Italy B-LOC NNP
# 21 side O NN
# 22 that O WDT
# 23 faced O VBD
# 24 England B-LOC NNP
# 25 in O IN
# 26 the O DT
# 27 pool O NN
# 28 stages O NNS
# 29 . O .
#
#
# 1 Virginia B-PER NNP
# 2 said O VBD
# 3 he O PRP
# 4 had O VBD
# 5 approached O VBN
# 6 the O DT
# 7 player O NN
# 8 two O CD
# 9 months O NNS
# 10 ago O RB
# 11 about O RB
# 12 a O DT
# 13 comeback O NN
# 14 . O .
#
#
# 1 " O "
# 2 He O PRP
# 3 ended O VBD
# 4 the O DT
# 5 World B-MISC NNP
# 6 Cup I-MISC NNP
# 7 on O IN
# 8 the O DT
# 9 wrong O JJ
# 10 note O NN
# 11 , O ,
# 12 " O "
# 13 Virginia B-PER NNP
# 14 said O VBD
# 15 . O .
#
#
# 1 " O "
# 2 I O PRP
# 3 thought O VBD
# 4 it O PRP
# 5 would O MD
# 6 be O VB
# 7 useful O JJ
# 8 to O TO
# 9 have O VB
# 10 him O PRP
# 11 back O RB
# 12 and O CC
# 13 he O PRP
# 14 said O VBD
# 15 he O PRP
# 16 would O MD
# 17 be O VB
# 18 available O JJ
# 19 . O .
#
#
# 1 I O PRP
# 2 think O VBP
# 3 now O RB
# 4 is O VBZ
# 5 the O DT
# 6 right O JJ
# 7 time O NN
# 8 for O IN
# 9 him O PRP
# 10 to O TO
# 11 return O VB
# 12 . O .
# 13 " O "
#
#
# 1 Squad O VB
# 2 : O :
# 3 Charley B-PER NNP
# 4 Pertile I-PER NNP
# 5 , O ,
# 6 Nova B-PER NNP
# 7 Vaccari I-PER NNP
# 8 , O ,
# 9 Myla B-PER NNP
# 10 Cuttitta I-PER NNP
# 11 , O ,
# 12 Dahlia B-PER NNP
# 13 Francescato I-PER NNP
# 14 , O ,
# 15 Halo B-PER NNP
# 16 Manteri I-PER NNP
# 17 , O ,
# 18 Celeste B-PER NNP
# 19 Dominguez I-PER NNP
# 20 , O ,
# 21 Avianna B-PER NNP
# 22 Mazzariol I-PER NNP
# 23 , O ,
# 24 Adriana B-PER NNP
# 25 Troncon I-PER NNP
# 26 , O ,
# 27 Leila B-PER NNP
# 28 Arancio I-PER NNP
# 29 , O ,
# 30 Isla B-PER NNP
# 31 Sgorlon I-PER NNP
# 32 , O ,
# 33 Alaiya B-PER NNP
# 34 Giovanelli I-PER NNP
# 35 , O ,
# 36 Avani B-PER NNP
# 37 Checchinato I-PER NNP
# 38 , O ,
# 39 Treasure B-PER NNP
# 40 Cristofoletto I-PER NNP
# 41 , O ,
# 42 Ivanna B-PER NNP
# 43 Properzi I-PER NNP
# 44 Curti I-PER NNP
# 45 , O ,
# 46 Avani B-PER NNP
# 47 Orlandi I-PER NNP
# 48 , O ,
# 49 Alaiya B-PER NNP
# 50 Cuttitta I-PER NNP
# 51 , O ,
# 52 Lucia B-PER NNP
# 53 Croci I-PER NNP
# 54 , O ,
# 55 Marlee B-PER NNP
# 56 Guidi I-PER NNP
# 57 , O ,
# 58 Alondra B-PER NNP
# 59 Mazzucato I-PER NNP
# 60 , O ,
# 61 Adriana B-PER NNP
# 62 Moscardi I-PER NNP
# 63 , O ,
# 64 Isla B-PER NNP
# 65 Castellani I-PER NNP
# 66 . O .
#
#
# 1 SOCCER O NN
# 2 - O :
# 3 LATE O JJ
# 4 GOALS O NNS
# 5 GIVE O VBP
# 6 JAPAN B-LOC NNP
# 7 WIN O NNP
# 8 OVER O IN
# 9 SYRIA B-LOC NNP
# 10 . O .
#
#
# 1 AL-AIN B-LOC NNP
# 2 , O ,
# 3 United B-LOC NNP
# 4 Arab I-LOC NNP
# 5 Emirates I-LOC NNPS
# 6 1996-12-06 O CD
#
#
# 1 Two O CD
# 2 goals O NNS
# 3 in O IN
# 4 the O DT
# 5 last O JJ
# 6 six O CD
# 7 minutes O NNS
# 8 gave O VBD
# 9 holders O NNS
# 10 Japan B-LOC NNP
# 11 an O DT
# 12 uninspiring O JJ
# 13 2-1 O CD
# 14 Asian B-MISC NNP
# 15 Cup I-MISC NNP
# 16 victory O NN
# 17 over O IN
# 18 Syria B-LOC NNP
# 19 on O IN
# 20 Friday O NNP
# 21 . O .
#
#
# 1 Sierra B-PER NNP
# 2 Takagi I-PER NNP
# 3 headed O VBD
# 4 the O DT
# 5 winner O NN
# 6 in O IN
# 7 the O DT
# 8 88th O JJ
# 9 minute O NN
# 10 of O IN
# 11 the O DT
# 12 group O NN
# 13 C O NNP
# 14 game O NN
# 15 after O IN
# 16 goalkeeper O NN
# 17 Itzel B-PER NNP
# 18 Bitar I-PER NNP
# 19 spoiled O JJ
# 20 a O DT
# 21 mistake-free O NN
# 22 display O NN
# 23 by O IN
# 24 allowing O VBG
# 25 the O DT
# 26 ball O NN
# 27 to O TO
# 28 slip O VB
# 29 under O IN
# 30 his O PRP$
# 31 body O NN
# 32 . O .
#
#
# 1 It O PRP
# 2 was O VBD
# 3 the O DT
# 4 second O JJ
# 5 Syrian B-MISC JJ
# 6 defensive O JJ
# 7 blunder O NN
# 8 in O IN
# 9 four O CD
# 10 minutes O NNS
# 11 . O .
#
#
# 1 Defender O NNP
# 2 Giselle B-PER NNP
# 3 Abbas I-PER NNP
# 4 rose O VBD
# 5 to O TO
# 6 intercept O VB
# 7 a O DT
# 8 long O JJ
# 9 ball O NN
# 10 into O IN
# 11 the O DT
# 12 area O NN
# 13 in O IN
# 14 the O DT
# 15 84th O JJ
# 16 minute O NN
# 17 but O CC
# 18 only O RB
# 19 managed O VBD
# 20 to O TO
# 21 divert O VB
# 22 it O PRP
# 23 into O IN
# 24 the O DT
# 25 top O JJ
# 26 corner O NN
# 27 of O IN
# 28 Josephine B-PER NN
# 29 's O POS
# 30 goal O NN
# 31 . O .
#
#
# 1 Syria B-LOC NNP
# 2 had O VBD
# 3 taken O VBN
# 4 the O DT
# 5 lead O NN
# 6 from O IN
# 7 their O PRP$
# 8 first O JJ
# 9 serious O JJ
# 10 attack O NN
# 11 in O IN
# 12 the O DT
# 13 seventh O JJ
# 14 minute O NN
# 15 . O .
#
#
# 1 Khloe B-PER NNP
# 2 Jokhadar I-PER NNP
# 3 headed O VBD
# 4 a O DT
# 5 cross O NN
# 6 from O IN
# 7 the O DT
# 8 right O NN
# 9 by O IN
# 10 Charlee B-PER NNP
# 11 Awad I-PER NNP
# 12 into O IN
# 13 the O DT
# 14 top O JJ
# 15 right O NN
# 16 corner O NN
# 17 of O IN
# 18 Karter B-PER NNP
# 19 Shimokawa I-PER NNP
# 20 's O POS
# 21 goal O NN
# 22 . O .
#
#
# 1 Japan B-LOC NNP
# 2 then O RB
# 3 laid O VBD
# 4 siege O NN
# 5 to O TO
# 6 the O DT
# 7 Syrian B-MISC JJ
# 8 penalty O NN
# 9 area O NN
# 10 and O CC
# 11 had O VBD
# 12 a O DT
# 13 goal O NN
# 14 disallowed O VBD
# 15 for O IN
# 16 offside O NN
# 17 in O IN
# 18 the O DT
# 19 16th O JJ
# 20 minute O NN
# 21 . O .
#
#
# 1 A O DT
# 2 minute O NN
# 3 later O RB
# 4 , O ,
# 5 Josephine B-PER NN
# 6 produced O VBD
# 7 a O DT
# 8 good O JJ
# 9 double O JJ
# 10 save O VB
# 11 , O ,
# 12 first O JJ
# 13 from O IN
# 14 Kinley B-PER NNP
# 15 Miura I-PER NNP
# 16 's O POS
# 17 header O NN
# 18 and O CC
# 19 then O RB
# 20 blocked O VBN
# 21 a O DT
# 22 Khaleesi B-PER NNP
# 23 follow-up O JJ
# 24 shot O NN
# 25 . O .
#
#
# 1 Josephine B-PER JJ
# 2 saved O JJ
# 3 well O NN
# 4 again O RB
# 5 from O IN
# 6 Harmoni B-PER NNP
# 7 in O IN
# 8 the O DT
# 9 37th O JJ
# 10 minute O NN
# 11 , O ,
# 12 parrying O VBG
# 13 away O RB
# 14 his O PRP$
# 15 header O NN
# 16 from O IN
# 17 a O DT
# 18 corner O NN
# 19 . O .
#
#
# 1 Japan B-LOC NNP
# 2 started O VBD
# 3 the O DT
# 4 second O JJ
# 5 half O NN
# 6 brightly O RB
# 7 but O CC
# 8 Josephine B-PER NNP
# 9 denied O VBD
# 10 them O PRP
# 11 an O DT
# 12 equaliser O NN
# 13 when O WRB
# 14 he O PRP
# 15 dived O VBD
# 16 to O TO
# 17 his O PRP$
# 18 right O NN
# 19 to O TO
# 20 save O VB
# 21 Genevieve B-PER NNP
# 22 Soma I-PER NNP
# 23 's O POS
# 24 low O JJ
# 25 drive O NN
# 26 in O IN
# 27 the O DT
# 28 53rd O CD
# 29 minute O NN
# 30 . O .
#
#
# 1 Japan B-LOC NNP
# 2 : O :
# 3 19 O CD
# 4 - O :
# 5 Karter B-PER NNP
# 6 Shimokawa I-PER NNP
# 7 , O ,
# 8 2 O CD
# 9 - O :
# 10 Mckinley B-PER NNP
# 11 Yanagimoto I-PER NNP
# 12 , O ,
# 13 3 O CD
# 14 - O :
# 15 Genevieve B-PER NNP
# 16 Soma I-PER NNP
# 17 , O ,
# 18 4 O CD
# 19 - O :
# 20 Winona B-PER NNP
# 21 Ihara I-PER NNP
# 22 , O ,
# 23 5 O CD
# 24 - O :
# 25 Carly B-PER NNP
# 26 Omura I-PER NNP
# 27 , O ,
# 28 6 O CD
# 29 - O :
# 30 Anaiah B-PER NNP
# 31 Yamaguchi I-PER NNP
# 32 , O ,
# 33 8 O CD
# 34 - O :
# 35 Ryan B-PER NNP
# 36 Maezono I-PER NNP
# 37 ( O (
# 38 7 O CD
# 39 - O :
# 40 Lisa B-PER NNP
# 41 Honda I-PER NNP
# 42 71 O CD
# 43 ) O )
# 44 , O ,
# 45 9 O CD
# 46 - O :
# 47 Sierra B-PER NNP
# 48 Takagi I-PER NNP
# 49 , O ,
# 50 10 O CD
# 51 - O :
# 52 Sunny B-PER NNP
# 53 Nanami I-PER NNP
# 54 , O ,
# 55 11 O CD
# 56 - O :
# 57 Kinley B-PER NNP
# 58 Miura I-PER NNP
# 59 , O ,
# 60 15 O CD
# 61 - O :
# 62 Harmony B-PER NNP
# 63 Morishima I-PER NNP
# 64 ( O (
# 65 14 O CD
# 66 - O :
# 67 Nala B-PER NNP
# 68 Okano I-PER NNP
# 69 75 O CD
# 70 ) O )
# 71 . O .
#
#
# 1 Syria B-LOC NNP
# 2 : O :
# 3 24 O CD
# 4 - O :
# 5 Itzel B-PER NNP
# 6 Bitar I-PER NNP
# 7 , O ,
# 8 3 O CD
# 9 - O :
# 10 Alivia B-PER NNP
# 11 Srour I-PER NNP
# 12 ; O :
# 13 4 O CD
# 14 - O :
# 15 Giselle B-PER NNP
# 16 Abbas I-PER NNP
# 17 , O ,
# 18 5 O CD
# 19 - O :
# 20 Gwen B-PER NNP
# 21 Jabban I-PER NNP
# 22 , O ,
# 23 6 O CD
# 24 - O :
# 25 Charlee B-PER NNP
# 26 Awad I-PER NNP
# 27 ( O (
# 28 9 O CD
# 29 - O :
# 30 Arleth B-PER JJ
# 31 Taleb I-PER NNP
# 32 69 O CD
# 33 ) O )
# 34 , O ,
# 35 8 O CD
# 36 - O :
# 37 Gwen B-PER NNP
# 38 al-Boushi I-PER NNS
# 39 , O ,
# 40 10 O CD
# 41 - O :
# 42 Emmie B-PER NNP
# 43 Afash I-PER NNP
# 44 , O ,
# 45 12 O CD
# 46 - O :
# 47 Denver B-PER NNP
# 48 Dib I-PER NNP
# 49 , O ,
# 50 13 O CD
# 51 - O :
# 52 Zoey B-PER NNP
# 53 Latif I-PER NNP
# 54 Helou I-PER NNP
# 55 ( O (
# 56 17 O CD
# 57 - O :
# 58 Charlee B-PER NNP
# 59 Rihawiy I-PER NNP
# 60 46 O CD
# 61 ) O )
# 62 , O ,
# 63 14 O CD
# 64 - O :
# 65 Giovanna B-PER VBD
# 66 Zaher I-PER NNP
# 67 ; O :
# 68 16 O CD
# 69 - O :
# 70 Khloe B-PER NNP
# 71 Jokhadar I-PER NNP
# 72 . O .
#
#
# 1 FREESTYLE O NNP
# 2 SKIING-WORLD B-MISC NNP
# 3 CUP I-MISC NNP
# 4 MOGUL O NNP
# 5 RESULTS O NNS
# 6 . O .
#
#
# 1 TIGNES B-LOC NNP
# 2 , O ,
# 3 France B-LOC NNP
# 4 1996-12-06 O CD
#
#
# 1 Results O NNS
# 2 of O IN
# 3 the O DT
# 4 World B-MISC NNP
# 5 Cup I-MISC NNP
#
#
# 1 freestyle O JJ
# 2 skiing O NN
# 3 moguls O NNS
# 4 competition O NN
# 5 on O IN
# 6 Friday O NNP
# 7 : O :
#
#
# 1 Men O NN
#
#
# 1 1. O CD
# 2 Elowyn B-PER NNP
# 3 Ronnback I-PER NNP
# 4 ( O (
# 5 Sweden B-LOC NNP
# 6 ) O )
# 7 25.76 O CD
# 8 points O NNS
#
#
# 1 2. O CD
# 2 Amelia B-PER NNP
# 3 Ivanov I-PER NNP
# 4 ( O (
# 5 Russia B-LOC NNP
# 6 ) O )
# 7 24.88 O CD
#
#
# 1 3. O NNP
# 2 Thalia B-PER NNP
# 3 Johnson I-PER NNP
# 4 ( O (
# 5 Canada B-LOC NNP
# 6 ) O )
# 7 24.57 O CD
#
#
# 1 4. O CD
# 2 Angel B-PER NNP
# 3 Brassard I-PER NNP
# 4 ( O (
# 5 Canada B-LOC NNP
# 6 ) O )
# 7 24.40 O CD
#
#
# 1 5. O CD
# 2 Camilla B-PER NNP
# 3 Hole I-PER NNP
# 4 ( O (
# 5 Norway B-LOC NNP
# 6 ) O )
# 7 23.92 O CD
#
#
# 1 6. O CD
# 2 Braelynn B-PER NNP
# 3 Collomb-Patton I-PER NNP
# 4 ( O (
# 5 France B-LOC NNP
# 6 ) O )
# 7 23.87 O CD
#
#
# 1 7. O NNP
# 2 Meredith B-PER NNP
# 3 Moran I-PER NNP
# 4 ( O (
# 5 U.S. B-LOC NNP
# 6 ) O )
# 7 23.25 O CD
#
#
# 1 8. O NNP
# 2 Katie B-PER NNP
# 3 Gauthier I-PER NNP
# 4 ( O (
# 5 Canada B-LOC NNP
# 6 ) O )
# 7 22.73 O CD
#
#
# 1 9. O CD
# 2 Allie B-PER NNP
# 3 Gregoire I-PER NNP
# 4 ( O (
# 5 France B-LOC NNP
# 6 ) O )
# 7 22.58 O CD
#
#
# 1 10. O CD
# 2 Janelle B-PER NNP
# 3 Benson I-PER NNP
# 4 ( O (
# 5 U.S. B-LOC NNP
# 6 ) O )
# 7 22.56 O CD
#
#
# 1 Women O NNS
#
#
# 1 1. O CD
# 2 Murphy B-PER NNP
# 3 Mittermayer I-PER NNP
# 4 ( O (
# 5 Germany B-LOC NNP
# 6 ) O )
# 7 24.32 O CD
#
#
# 1 2. O NNP
# 2 Kenna B-PER NNP
# 3 Gilg I-PER NNP
# 4 ( O (
# 5 France B-LOC NNP
# 6 ) O )
# 7 24.31 O CD
#
#
# 1 3. O NNP
# 2 Collins B-PER NNP
# 3 Karhu I-PER NNP
# 4 ( O (
# 5 Finland B-LOC NNP
# 6 ) O )
# 7 24.05 O CD
#
#
# 1 4. O CD
# 2 Karter B-PER NNP
# 3 Satoya I-PER NNP
# 4 ( O (
# 5 Japan B-LOC NNP
# 6 ) O )
# 7 23.75 O CD
#
#
# 1 5. O NNP
# 2 Kahlani B-PER NNP
# 3 Battellle I-PER NNP
# 4 ( O (
# 5 U.S. B-LOC NNP
# 6 ) O )
# 7 23.56 O CD
#
#
# 1 6. O NNP
# 2 Loretta B-PER NNP
# 3 Weinbrecht I-PER NNP
# 4 ( O (
# 5 U.S. B-LOC NNP
# 6 ) O )
# 7 22.48 O CD
#
#
# 1 7. O NNP
# 2 Fatima B-PER NNP
# 3 McIntyre I-PER NNP
# 4 ( O (
# 5 U.S. B-LOC NNP
# 6 ) O )
# 7 22.00 O CD
#
#
# 1 8. O NNP
# 2 Evie B-PER NNP
# 3 Koroleva I-PER NNP
# 4 ( O (
# 5 Russia B-LOC NNP
# 6 ) O )
# 7 21.77 O CD
#
#
# 1 9. O CD
# 2 Malka B-PER NNP
# 3 Dymchenko I-PER NNP
# 4 ( O (
# 5 Russia B-LOC NNP
# 6 ) O )
# 7 21.59 O CD
#
#
# 1 10. O CD
# 2 Emmie B-PER NNP
# 3 Allais I-PER NNPS
# 4 ( O (
# 5 France B-LOC NNP
# 6 ) O )
# 7 21.58 O CD
#
#
# 1 SOCCER O NN
# 2 - O :
# 3 ASIAN B-MISC NNP
# 4 CUP I-MISC NNP
# 5 GROUP O NNP
# 6 C O NNP
# 7 RESULTS O NNS
# 8 . O .
#
#
# 1 AL-AIN B-LOC NNP
# 2 , O ,
# 3 United B-LOC NNP
# 4 Arab I-LOC NNP
# 5 Emirates I-LOC NNPS
# 6 1996-12-06 O CD
#
#
# 1 Results O NNS
# 2 of O IN
# 3 Asian B-MISC NNP
# 4 Cup I-MISC NNP
# 5 group O NN
# 6 C O NNP
# 7 matches O NNS
# 8 played O VBN
# 9 on O IN
# 10 Friday O NNP
# 11 : O :
#
#
# 1 Japan B-LOC NNP
# 2 2 O CD
# 3 Syria B-LOC NNP
# 4 1 O CD
# 5 ( O (
# 6 halftime O NN
# 7 0-1 O JJ
# 8 ) O )
#
#
# 1 Scorers O NNS
# 2 : O :
#
#
# 1 Japan B-LOC NNP
# 2 - O :
# 3 Giselle B-PER NNP
# 4 Abbas I-PER NNP
# 5 84 O CD
# 6 own O JJ
# 7 goal O NN
# 8 , O ,
# 9 Sierra B-PER NNP
# 10 Takagi I-PER NNP
# 11 88 O CD
# 12 . O .
#
#
# 1 Syria B-LOC NNP
# 2 - O :
# 3 Khloe B-PER NNP
# 4 Jokhadar I-PER NNP
# 5 7 O CD
#
#
# 1 Attendance O NN
# 2 : O :
# 3 10,000 O LS
# 4 . O .
#
#
# 1 China B-LOC NNP
# 2 0 O CD
# 3 Uzbekistan B-LOC NNP
# 4 2 O CD
# 5 ( O (
# 6 halftime O NN
# 7 0-0 O CD
# 8 ) O )
#
#
# 1 Scorers O NNS
# 2 : O :
# 3 Kaeli B-PER NNP
# 4 Igor I-PER NNP
# 5 78 O CD
# 6 , O ,
# 7 Salome B-PER NNP
# 8 Oleg I-PER NNP
# 9 90 O CD
#
#
# 1 Attendence O NN
# 2 : O :
# 3 3,000 O CD
#
#
# 1 Standings O NNS
# 2 ( O (
# 3 tabulate O NN
# 4 under O IN
# 5 played O JJ
# 6 , O ,
# 7 won O VBD
# 8 , O ,
# 9 drawn O VBN
# 10 , O ,
# 11 lost O VBD
# 12 , O ,
# 13 goals O NNS
#
#
# 1 for O IN
# 2 , O ,
# 3 goals O NNS
# 4 against O IN
# 5 , O ,
# 6 points O VBZ
# 7 ) O )
# 8 : O :
#
#
# 1 Uzbekistan B-LOC NNP
# 2 1 O CD
# 3 1 O CD
# 4 0 O CD
# 5 0 O CD
# 6 2 O CD
# 7 0 O CD
# 8 3 O CD
#
#
# 1 Japan B-LOC NNP
# 2 1 O CD
# 3 1 O CD
# 4 0 O CD
# 5 0 O CD
# 6 2 O CD
# 7 1 O CD
# 8 3 O CD
#
#
# 1 Syria B-LOC NNP
# 2 1 O CD
# 3 0 O CD
# 4 0 O CD
# 5 1 O CD
# 6 1 O CD
# 7 2 O CD
# 8 0 O CD
#
#
# 1 China B-LOC NNP
# 2 1 O CD
# 3 0 O CD
# 4 0 O CD
# 5 1 O CD
# 6 0 O CD
# 7 2 O CD
# 8 0 O CD
#
#
# 1 CRICKET O NNP
# 2 - O :
# 3 PAKISTAN B-LOC NNP
# 4 V O NNP
# 5 NEW B-LOC JJ
# 6 ZEALAND I-LOC NNP
# 7 ONE-DAY O JJ
# 8 SCOREBOARD O NNP
# 9 . O .
#
#
# 1 [ O (
# 2 CORRECTED O NNP
# 3 14:06 O CD
# 4 GMT B-MISC NNP
# 5 ] O )
#
#
# 1 SIALKOT B-LOC NNP
# 2 , O ,
# 3 Pakistan B-LOC NNP
# 4 1996-12-06 O CD
#
#
# 1 Scoreboard O RB
# 2 in O IN
# 3 the O DT
# 4 second O JJ
#
#
# 1 one-day O JJ
# 2 cricket O NN
# 3 international O JJ
# 4 between O IN
# 5 Pakistan B-LOC NNP
# 6 and O CC
# 7 New B-LOC NNP
# 8 Zealand I-LOC NNP
#
#
# 1 on O IN
# 2 Friday O NNP
# 3 : O :
#
#
# 1 Pakistan B-LOC NNP
#
#
# 1 Keilani B-PER NNP
# 2 Anwar I-PER NNP
# 3 run O VBP
# 4 out O RP
# 5 91 O CD
# 6 ( O (
# 7 corrects O VBZ
# 8 from O IN
# 9 90 O CD
# 10 ) O )
#
#
# 1 Saanvi B-PER NNP
# 2 Elahi I-PER NNP
# 3 b O SYM
# 4 Pearl B-PER NNPS
# 5 86 O CD
# 6 ( O (
# 7 corrects O VBZ
# 8 from O IN
# 9 87 O CD
# 10 ) O )
#
#
# 1 Fiona B-PER NNP
# 2 Ahmad I-PER NNP
# 3 c O SYM
# 4 Quinn B-PER NNP
# 5 b O SYM
# 6 Mckinley B-PER NNP
# 7 59 O CD
#
#
# 1 Lila B-PER JJ
# 2 Haq I-PER NNP
# 3 st O NN
# 4 Jane B-PER NNP
# 5 b O SYM
# 6 Saige B-PER NNP
# 7 2 O CD
#
#
# 1 Olivia B-PER NNP
# 2 Akram I-PER NNP
# 3 b O SYM
# 4 Myra B-PER NNP
# 5 4 O CD
#
#
# 1 Eva B-PER NNP
# 2 Afridi I-PER NNP
# 3 b O SYM
# 4 Myra B-PER NNP
# 5 2 O CD
#
#
# 1 Laurel B-PER NNP
# 2 Khan I-PER NNP
# 3 c O SYM
# 4 Saige B-PER NNP
# 5 b O SYM
# 6 Myra B-PER NNP
# 7 1 O CD
#
#
# 1 Remy B-PER NNP
# 2 Younis I-PER NNP
# 3 st O NN
# 4 Jane B-PER NNP
# 5 b O SYM
# 6 Myra B-PER NNP
# 7 0 O CD
#
#
# 1 Miriam B-PER NNP
# 2 Mushtaq I-PER NNP
# 3 b O SYM
# 4 Myra B-PER NNP
# 5 2 O CD
#
#
# 1 Ariyah B-PER NNP
# 2 Ahmad I-PER NNP
# 3 not O RB
# 4 out O IN
# 5 5 O CD
#
#
# 1 Delilah B-PER NNP
# 2 Malik I-PER NNP
# 3 not O RB
# 4 out O IN
# 5 1 O CD
#
#
# 1 Extras O NNS
# 2 ( O (
# 3 lb-8 O CD
# 4 nb-2 O JJ
# 5 w-14 O CD
# 6 ) O )
# 7 24 O CD
#
#
# 1 Total O JJ
# 2 ( O (
# 3 for O IN
# 4 9 O CD
# 5 wickets O NNS
# 6 in O IN
# 7 47 O CD
# 8 overs O NNS
# 9 ) O )
# 10 277 O CD
#
#
# 1 Fall O NN
# 2 of O IN
# 3 wicket O NN
# 4 : O :
# 5 1-177 O CD
# 6 ( O (
# 7 corrects O VBZ
# 8 from O IN
# 9 1-178 O CD
# 10 ) O )
# 11 2-225 O CD
# 12 3-240 O CD
# 13 4-247 O CD
# 14 5-252 O CD
# 15 6-260 O CD
# 16 7-261 O CD
# 17 8-269 O CD
# 18 9-276 O CD
#
#
# 1 Bowling O NNP
# 2 : O :
# 3 Cataleya B-PER VB
# 4 8-1-60-0 O CD
# 5 ( O (
# 6 w-3 O CD
# 7 ) O )
# 8 , O ,
# 9 Adalynn B-PER NNP
# 10 3-0-24-0 O CD
# 11 ( O (
# 12 w-7 O CD
# 13 nb-1 O JJ
# 14 ) O )
# 15 , O ,
#
#
# 1 Pearl B-PER NNS
# 2 8-1-35-1 O JJ
# 3 ( O (
# 4 w-2 O CD
# 5 ) O )
# 6 , O ,
# 7 Mckinley B-PER NNP
# 8 9-1-55-1 O CD
# 9 , O ,
# 10 Myra B-PER NNP
# 11 10-0-42-5 O CD
# 12 ( O (
# 13 w-1 O CD
# 14 ) O )
# 15 , O ,
#
#
# 1 Saige B-PER NNP
# 2 9-0-53-1 O CD
# 3 ( O (
# 4 w-1 O CD
# 5 nb-1 O JJ
# 6 ) O )
#
#
# 1 New B-LOC NNP
# 2 Zealand I-LOC NNP
# 3 innings O NN
#
#
# 1 Nyomi B-PER NNP
# 2 Young I-PER NNP
# 3 c O SYM
# 4 Laurel B-PER NNP
# 5 Khan I-PER NNP
# 6 b O SYM
# 7 Remy B-PER NNP
# 8 5 O CD
#
#
# 1 Fernanda B-PER NNP
# 2 Spearman I-PER NNP
# 3 c O SYM
# 4 Laurel B-PER NNP
# 5 Khan I-PER NNP
# 6 b O SYM
# 7 Olivia B-PER NNP
# 8 0 O CD
#
#
# 1 Joanna B-PER NNP
# 2 Parore I-PER NNP
# 3 c O SYM
# 4 Fiona B-PER NNP
# 5 Ahmad I-PER NNP
# 6 b O SYM
# 7 Miriam B-PER NNP
# 8 37 O CD
#
#
# 1 Cecelia B-PER NNP
# 2 Fleming I-PER NNP
# 3 c O SYM
# 4 and O CC
# 5 b O SYM
# 6 Remi B-PER NNP
# 7 88 O CD
#
#
# 1 Fernanda B-PER NNP
# 2 Cairns I-PER NNPS
# 3 b O SYM
# 4 Miriam B-PER NNP
# 5 10 O CD
#
#
# 1 Dream B-PER NNP
# 2 Astle I-PER NNP
# 3 c O SYM
# 4 Fiona B-PER NNP
# 5 Ahmad I-PER NNP
# 6 b O SYM
# 7 Delilah B-PER NNP
# 8 Malik I-PER NNP
# 9 20 O CD
#
#
# 1 Fernanda B-PER NNP
# 2 Harris I-PER NNP
# 3 lbw O NN
# 4 b O SYM
# 5 Olivia B-PER NNP
# 6 22 O CD
#
#
# 1 Ryleigh B-PER NNP
# 2 Germon I-PER NNP
# 3 lbw O NN
# 4 b O SYM
# 5 Remi B-PER NNP
# 6 2 O CD
#
#
# 1 Talia B-PER NNP
# 2 Vaughan I-PER NNP
# 3 c O SYM
# 4 Laurel B-PER NNP
# 5 Khan I-PER NNP
# 6 b O SYM
# 7 Olivia B-PER NN
# 8 13 O CD
#
#
# 1 Cecelia B-PER NNP
# 2 Doull I-PER NNP
# 3 c O SYM
# 4 subs O NNS
# 5 ( O (
# 6 Hana B-PER NNP
# 7 Wasim I-PER NNP
# 8 ) O )
# 9 b O SYM
# 10 Remy B-PER NNP
# 11 1 O CD
#
#
# 1 Emmy B-PER NNP
# 2 Kennedy I-PER NNP
# 3 not O RB
# 4 out O IN
# 5 7 O CD
#
#
# 1 Extras O NNS
# 2 ( O (
# 3 b-9 O CD
# 4 lb-3 O CD
# 5 w-12 O CD
# 6 nb-2 O JJ
# 7 ) O )
# 8 26 O CD
#
#
# 1 Total O JJ
# 2 ( O (
# 3 all O DT
# 4 out O RP
# 5 in O IN
# 6 42.1 O CD
# 7 overs O NNS
# 8 ) O )
# 9 231 O CD
#
#
# 1 Fall O NN
# 2 of O IN
# 3 wickets O NN
# 4 : O :
# 5 1-3 O CD
# 6 2-7 O JJ
# 7 3-125 O CD
# 8 4-146 O JJ
# 9 5-170 O JJ
# 10 6-190 O CD
# 11 7-195 O NN
#
#
# 1 8-213 O CD
# 2 9-216 O CD
# 3 . O .
#
#
# 1 Bowling O NNP
# 2 : O :
# 3 Olivia B-PER NNP
# 4 Akram I-PER NNP
# 5 8.1-0-43-3 O CD
# 6 ( O (
# 7 9w O CD
# 8 , O ,
# 9 1nb O CD
# 10 ) O )
# 11 , O ,
# 12 Remy B-PER NNP
# 13 Younis I-PER NNP
#
#
# 1 6-0-32-2 O RB
# 2 ( O (
# 3 2w O CD
# 4 , O ,
# 5 1nb O CD
# 6 ) O )
# 7 , O ,
# 8 Miriam B-PER NNP
# 9 Mushtaq I-PER NNP
# 10 8-0-54-2 O CD
# 11 , O ,
# 12 Ariyah B-PER NNP
# 13 Ahmad I-PER NNP
#
#
# 1 10-0-42-0 O CD
# 2 ( O (
# 3 1w O CD
# 4 ) O )
# 5 , O ,
# 6 Eva B-PER NNP
# 7 Afridi I-PER NNP
# 8 7-0-40-2 O CD
# 9 , O ,
# 10 Delilah B-PER NNP
# 11 Malik I-PER NNP
# 12 2.5-0-8-1 O CD
# 13 , O ,
#
#
# 1 Fiona B-PER NNP
# 2 Ahmad I-PER NNP
# 3 0.1-0-0-0 O NNS
# 4 . O .
#
#
# 1 Result O NN
# 2 : O :
# 3 Pakistan B-LOC NNP
# 4 won O VBD
# 5 by O IN
# 6 46 O CD
# 7 runs O NNS
# 8 . O .
#
#
# 1 Third O JJ
# 2 one-day O JJ
# 3 match O NN
# 4 : O :
# 5 December O NNP
# 6 8 O CD
# 7 , O ,
# 8 in O IN
# 9 Karachi B-LOC NNP
# 10 . O .
#
#
# 1 SOCCER O NN
# 2 - O :
# 3 ENGLISH B-MISC NNP
# 4 F.A. I-MISC NNP
# 5 CUP I-MISC NNP
# 6 SECOND O NNP
# 7 ROUND O NNP
# 8 RESULT O NNP
# 9 . O .
#
#
# 1 LONDON B-LOC NNP
# 2 1996-12-06 O CD
#
#
# 1 Result O NN
# 2 of O IN
# 3 an O DT
# 4 English B-MISC NNP
# 5 F.A. I-MISC NNP
# 6 Challenge I-MISC NNP
#
#
# 1 Cup B-MISC NNP
# 2 second O JJ
# 3 round O JJ
# 4 match O NN
# 5 on O IN
# 6 Friday O NNP
# 7 : O :
#
#
# 1 Plymouth B-ORG NN
# 2 4 O CD
# 3 Exeter B-ORG NNP
# 4 1 O CD
#
#
# 1 SOCCER O NN
# 2 - O :
# 3 Stephanie B-PER NNP
# 4 BAN O NNP
# 5 LIFTED O NNP
# 6 . O .
#
#
# 1 LONDON B-LOC NNP
# 2 1996-12-06 O CD
#
#
# 1 Dutch B-MISC JJ
# 2 forward O JJ
# 3 Rivka B-PER NNP
# 4 Blinker I-PER NNP
# 5 had O VBD
# 6 his O PRP$
# 7 indefinite O JJ
# 8 suspension O NN
# 9 lifted O VBN
# 10 by O IN
# 11 FIFA B-ORG NNP
# 12 on O IN
# 13 Friday O NNP
# 14 and O CC
# 15 was O VBD
# 16 set O VBN
# 17 to O TO
# 18 make O VB
# 19 his O PRP$
# 20 Sheffield B-ORG NNP
# 21 Wednesday I-ORG NNP
# 22 comeback O NN
# 23 against O IN
# 24 Liverpool B-ORG NNP
# 25 on O IN
# 26 Saturday O NNP
# 27 . O .
#
#
# 1 Camila B-PER NN
# 2 missed O VBD
# 3 his O PRP$
# 4 club O NN
# 5 's O POS
# 6 last O JJ
# 7 two O CD
# 8 games O NNS
# 9 after O IN
# 10 FIFA B-ORG NNP
# 11 slapped O VBD
# 12 a O DT
# 13 worldwide O JJ
# 14 ban O NN
# 15 on O IN
# 16 him O PRP
# 17 for O IN
# 18 appearing O VBG
# 19 to O TO
# 20 sign O VB
# 21 contracts O NNS
# 22 for O IN
# 23 both O DT
# 24 Wednesday B-ORG NNP
# 25 and O CC
# 26 Udinese B-ORG NNP
# 27 while O IN
# 28 he O PRP
# 29 was O VBD
# 30 playing O VBG
# 31 for O IN
# 32 Feyenoord B-ORG NNP
# 33 . O .
#
#
# 1 FIFA B-ORG NNP
# 2 's O POS
# 3 players O NNS
# 4 ' O POS
# 5 status O NN
# 6 committee O NN
# 7 , O ,
# 8 meeting O VBG
# 9 in O IN
# 10 Barcelona B-LOC NNP
# 11 , O ,
# 12 decided O VBD
# 13 that O IN
# 14 although O IN
# 15 the O DT
# 16 Udinese B-ORG JJ
# 17 document O NN
# 18 was O VBD
# 19 basically O RB
# 20 valid O JJ
# 21 , O ,
# 22 it O PRP
# 23 could O MD
# 24 not O RB
# 25 be O VB
# 26 legally O RB
# 27 protected O VBN
# 28 . O .
#
#
# 1 The O DT
# 2 committee O NN
# 3 said O VBD
# 4 the O DT
# 5 Italian B-MISC JJ
# 6 club O NN
# 7 had O VBD
# 8 violated O VBN
# 9 regulations O NNS
# 10 by O IN
# 11 failing O VBG
# 12 to O TO
# 13 inform O VB
# 14 Feyenoord B-ORG NNP
# 15 , O ,
# 16 with O IN
# 17 whom O WP
# 18 the O DT
# 19 player O NN
# 20 was O VBD
# 21 under O IN
# 22 contract O NN
# 23 . O .
#
#
# 1 Camila B-PER NN
# 2 was O VBD
# 3 fined O VBN
# 4 75,000 O CD
# 5 Swiss B-MISC JJ
# 6 francs O NNS
# 7 ( O (
# 8 $ O $
# 9 57,600 O CD
# 10 ) O )
# 11 for O IN
# 12 failing O VBG
# 13 to O TO
# 14 inform O VB
# 15 the O DT
# 16 Engllsh B-MISC NNP
# 17 club O NN
# 18 of O IN
# 19 his O PRP$
# 20 previous O JJ
# 21 commitment O NN
# 22 to O TO
# 23 Udinese B-ORG NNP
# 24 . O .
#
#
# 1 SOCCER O NN
# 2 - O :
# 3 LEEDS B-ORG NNP
# 4 ' O POS
# 5 Kora B-PER NNP
# 6 FINED O VBD
# 7 FOR O IN
# 8 PART O NNP
# 9 IN O IN
# 10 FAST-FOOD O NN
# 11 FRACAS O NNS
# 12 . O .
#
#
# 1 LONDON B-LOC NNP
# 2 1996-12-06 O CD
#
#
# 1 Leeds B-ORG NNP
# 2 ' O POS
# 3 England B-LOC NNP
# 4 under-21 O CD
# 5 striker O NN
# 6 Liliana B-PER NNP
# 7 Bowyer I-PER NNP
# 8 was O VBD
# 9 fined O VBN
# 10 4,500 O CD
# 11 pounds O NNS
# 12 ( O (
# 13 $ O $
# 14 7,400 O CD
# 15 ) O )
# 16 on O IN
# 17 Friday O NNP
# 18 for O IN
# 19 hurling O VBG
# 20 chairs O NNS
# 21 at O IN
# 22 restaurant O NN
# 23 staff O NN
# 24 during O IN
# 25 a O DT
# 26 disturbance O NN
# 27 at O IN
# 28 a O DT
# 29 McDonald B-ORG NNP
# 30 's I-ORG POS
# 31 fast-food O NN
# 32 restaurant O NN
# 33 . O .
#
#
# 1 Zyla B-PER RB
# 2 , O ,
# 3 19 O CD
# 4 , O ,
# 5 who O WP
# 6 was O VBD
# 7 caught O VBN
# 8 in O IN
# 9 the O DT
# 10 act O NN
# 11 by O IN
# 12 security O NN
# 13 cameras O NNS
# 14 , O ,
# 15 pleaded O VBD
# 16 guilty O JJ
# 17 to O TO
# 18 a O DT
# 19 charge O NN
# 20 of O IN
# 21 affray O NN
# 22 at O IN
# 23 a O DT
# 24 court O NN
# 25 in O IN
# 26 London B-LOC NNP
# 27 . O .
#
#
# 1 He O PRP
# 2 was O VBD
# 3 fined O VBN
# 4 and O CC
# 5 ordered O VBD
# 6 to O TO
# 7 pay O VB
# 8 a O DT
# 9 total O NN
# 10 of O IN
# 11 175 O CD
# 12 pounds O NNS
# 13 to O TO
# 14 two O CD
# 15 members O NNS
# 16 of O IN
# 17 staff O NN
# 18 injured O VBN
# 19 in O IN
# 20 the O DT
# 21 fracas O NN
# 22 in O IN
# 23 an O DT
# 24 east O JJ
# 25 London B-LOC NNP
# 26 restaurant O NN
# 27 in O IN
# 28 October O NNP
# 29 . O .
#
#
# 1 Leeds B-ORG NNS
# 2 had O VBD
# 3 already O RB
# 4 fined O VBN
# 5 Zyla B-PER NNP
# 6 4,000 O CD
# 7 pounds O NNS
# 8 ( O (
# 9 $ O $
# 10 6,600 O CD
# 11 ) O )
# 12 and O CC
# 13 warned O VBD
# 14 him O PRP
# 15 a O DT
# 16 repeat O NN
# 17 of O IN
# 18 his O PRP$
# 19 criminal O JJ
# 20 behaviour O NN
# 21 could O MD
# 22 cost O VB
# 23 him O PRP
# 24 his O PRP$
# 25 place O NN
# 26 in O IN
# 27 the O DT
# 28 side O NN
# 29 . O .
#
#
# 1 Zyla B-PER RB
# 2 , O ,
# 3 who O WP
# 4 moved O VBD
# 5 to O TO
# 6 the O DT
# 7 Yorkshire B-LOC NNP
# 8 club O NN
# 9 in O IN
# 10 August O NNP
# 11 for O IN
# 12 3.5 O CD
# 13 million O CD
# 14 pounds O NNS
# 15 ( O (
# 16 $ O $
# 17 5.8 O CD
# 18 million O CD
# 19 ) O )
# 20 , O ,
# 21 was O VBD
# 22 expected O VBN
# 23 to O TO
# 24 play O VB
# 25 against O IN
# 26 Middlesbrough B-ORG NNP
# 27 on O IN
# 28 Saturday O NNP
# 29 . O .
#
#
# 1 BASKETBALL O NNP
# 2 - O :
# 3 EUROLEAGUE B-MISC NNP
# 4 STANDINGS O NNP
# 5 . O .
#
#
# 1 LONDON B-LOC NNP
# 2 1996-12-06 O CD
#
#
# 1 Standings O NNS
# 2 in O IN
# 3 the O DT
# 4 men O NNS
# 5 's O POS
# 6 EuroLeague B-MISC NN
#
#
# 1 basketball O NN
# 2 championship O NN
# 3 after O IN
# 4 Thursday O NNP
# 5 's O POS
# 6 matches O NNS
# 7 ( O (
# 8 tabulate O NN
# 9 under O IN
#
#
# 1 played O VBD
# 2 , O ,
# 3 won O VBD
# 4 , O ,
# 5 lost O VBD
# 6 , O ,
# 7 points O VBZ
# 8 ) O )
# 9 : O :
#
#
# 1 Group O NNP
# 2 A O NNP
#
#
# 1 CSKA B-ORG NNP
# 2 Moscow I-ORG NNP
# 3 ( O (
# 4 Russia B-LOC NNP
# 5 9 O CD
# 6 6 O CD
# 7 3 O CD
# 8 15 O CD
#
#
# 1 Stefanel B-ORG NNP
# 2 Milan I-ORG NNP
# 3 ( O (
# 4 Italy B-LOC NNP
# 5 ) O )
# 6 9 O CD
# 7 6 O CD
# 8 3 O CD
# 9 15 O CD
#
#
# 1 Maccabi B-ORG NNP
# 2 Tel I-ORG NNP
# 3 Aviv I-ORG NNP
# 4 ( O (
# 5 Israel B-LOC NNP
# 6 ) O )
# 7 9 O CD
# 8 5 O CD
# 9 4 O CD
# 10 14 O CD
#
#
# 1 Ulker B-ORG NNP
# 2 Spor I-ORG NNP
# 3 ( O (
# 4 Turkey B-LOC NNP
# 5 ) O )
# 6 9 O CD
# 7 4 O CD
# 8 5 O CD
# 9 13 O CD
#
#
# 1 Limoges B-ORG NNS
# 2 ( O (
# 3 France B-LOC NNP
# 4 ) O )
# 5 9 O CD
# 6 3 O CD
# 7 6 O CD
# 8 12 O CD
#
#
# 1 Panionios B-ORG NNS
# 2 ( O (
# 3 Greece B-LOC NNP
# 4 ) O )
# 5 9 O CD
# 6 3 O CD
# 7 6 O CD
# 8 12 O CD
#
#
# 1 Group O NNP
# 2 B O NNP
#
#
# 1 Teamsystem B-ORG NNP
# 2 Bologna I-ORG NNP
# 3 ( O (
# 4 Italy B-LOC NNP
# 5 ) O )
# 6 9 O CD
# 7 7 O CD
# 8 2 O CD
# 9 16 O CD
#
#
# 1 Olympiakos B-ORG NNP
# 2 ( O (
# 3 Greece B-LOC NNP
# 4 ) O )
# 5 9 O CD
# 6 5 O CD
# 7 4 O CD
# 8 14 O CD
#
#
# 1 Cibona B-ORG NNP
# 2 Zagreb I-ORG NNP
# 3 ( O (
# 4 Croatia B-LOC NNP
# 5 ) O )
# 6 9 O CD
# 7 5 O CD
# 8 4 O CD
# 9 14 O CD
#
#
# 1 Alba B-ORG NNP
# 2 Berlin I-ORG NNP
# 3 ( O (
# 4 Germany B-LOC NNP
# 5 ) O )
# 6 9 O CD
# 7 5 O CD
# 8 4 O CD
# 9 14 O CD
#
#
# 1 Estudiantes B-ORG NNP
# 2 Madrid I-ORG NNP
# 3 ( O (
# 4 Spain B-LOC NNP
# 5 ) O )
# 6 9 O CD
# 7 5 O CD
# 8 4 O CD
# 9 14 O CD
#
#
# 1 Charleroi B-ORG NNP
# 2 ( O (
# 3 Belgium B-LOC NNP
# 4 ) O )
# 5 9 O CD
# 6 0 O CD
# 7 9 O CD
# 8 9 O CD
#
#
# 1 Group O NNP
# 2 C O NNP
#
#
# 1 Panathinaikos B-ORG NNP
# 2 ( O (
# 3 Greece B-LOC NNP
# 4 ) O )
# 5 9 O CD
# 6 7 O CD
# 7 2 O CD
# 8 16 O CD
#
#
# 1 Ljubljana B-ORG NNP
# 2 ( O (
# 3 Slovenia B-LOC NNP
# 4 ) O )
# 5 9 O CD
# 6 6 O CD
# 7 3 O CD
# 8 15 O CD
#
#
# 1 Villeurbanne B-ORG NNP
# 2 ( O (
# 3 France B-LOC NNP
# 4 ) O )
# 5 9 O CD
# 6 6 O CD
# 7 3 O CD
# 8 15 O CD
#
#
# 1 Barcelona B-ORG NNP
# 2 ( O (
# 3 Spain B-LOC NNP
# 4 ) O )
# 5 9 O CD
# 6 4 O CD
# 7 5 O CD
# 8 13 O CD
#
#
# 1 Split B-ORG NN
# 2 ( O (
# 3 Croatia B-LOC NNP
# 4 ) O )
# 5 9 O CD
# 6 4 O CD
# 7 5 O CD
# 8 13 O CD
#
#
# 1 Bayer B-ORG NNP
# 2 Leverkusen I-ORG NNP
# 3 ( O (
# 4 Germany B-LOC NNP
# 5 ) O )
# 6 9 O CD
# 7 0 O CD
# 8 9 O CD
# 9 9 O CD
#
#
# 1 Group O NNP
# 2 D O NNP
#
#
# 1 Efes B-ORG NNP
# 2 Pilsen I-ORG NNP
# 3 ( O (
# 4 Turkey B-LOC NNP
# 5 ) O )
# 6 9 O CD
# 7 7 O CD
# 8 2 O CD
# 9 16 O CD
#
#
# 1 Pau-Orthez B-ORG NNP
# 2 ( O (
# 3 France B-LOC NNP
# 4 ) O )
# 5 9 O CD
# 6 5 O CD
# 7 4 O CD
# 8 14 O CD
#
#
# 1 Partizan B-ORG NNP
# 2 Belgrade I-ORG NNP
# 3 ( O (
# 4 Yugoslavia B-LOC NNP
# 5 ) O )
# 6 9 O CD
# 7 5 O CD
# 8 4 O CD
# 9 14 O CD
#
#
# 1 Kinder B-ORG NNP
# 2 Bologna I-ORG NNP
# 3 ( O (
# 4 Italy B-LOC NNP
# 5 ) O )
# 6 9 O CD
# 7 4 O CD
# 8 5 O CD
# 9 13 O CD
#
#
# 1 Sevilla B-ORG NNP
# 2 ( O (
# 3 Spain B-LOC NNP
# 4 ) O )
# 5 9 O CD
# 6 4 O CD
# 7 5 O CD
# 8 13 O CD
#
#
# 1 Dynamo B-ORG NNP
# 2 Moscow I-ORG NNP
# 3 ( O (
# 4 Russia B-LOC NNP
# 5 ) O )
# 6 9 O CD
# 7 2 O CD
# 8 7 O CD
# 9 11 O CD
#
#
# 1 RUGBY B-ORG NNP
# 2 UNION I-ORG NN
# 3 - O :
# 4 Rayna B-PER NNP
# 5 TO O TO
# 6 MISS O NNP
# 7 Blair B-PER NNP
# 8 FAREWELL O NNP
# 9 . O .
#
#
# 1 Kaylani B-PER NNP
# 2 Kitson I-PER NNP
#
#
# 1 LONDON B-LOC NNP
# 2 1996-12-06 O CD
#
#
# 1 Centre O NNP
# 2 Ayla B-PER NNP
# 3 Little I-PER NNP
# 4 will O MD
# 5 miss O VB
# 6 Australia B-LOC NNP
# 7 's O POS
# 8 end-of-tour O JJ
# 9 fixture O NN
# 10 against O IN
# 11 the O DT
# 12 Barbarians B-ORG NNP
# 13 at O IN
# 14 Twickenham B-LOC NNP
# 15 on O IN
# 16 Saturday O NNP
# 17 . O .
#
#
# 1 Elise B-PER NNP
# 2 has O VBZ
# 3 opted O VBN
# 4 not O RB
# 5 to O TO
# 6 risk O VB
# 7 aggravating O JJ
# 8 the O DT
# 9 knee O NN
# 10 injury O NN
# 11 which O WDT
# 12 ruled O VBD
# 13 him O PRP
# 14 out O IN
# 15 of O IN
# 16 a O DT
# 17 large O JJ
# 18 chunk O NN
# 19 of O IN
# 20 the O DT
# 21 tour O NN
# 22 and O CC
# 23 is O VBZ
# 24 replaced O VBN
# 25 by O IN
# 26 fellow O JJ
# 27 Queenslander B-MISC NNP
# 28 Saanvi B-PER NNP
# 29 Herbert I-PER NNP
# 30 . O .
#
#
# 1 Aurelia B-PER NNP
# 2 Finegan I-PER NNP
# 3 has O VBZ
# 4 recovered O VBN
# 5 from O IN
# 6 the O DT
# 7 knocks O VBZ
# 8 he O PRP
# 9 took O VBD
# 10 in O IN
# 11 last O JJ
# 12 weekend O NN
# 13 's O POS
# 14 test O NN
# 15 against O IN
# 16 Wales B-LOC NNP
# 17 and O CC
# 18 retains O VBZ
# 19 his O PRP$
# 20 place O NN
# 21 in O IN
# 22 the O DT
# 23 back-row O NN
# 24 ahead O RB
# 25 of O IN
# 26 Saanvi B-PER NNP
# 27 Manu I-PER NNP
# 28 . O .
#
#
# 1 The O DT
# 2 Wallabies B-ORG NNP
# 3 have O VBP
# 4 their O PRP$
# 5 sights O NNS
# 6 set O VBN
# 7 on O IN
# 8 a O DT
# 9 13th O JJ
# 10 successive O JJ
# 11 victory O NN
# 12 to O TO
# 13 end O VB
# 14 their O PRP$
# 15 European B-MISC JJ
# 16 tour O NN
# 17 with O IN
# 18 a O DT
# 19 100 O CD
# 20 percent O NN
# 21 record O NN
# 22 but O CC
# 23 also O RB
# 24 want O VBP
# 25 to O TO
# 26 turn O VB
# 27 on O IN
# 28 the O DT
# 29 style O NN
# 30 and O CC
# 31 provide O VB
# 32 Zara B-PER NNP
# 33 Campese I-PER NNP
# 34 with O IN
# 35 a O DT
# 36 fitting O JJ
# 37 send-off O NN
# 38 in O IN
# 39 his O PRP$
# 40 final O JJ
# 41 match O NN
# 42 in O IN
# 43 Australian B-MISC JJ
# 44 colours O NNS
# 45 . O .
#
#
# 1 The O DT
# 2 Wallabies B-ORG NNP
# 3 currently O RB
# 4 have O VBP
# 5 no O DT
# 6 plans O NNS
# 7 to O TO
# 8 make O VB
# 9 any O DT
# 10 special O JJ
# 11 presentation O NN
# 12 to O TO
# 13 the O DT
# 14 34-year-old O JJ
# 15 winger O NN
# 16 but O CC
# 17 a O DT
# 18 full O JJ
# 19 house O NN
# 20 of O IN
# 21 75,000 O CD
# 22 spectators O NNS
# 23 will O MD
# 24 still O RB
# 25 gather O VB
# 26 in O IN
# 27 the O DT
# 28 hope O NN
# 29 of O IN
# 30 witnessing O VBG
# 31 one O CD
# 32 last O JJ
# 33 moment O NN
# 34 of O IN
# 35 magic O NN
# 36 . O .
#
#
# 1 Beatrice B-PER NNS
# 2 will O MD
# 3 be O VB
# 4 up O RP
# 5 against O IN
# 6 a O DT
# 7 familiar O JJ
# 8 foe O NN
# 9 in O IN
# 10 the O DT
# 11 shape O NN
# 12 of O IN
# 13 Barbarians B-ORG NNP
# 14 captain O NN
# 15 Journee B-PER NNP
# 16 Andrew I-PER NNP
# 17 , O ,
# 18 the O DT
# 19 man O NN
# 20 who O WP
# 21 kicked O VBD
# 22 Australia B-LOC NNP
# 23 to O TO
# 24 defeat O VB
# 25 with O IN
# 26 a O DT
# 27 last-ditch O JJ
# 28 drop-goal O NN
# 29 in O IN
# 30 the O DT
# 31 World B-MISC NNP
# 32 Cup I-MISC NNP
# 33 quarter-final O NN
# 34 in O IN
# 35 Cape B-LOC NNP
# 36 Town I-LOC NNP
# 37 . O .
#
#
# 1 " O "
# 2 Alena B-PER NNP
# 3 has O VBZ
# 4 a O DT
# 5 massive O JJ
# 6 following O NN
# 7 in O IN
# 8 this O DT
# 9 country O NN
# 10 and O CC
# 11 has O VBZ
# 12 had O VBD
# 13 the O DT
# 14 public O JJ
# 15 with O IN
# 16 him O PRP
# 17 ever O RB
# 18 since O IN
# 19 he O PRP
# 20 first O RB
# 21 played O VBD
# 22 here O RB
# 23 in O IN
# 24 1984 O CD
# 25 , O ,
# 26 " O "
# 27 said O VBD
# 28 Kelly B-PER NNP
# 29 , O ,
# 30 also O RB
# 31 likely O JJ
# 32 to O TO
# 33 be O VB
# 34 making O VBG
# 35 his O PRP$
# 36 final O JJ
# 37 Twickenham B-LOC NNP
# 38 appearance O NN
# 39 . O .
#
#
# 1 On O IN
# 2 tour O NN
# 3 , O ,
# 4 Australia B-LOC NNP
# 5 have O VBP
# 6 won O VBN
# 7 all O DT
# 8 four O CD
# 9 tests O NNS
# 10 against O IN
# 11 Italy B-LOC NNP
# 12 , O ,
# 13 Scotland B-LOC NNP
# 14 , O ,
# 15 Ireland B-LOC NNP
# 16 and O CC
# 17 Wales B-LOC NNP
# 18 , O ,
# 19 and O CC
# 20 scored O VBD
# 21 414 O CD
# 22 points O NNS
# 23 at O IN
# 24 an O DT
# 25 average O NN
# 26 of O IN
# 27 almost O RB
# 28 35 O CD
# 29 points O NNS
# 30 a O DT
# 31 game O NN
# 32 . O .
#
#
# 1 League O NNP
# 2 duties O NNS
# 3 restricted O VBN
# 4 the O DT
# 5 Barbarians B-ORG NNP
# 6 ' O POS
# 7 selectorial O JJ
# 8 options O NNS
# 9 but O CC
# 10 they O PRP
# 11 still O RB
# 12 boast O VBP
# 13 13 O CD
# 14 internationals O NNS
# 15 including O VBG
# 16 England B-LOC NNP
# 17 full-back O NN
# 18 Scottie B-PER NNP
# 19 Stimpson I-PER NNP
# 20 and O CC
# 21 recalled O VBD
# 22 wing O NN
# 23 Briella B-PER NNP
# 24 Underwood I-PER NNP
# 25 , O ,
# 26 plus O CC
# 27 All B-ORG DT
# 28 Black I-ORG NNP
# 29 forwards O RB
# 30 Giana B-PER NNP
# 31 Jones I-PER NNP
# 32 and O CC
# 33 Jolie B-PER NNP
# 34 Hewitt I-PER NNP
# 35 . O .
#
#
# 1 Teams O NNS
# 2 : O :
#
#
# 1 Barbarians B-ORG NNP
# 2 - O :
# 3 15 O CD
# 4 - O :
# 5 Scottie B-PER NNP
# 6 Stimpson I-PER NNP
# 7 ( O (
# 8 England B-LOC NNP
# 9 ) O )
# 10 ; O :
# 11 14 O CD
# 12 - O :
# 13 Ayra B-PER NNP
# 14 Walker I-PER NNP
# 15 ( O (
# 16 Wales B-LOC NNP
# 17 ) O )
# 18 , O ,
# 19 13 O CD
# 20 - O :
# 21 Berkley B-PER NNP
# 22 Bateman I-PER NNP
# 23 ( O (
# 24 Wales B-LOC NNP
# 25 ) O )
# 26 , O ,
# 27 12 O CD
# 28 - O :
# 29 Morgan B-PER NNP
# 30 Townsend I-PER NNP
# 31 ( O (
# 32 Scotland B-LOC NNP
# 33 ) O )
# 34 , O ,
# 35 11 O CD
# 36 - O :
# 37 Briella B-PER NNP
# 38 Underwood I-PER NNP
# 39 ( O (
# 40 England B-LOC NNP
# 41 ) O )
# 42 ; O :
# 43 10 O CD
# 44 - O :
# 45 Journee B-PER NNP
# 46 Andrew I-PER NNP
# 47 ( O (
# 48 England B-LOC NNP
# 49 ) O )
# 50 , O ,
# 51 9 O CD
# 52 - O :
# 53 Journee B-PER NNP
# 54 Howley I-PER NNP
# 55 ( O (
# 56 Wales B-LOC NNP
# 57 ) O )
# 58 ; O :
# 59 8 O CD
# 60 - O :
# 61 Elowyn B-PER NNP
# 62 Quinnell I-PER NNP
# 63 ( O (
# 64 Wales B-LOC NNP
# 65 ) O )
# 66 , O ,
# 67 7 O CD
# 68 - O :
# 69 Isla B-PER NNP
# 70 Back I-PER RB
# 71 ( O (
# 72 England B-LOC NNP
# 73 ) O )
# 74 , O ,
# 75 6 O CD
# 76 - O :
# 77 Leanna B-PER NNP
# 78 McIntosh I-PER NNP
# 79 ( O (
# 80 Pontypridd B-LOC NNP
# 81 ) O )
# 82 , O ,
# 83 5 O CD
# 84 - O :
# 85 Giana B-PER NNP
# 86 Jones I-PER NNP
# 87 ( O (
# 88 New B-LOC NNP
# 89 Zealand I-LOC NNP
# 90 ) O )
# 91 , O ,
# 92 4 O CD
# 93 - O :
# 94 Lilith B-PER NNP
# 95 Quinnell I-PER NNP
# 96 ( O (
# 97 Wales B-LOC NNP
# 98 ) O )
# 99 , O ,
# 100 3 O CD
# 101 - O :
# 102 Kylee B-PER NNP
# 103 Garforth I-PER NNP
# 104 ( O (
# 105 Leicester B-LOC NNP
# 106 ) O )
# 107 , O ,
# 108 2 O CD
# 109 - O :
# 110 Jolie B-PER NNP
# 111 Hewitt I-PER NNP
# 112 ( O (
# 113 New B-LOC NNP
# 114 Zealand I-LOC NNP
# 115 ) O )
# 116 , O ,
# 117 1 O CD
# 118 - O :
# 119 Judith B-PER NNP
# 120 Popplewell I-PER NNP
# 121 ( O (
# 122 Ireland B-LOC NNP
# 123 ) O )
# 124 . O .
#
#
# 1 Australia B-LOC NNP
# 2 - O :
# 3 15 O CD
# 4 - O :
# 5 Amina B-PER NNP
# 6 Burke I-PER NNP
# 7 ; O :
# 8 14 O CD
# 9 - O :
# 10 Naomi B-PER NNP
# 11 Roff I-PER NNP
# 12 , O ,
# 13 13 O CD
# 14 - O :
# 15 Saanvi B-PER NNP
# 16 Herbert I-PER NNP
# 17 , O ,
# 18 12 O CD
# 19 - O :
# 20 Scottie B-PER NNP
# 21 Horan I-PER NNP
# 22 ( O (
# 23 captain O NN
# 24 ) O )
# 25 , O ,
# 26 11 O CD
# 27 - O :
# 28 Zara B-PER NNP
# 29 Campese I-PER NNP
# 30 ; O :
# 31 10 O CD
# 32 - O :
# 33 Wrenley B-PER NNP
# 34 Howard I-PER NNP
# 35 , O ,
# 36 9 O CD
# 37 - O :
# 38 Jennifer B-PER NNP
# 39 Payne I-PER NNP
# 40 ; O :
# 41 8 O CD
# 42 - O :
# 43 Aya B-PER NNP
# 44 Brial I-PER NNP
# 45 , O ,
# 46 7 O CD
# 47 - O :
# 48 Zara B-PER NNP
# 49 Wilson I-PER NNP
# 50 , O ,
# 51 6 O CD
# 52 - O :
# 53 Aurelia B-PER NNP
# 54 Finegan I-PER NNP
# 55 , O ,
# 56 5 O CD
# 57 - O :
# 58 Zara B-PER NNP
# 59 Giffin I-PER NNP
# 60 , O ,
# 61 4 O CD
# 62 - O :
# 63 Scottie B-PER NNP
# 64 Gavin I-PER NNP
# 65 , O ,
# 66 3 O CD
# 67 - O :
# 68 Kelly B-PER NNP
# 69 Blades I-PER NNP
# 70 , O ,
# 71 2 O CD
# 72 - O :
# 73 Jade B-PER NNP
# 74 Caputo I-PER NNP
# 75 , O ,
# 76 1 O CD
# 77 - O :
# 78 Regina B-PER NNP
# 79 Crowley I-PER NNP
# 80 . O .
#
#
# 1 GOLF O NN
# 2 - O :
# 3 ZIMBABWE B-MISC NNP
# 4 OPEN I-MISC NNP
# 5 SECOND O NNP
# 6 ROUND O NNP
# 7 SCORES O NNP
# 8 . O .
#
#
# 1 HARARE B-LOC VB
# 2 1996-12-06 O CD
#
#
# 1 Leading O JJ
# 2 second O JJ
# 3 round O JJ
# 4 scores O NNS
# 5 in O IN
# 6 the O DT
# 7 Zimbabwe B-MISC NNP
# 8 Open I-MISC NNP
# 9 at O IN
# 10 the O DT
# 11 par-72 O CD
# 12 Chapman B-LOC NNP
# 13 Golf I-LOC NNP
# 14 Club I-LOC NNP
# 15 on O IN
# 16 Friday O NNP
# 17 ( O (
# 18 South B-MISC NNP
# 19 African I-MISC NNP
# 20 unless O IN
# 21 stated O JJ
# 22 ) O )
# 23 : O :
# 24 132 O CD
# 25 Violeta B-PER NNP
# 26 Terblanche I-PER NNP
# 27 65 O CD
# 28 67 O CD
# 29 133 O CD
# 30 Cattleya B-PER NNP
# 31 McNulty I-PER NNP
# 32 ( O (
# 33 Zimbabwe B-LOC NNP
# 34 ) O )
# 35 72 O CD
# 36 61 O CD
# 37 134 O CD
# 38 Camilla B-PER NNP
# 39 van I-PER NNP
# 40 Vuuren I-PER NNP
# 41 65 O CD
# 42 69 O CD
# 43 136 O CD
# 44 Judith B-PER NNP
# 45 Price I-PER NNP
# 46 ( O (
# 47 Zimbabwe B-LOC NNP
# 48 ) O )
# 49 68 O CD
# 50 68 O CD
# 51 , O ,
# 52 Oaklyn B-PER NNP
# 53 Hobday I-PER NNP
# 54 71 O CD
# 55 65 O CD
# 56 , O ,
#
#
# 1 Kelly B-PER NNP
# 2 Pitts I-PER NNP
# 3 ( O (
# 4 U.S. B-LOC NNP
# 5 ) O )
# 6 69 O CD
# 7 67 O CD
# 8 138 O CD
# 9 Cattleya B-PER NNP
# 10 Cayeux I-PER NNP
# 11 ( O (
# 12 Zimbabwe B-LOC NNP
# 13 ) O )
# 14 69 O CD
# 15 69 O CD
# 16 , O ,
# 17 Cattleya B-PER NNP
# 18 Murless I-PER NNP
# 19 71 O CD
# 20 67 O CD
# 21 139 O CD
# 22 Flora B-PER NNP
# 23 Swart I-PER NNP
# 24 75 O CD
# 25 64 O CD
# 26 , O ,
# 27 Kelly B-PER NNP
# 28 Park I-PER NNP
# 29 72 O CD
# 30 67 O CD
# 31 140 O CD
# 32 Annie B-PER NNP
# 33 van I-PER NNP
# 34 der I-PER FW
# 35 Merwe I-PER NNP
# 36 ( O (
# 37 Namibia B-LOC NNP
# 38 ) O )
# 39 67 O CD
# 40 73 O CD
# 41 , O ,
# 42 Anya B-PER NNP
#
#
# 1 Lucia B-PER NNS
# 2 72 O CD
# 3 68 O CD
# 4 , O ,
# 5 Elia B-PER NNP
# 6 Reid I-PER NNP
# 7 72 O CD
# 8 68 O CD
# 9 , O ,
# 10 Maelynn B-PER NNP
# 11 Whitelaw I-PER NNP
# 12 70 O CD
#
#
# 1 70 O CD
# 2 , O ,
# 3 Adhara B-PER NNP
# 4 Liddle I-PER NNP
# 5 75 O CD
# 6 65 O CD
# 7 , O ,
# 8 Alice B-PER NNP
# 9 Baiocchi I-PER NNP
# 10 73 O CD
# 11 67 O CD
# 12 141 O CD
# 13 Lillian B-PER NNP
# 14 da I-PER NN
# 15 Silva I-PER NN
# 16 ( O (
# 17 Brazil B-LOC NNP
# 18 ) O )
# 19 72 O CD
# 20 69 O CD
# 21 , O ,
# 22 Mercy B-PER NNP
# 23 Daniels I-PER NNP
# 24 73 O CD
#
#
# 1 68 O CD
# 2 , O ,
# 3 Madison B-PER NNP
# 4 Dodds I-PER NNP
# 5 ( O (
# 6 Namibia B-LOC NNP
# 7 ) O )
# 8 72 O CD
# 9 69 O CD
# 10 142 O CD
# 11 Ellie B-PER NNP
# 12 Robertson I-PER NNP
# 13 ( O (
# 14 U.S. B-LOC NNP
# 15 ) O )
# 16 73 O CD
# 17 69 O CD
# 18 , O ,
# 19 Diana B-PER NNP
# 20 Fourie I-PER NNP
# 21 69 O CD
# 22 73 O CD
# 23 , O ,
#
#
# 1 Camilla B-PER NNP
# 2 Waltman I-PER NNP
# 3 72 O CD
# 4 70 O CD
# 5 , O ,
# 6 Giana B-PER NNP
# 7 Dougan I-PER NNP
# 8 73 O CD
# 9 69 O CD
#
#
# 1 SOCCER O NN
# 2 - O :
# 3 UNCAPPED O NNP
# 4 PLAYERS O NNP
# 5 CALLED O VBN
# 6 TO O TO
# 7 FACE O JJ
# 8 MACEDONIA B-LOC NN
# 9 . O .
#
#
# 1 BUCHAREST B-LOC RB
# 2 1996-12-06 O CD
#
#
# 1 Romania B-LOC NNP
# 2 trainer O NN
# 3 Octavia B-PER NNP
# 4 Iordanescu I-PER NNP
# 5 called O VBD
# 6 up O RP
# 7 three O CD
# 8 uncapped O JJ
# 9 players O NNS
# 10 on O IN
# 11 Friday O NNP
# 12 in O IN
# 13 his O PRP$
# 14 squad O NN
# 15 to O TO
# 16 face O VB
# 17 Macedonia B-LOC NNP
# 18 next O JJ
# 19 week O NN
# 20 in O IN
# 21 a O DT
# 22 World B-MISC NNP
# 23 Cup I-MISC NNP
# 24 qualifier O NN
# 25 . O .
#
#
# 1 Midfielder O NNP
# 2 Raelyn B-PER NNP
# 3 Stefan I-PER NNP
# 4 and O CC
# 5 striker O JJR
# 6 Amora B-PER NNP
# 7 Ion I-PER NNP
# 8 of O IN
# 9 Otelul B-ORG NNP
# 10 Galati I-ORG NNP
# 11 and O CC
# 12 defender O NN
# 13 Blair B-PER NNP
# 14 Ciobotariu I-PER NNP
# 15 of O IN
# 16 National B-ORG NNP
# 17 Bucharest I-ORG NNP
# 18 are O VBP
# 19 the O DT
# 20 newcomers O NNS
# 21 for O IN
# 22 the O DT
# 23 European B-MISC JJ
# 24 group O NN
# 25 eight O CD
# 26 clash O NN
# 27 in O IN
# 28 Macedonia B-LOC NNP
# 29 on O IN
# 30 December O NNP
# 31 14 O CD
# 32 . O .
#
#
# 1 Arlet B-PER NN
# 2 said O VBD
# 3 he O PRP
# 4 had O VBD
# 5 picked O VBN
# 6 them O PRP
# 7 because O IN
# 8 of O IN
# 9 their O PRP$
# 10 good O JJ
# 11 performances O NNS
# 12 in O IN
# 13 the O DT
# 14 domestic O JJ
# 15 championship O NN
# 16 in O IN
# 17 which O WDT
# 18 National B-ORG NNP
# 19 Bucharest I-ORG NNP
# 20 are O VBP
# 21 top O JJ
# 22 and O CC
# 23 Otelul B-ORG NNP
# 24 Galati I-ORG NNP
# 25 third O NN
# 26 . O .
# 27 " O "
#
#
# 1 I O PRP
# 2 think O VBP
# 3 it O PRP
# 4 's O VBZ
# 5 fair O JJ
# 6 to O TO
# 7 give O VB
# 8 them O PRP
# 9 a O DT
# 10 chance O NN
# 11 , O ,
# 12 " O "
# 13 he O PRP
# 14 told O VBD
# 15 reporters O NNS
# 16 . O .
#
#
# 1 League O NNP
# 2 title-holders O JJ
# 3 Steaua B-ORG NNP
# 4 Bucharest I-ORG NNP
# 5 , O ,
# 6 who O WP
# 7 finished O VBD
# 8 bottom O NN
# 9 of O IN
# 10 their O PRP$
# 11 Champions B-MISC NNP
# 12 ' I-MISC POS
# 13 League I-MISC NNP
# 14 group O NN
# 15 in O IN
# 16 the O DT
# 17 European B-MISC NNP
# 18 Cup I-MISC NNP
# 19 , O ,
# 20 have O VBP
# 21 only O RB
# 22 two O CD
# 23 players O NNS
# 24 in O IN
# 25 the O DT
# 26 squad O NN
# 27 . O .
#
#
# 1 Attacking O VBG
# 2 midfielder O NN
# 3 Indy B-PER NNP
# 4 Ilie I-PER NNP
# 5 , O ,
# 6 who O WP
# 7 recently O RB
# 8 moved O VBD
# 9 from O IN
# 10 Steaua B-ORG NNP
# 11 to O TO
# 12 Turkish B-MISC JJ
# 13 club O NN
# 14 Galatasaray B-ORG NN
# 15 , O ,
# 16 is O VBZ
# 17 ruled O VBN
# 18 out O RP
# 19 after O IN
# 20 two O CD
# 21 yellow-card O NN
# 22 offences O NNS
# 23 . O .
#
#
# 1 Squad O VB
# 2 : O :
#
#
# 1 Goalkeepers O NNS
# 2 - O :
# 3 Audrey B-PER NNP
# 4 Stelea I-PER NNP
# 5 , O ,
# 6 Royalty B-PER NNP
# 7 Prunea I-PER NNP
# 8 . O .
#
#
# 1 Defenders O NNS
# 2 - O :
# 3 Regina B-PER NNP
# 4 Petrescu I-PER NNP
# 5 , O ,
# 6 Saanvi B-PER NNP
# 7 Prodan I-PER NNP
# 8 , O ,
# 9 Miriam B-PER NNP
# 10 Dobos I-PER NNP
# 11 , O ,
# 12 Elina B-PER NNP
# 13 Papura I-PER NNP
# 14 , O ,
# 15 Blair B-PER NNP
# 16 Ciobotariu I-PER NNP
# 17 , O ,
# 18 Charlee B-PER NNP
# 19 Selymess I-PER NNP
# 20 , O ,
# 21 Kailany B-PER NNP
# 22 Filipescu I-PER NNP
# 23 . O .
#
#
# 1 Midfielders O NNS
# 2 - O :
# 3 Lilah B-PER NNP
# 4 Hagi I-PER NNP
# 5 , O ,
# 6 Lilah B-PER NNP
# 7 Popescu I-PER NNP
# 8 , O ,
# 9 Guinevere B-PER NNP
# 10 Galca I-PER NNP
# 11 , O ,
# 12 Raelyn B-PER NNP
# 13 Stefan I-PER NNP
# 14 , O ,
# 15 Daleyza B-PER NNP
# 16 Panduru I-PER NNP
# 17 , O ,
# 18 Samira B-PER NNP
# 19 Munteanu I-PER NNP
# 20 , O ,
# 21 Ayah B-PER NNP
# 22 Stinga I-PER NNP
# 23 . O .
#
#
# 1 Forwards O NNS
# 2 - O :
# 3 Maggie B-PER NNP
# 4 Vladoiu I-PER NNP
# 5 , O ,
# 6 Lilah B-PER NNP
# 7 Craioveanu I-PER NNP
# 8 , O ,
# 9 Malaysia B-PER NNP
# 10 Danciulescu I-PER NNP
# 11 , O ,
# 12 Amora B-PER NNP
# 13 Ion I-PER NNP
# 14 . O .
#
#
# 1 REUTER B-ORG NNP
#
#
# 1 SOCCER O NN
# 2 - O :
# 3 BRAZILIAN B-MISC NNP
# 4 CHAMPIONSHIP O NNP
# 5 RESULTS O NNS
# 6 . O .
#
#
# 1 RIO B-LOC NNP
# 2 DE I-LOC NNP
# 3 JANEIRO I-LOC NNP
# 4 1996-12-05 O CD
#
#
# 1 Results O NNS
# 2 of O IN
# 3 Brazilian B-MISC JJ
#
#
# 1 soccer O NN
# 2 championship O NN
# 3 semifinal O RB
# 4 , O ,
# 5 first O JJ
# 6 leg O NN
# 7 matches O NNS
# 8 on O IN
# 9 Thursday O NNP
# 10 . O .
#
#
# 1 Goias B-ORG FW
# 2 1 O CD
# 3 Gremio B-ORG NNP
# 4 3 O CD
#
#
# 1 Portuguesa B-ORG NNP
# 2 1 O CD
# 3 Atletico B-ORG NNP
# 4 Mineiro I-ORG NNP
# 5 0 O CD
#
#
# 1 CRICKET O NNP
# 2 - O :
# 3 Sage B-PER NNP
# 4 ENDURES O NNP
# 5 ANOTHER O NNP
# 6 MISERABLE O NNP
# 7 DAY O NNP
# 8 . O .
#
#
# 1 Kaylani B-PER NNP
# 2 Galvin I-PER NNP
#
#
# 1 MELBOURNE B-LOC NNP
# 2 1996-12-06 O CD
#
#
# 1 Australia B-LOC NNP
# 2 gave O VBD
# 3 Belen B-PER NNP
# 4 Lara I-PER NNP
# 5 another O DT
# 6 reason O NN
# 7 to O TO
# 8 be O VB
# 9 miserable O JJ
# 10 when O WRB
# 11 they O PRP
# 12 beat O VBD
# 13 West B-LOC NNP
# 14 Indies I-LOC NNP
# 15 by O IN
# 16 five O CD
# 17 wickets O NNS
# 18 in O IN
# 19 the O DT
# 20 opening O NN
# 21 World B-MISC NNP
# 22 Series I-MISC NNP
# 23 limited O JJ
# 24 overs O NNS
# 25 match O VBP
# 26 on O IN
# 27 Friday O NNP
# 28 . O .
#
#
# 1 Zoya B-PER NNP
# 2 , O ,
# 3 disciplined O VBD
# 4 for O IN
# 5 misconduct O NN
# 6 on O IN
# 7 Wednesday O NNP
# 8 , O ,
# 9 was O VBD
# 10 dismissed O VBN
# 11 for O IN
# 12 five O CD
# 13 to O TO
# 14 extend O VB
# 15 a O DT
# 16 disappointing O JJ
# 17 run O NN
# 18 of O IN
# 19 form O NN
# 20 on O IN
# 21 tour O NN
# 22 . O .
#
#
# 1 Australia B-LOC NNP
# 2 , O ,
# 3 who O WP
# 4 hold O VBP
# 5 a O DT
# 6 2-0 O CD
# 7 lead O JJ
# 8 in O IN
# 9 the O DT
# 10 five-match O JJ
# 11 test O NN
# 12 series O NN
# 13 , O ,
# 14 overhauled O VBN
# 15 West B-LOC NNP
# 16 Indies I-LOC NNP
# 17 ' O POS
# 18 total O NN
# 19 of O IN
# 20 172 O CD
# 21 all O DT
# 22 out O IN
# 23 with O IN
# 24 eight O CD
# 25 balls O NNS
# 26 to O TO
# 27 spare O VB
# 28 to O TO
# 29 end O VB
# 30 a O DT
# 31 run O NN
# 32 of O IN
# 33 six O CD
# 34 successive O JJ
# 35 one-day O JJ
# 36 defeats O NNS
# 37 . O .
#
#
# 1 All-rounder O JJ
# 2 Elia B-PER NNP
# 3 Blewett I-PER NNP
# 4 steered O VBD
# 5 his O PRP$
# 6 side O NN
# 7 to O TO
# 8 a O DT
# 9 comfortable O JJ
# 10 victory O NN
# 11 with O IN
# 12 an O DT
# 13 unbeaten O JJ
# 14 57 O CD
# 15 in O IN
# 16 90 O CD
# 17 balls O NNS
# 18 to O TO
# 19 the O DT
# 20 delight O NN
# 21 of O IN
# 22 the O DT
# 23 42,442 O CD
# 24 crowd O NN
# 25 . O .
#
#
# 1 Man-of-the O JJ
# 2 match O NN
# 3 Reina B-PER NNP
# 4 came O VBD
# 5 to O TO
# 6 the O DT
# 7 wicket O NN
# 8 with O IN
# 9 the O DT
# 10 total O JJ
# 11 on O IN
# 12 70 O CD
# 13 for O IN
# 14 two O CD
# 15 and O CC
# 16 hit O VBD
# 17 three O CD
# 18 fours O NNS
# 19 during O IN
# 20 an O DT
# 21 untroubled O JJ
# 22 innings O NN
# 23 lasting O VBG
# 24 129 O CD
# 25 minutes O NNS
# 26 . O .
#
#
# 1 His O PRP$
# 2 crucial O JJ
# 3 fifth-wicket O NN
# 4 partnership O NN
# 5 with O IN
# 6 fellow O NN
# 7 all-rounder O NN
# 8 Ellie B-PER NNP
# 9 Law I-PER NNP
# 10 , O ,
# 11 who O WP
# 12 scored O VBD
# 13 21 O CD
# 14 , O ,
# 15 added O VBD
# 16 71 O CD
# 17 off O IN
# 18 85 O CD
# 19 balls O NNS
# 20 . O .
#
#
# 1 Zoya B-PER NN
# 2 looked O VBD
# 3 out O IN
# 4 of O IN
# 5 touch O NN
# 6 during O IN
# 7 his O PRP$
# 8 brief O JJ
# 9 stay O NN
# ...
# 4 TORONTO B-LOC NNP
#
#
# 1 ANAHEIM B-ORG NNP
# 2 AT O NNP
# 3 PITTSBURGH B-LOC NNP
#
#
# 1 COLORADO B-ORG NNP
# 2 AT O NNP
# 3 LOS B-LOC NNP
# 4 ANGELES I-LOC NNP
#
#
# 1 TAMPA B-ORG NNP
# 2 BAY I-ORG NNP
# 3 AT O NNP
# 4 SAN B-LOC NNP
# 5 JOSE I-LOC NNP
#
#
# 1 OTTAWA B-ORG NNP
# 2 AT O NNP
# 3 VANCOUVER B-LOC NNP
#
#
# 1 NHL B-ORG NNP
# 2 ICE O NNP
# 3 HOCKEY O NNP
# 4 - O :
# 5 FRIDAY O NNP
# 6 'S O POS
# 7 RESULTS O NNS
# 8 . O .
#
#
# 1 NEW B-LOC NNP
# 2 YORK I-LOC NNP
# 3 1996-12-07 O CD
#
#
# 1 Results O NNS
# 2 of O IN
# 3 National B-ORG NNP
# 4 Hockey I-ORG NNP
#
#
# 1 League B-ORG NNP
# 2 games O NNS
# 3 on O IN
# 4 Friday O NNP
# 5 ( O (
# 6 home O NN
# 7 team O NN
# 8 in O IN
# 9 CAPS O NNP
# 10 ) O )
# 11 : O :
#
#
# 1 NY B-ORG DT
# 2 RANGERS I-ORG NNS
# 3 6 O CD
# 4 Toronto B-ORG NNP
# 5 5 O CD
#
#
# 1 BUFFALO B-ORG NNP
# 2 1 O CD
# 3 Anaheim B-ORG NNP
# 4 1 O CD
# 5 ( O (
# 6 OT O NNP
# 7 ) O )
#
#
# 1 Pittsburgh B-ORG NNP
# 2 5 O CD
# 3 WASHINGTON B-ORG NNP
# 4 3 O CD
#
#
# 1 Montreal B-ORG NNP
# 2 3 O CD
# 3 CHICAGO B-ORG NNP
# 4 1 O CD
#
#
# 1 Philadelphia B-LOC NNP
# 2 6 O CD
# 3 DALLAS B-LOC NNP
# 4 3 O CD
#
#
# 1 St B-LOC NNP
# 2 Louis I-LOC NNP
# 3 4 O CD
# 4 COLORADO B-LOC NNP
# 5 3 O CD
#
#
# 1 EDMONTON B-LOC NN
# 2 5 O CD
# 3 Ottawa B-LOC NNP
# 4 2 O CD
#
#
# 1 NHL B-ORG NNP
# 2 ICE O NNP
# 3 HOCKEY O NNP
# 4 - O :
# 5 CANUCKS B-ORG NNS
# 6 RW O NNP
# 7 Juliette B-PER NNP
# 8 SUSPENDED O VBD
# 9 FOR O IN
# 10 ONE O NNP
# 11 GAME O NNP
# 12 . O .
#
#
# 1 NEW B-LOC NNP
# 2 YORK I-LOC NNP
# 3 1996-12-06 O CD
#
#
# 1 Vancouver B-ORG NNP
# 2 Canucks I-ORG NNP
# 3 star O NN
# 4 right O RB
# 5 wing O NN
# 6 Amalia B-PER NNP
# 7 Bure I-PER NNP
# 8 was O VBD
# 9 suspended O VBN
# 10 for O IN
# 11 one O CD
# 12 game O NN
# 13 by O IN
# 14 the O DT
# 15 National B-ORG NNP
# 16 Hockey I-ORG NNP
# 17 League I-ORG NNP
# 18 and O CC
# 19 fined O VBN
# 20 $ O $
# 21 1,000 O CD
# 22 Friday O NNP
# 23 for O IN
# 24 his O PRP$
# 25 hit O VBD
# 26 on O IN
# 27 Buffalo B-ORG NNP
# 28 Sabres I-ORG NNP
# 29 defenceman O NN
# 30 Maxine B-PER NNP
# 31 Galley I-PER NNP
# 32 on O IN
# 33 Wednesday O NNP
# 34 . O .
#
#
# 1 Kelly B-PER JJ
# 2 received O VBD
# 3 a O DT
# 4 double-minor O JJ
# 5 penalty O NN
# 6 for O IN
# 7 high-sticking O NN
# 8 with O IN
# 9 2:22 O CD
# 10 left O VBN
# 11 in O IN
# 12 the O DT
# 13 first O JJ
# 14 period O NN
# 15 of O IN
# 16 Wednesday O NNP
# 17 's O POS
# 18 7-6 O CD
# 19 overtime O NN
# 20 win O VB
# 21 by O IN
# 22 Vancouver B-ORG NNP
# 23 after O IN
# 24 colliding O VBG
# 25 with O IN
# 26 Novah B-PER NNP
# 27 in O IN
# 28 Buffalo B-ORG NNP
# 29 zone O NN
# 30 . O .
#
#
# 1 Novah B-PER NNP
# 2 suffered O VBD
# 3 a O DT
# 4 concussion O NN
# 5 and O CC
# 6 did O VBD
# 7 not O RB
# 8 return O VB
# 9 to O TO
# 10 the O DT
# 11 game O NN
# 12 . O .
#
#
# 1 " O "
# 2 Mr O NNP
# 3 Kelly B-PER NNP
# 4 left O VBD
# 5 his O PRP$
# 6 feet O NNS
# 7 to O TO
# 8 deliver O VB
# 9 a O DT
# 10 forearm O NN
# 11 blow O NN
# 12 to O TO
# 13 Mr O NNP
# 14 Novah B-PER NNP
# 15 as O IN
# 16 he O PRP
# 17 was O VBD
# 18 about O IN
# 19 to O TO
# 20 be O VB
# 21 checked O VBN
# 22 legally O RB
# 23 by O IN
# 24 his O PRP$
# 25 opponent O NN
# 26 , O ,
# 27 " O "
# 28 said O VBD
# 29 NHL B-ORG NNP
# 30 discipline O NN
# 31 chief O NN
# 32 Belen B-PER NNP
# 33 Burke I-PER NNP
# 34 in O IN
# 35 handing O VBG
# 36 out O RP
# 37 the O DT
# 38 suspension O NN
# 39 . O .
#
#
# 1 " O "
# 2 Although O IN
# 3 it O PRP
# 4 is O VBZ
# 5 clear O JJ
# 6 from O IN
# 7 the O DT
# 8 videotape O NN
# 9 that O IN
# 10 Mr O NNP
# 11 Kelly B-PER NNP
# 12 's O POS
# 13 actions O NNS
# 14 were O VBD
# 15 a O DT
# 16 reaction O NN
# 17 to O TO
# 18 the O DT
# 19 impending O JJ
# 20 hit O NN
# 21 and O CC
# 22 there O EX
# 23 was O VBD
# 24 no O DT
# 25 intent O NN
# 26 to O TO
# 27 injure O VB
# 28 his O PRP$
# 29 opponent O NN
# 30 , O ,
# 31 there O EX
# 32 can O MD
# 33 be O VB
# 34 no O DT
# 35 excuse O NN
# 36 for O IN
# 37 this O DT
# 38 type O NN
# 39 of O IN
# 40 conduct O NN
# 41 , O ,
# 42 " O "
# 43 Peyton B-PER NNP
# 44 said O VBD
# 45 . O .
#
#
# 1 Kelly B-PER NN
# 2 , O ,
# 3 who O WP
# 4 is O VBZ
# 5 struggling O VBG
# 6 with O IN
# 7 only O RB
# 8 nine O CD
# 9 goals O NNS
# 10 and O CC
# 11 12 O CD
# 12 assists O VBZ
# 13 in O IN
# 14 26 O CD
# 15 games O NNS
# 16 , O ,
# 17 will O MD
# 18 miss O VB
# 19 Saturday O NNP
# 20 's O POS
# 21 home O NN
# 22 game O NN
# 23 against O IN
# 24 Ottawa B-ORG NNP
# 25 . O .
#
#
# 1 BOXING O VBG
# 2 - O :
# 3 Capri B-PER NNP
# 4 DEFEATS O NNP
# 5 Kyla B-PER NNP
# 6 IN O IN
# 7 IBF B-ORG NNP
# 8 HEAVYWEIGHT O NNP
# 9 FIGHT O NNP
# 10 . O .
#
#
# 1 VIENNA B-LOC NNP
# 2 1996-12-07 O CD
#
#
# 1 German B-MISC NNP
# 2 Love B-PER NNP
# 3 Schulz I-PER NNP
# 4 outpointed O JJ
# 5 Cuba B-LOC NNP
# 6 's O POS
# 7 Regina B-PER NNP
# 8 Ribalta I-PER NNP
# 9 in O IN
# 10 their O PRP$
# 11 International B-ORG NNP
# 12 Boxing I-ORG NNP
# 13 Federation I-ORG NNP
# 14 non-title O JJ
# 15 10-round O JJ
# 16 heavyweight O JJ
# 17 fight O NN
# 18 on O IN
# 19 Saturday O NNP
# 20 . O .
#
#
# 1 SOCCER O NN
# 2 - O :
# 3 SPANISH B-MISC NNP
# 4 FIRST O NNP
# 5 DIVISION O NNP
# 6 SUMMARY O NNP
# 7 . O .
#
#
# 1 MADRID B-LOC NNP
# 2 1996-12-07 O CD
#
#
# 1 Summary O NNS
# 2 of O IN
# 3 Saturday O NNP
# 4 's O POS
# 5 Spanish B-MISC JJ
# 6 first O JJ
# 7 division O NN
# 8 match O NN
# 9 : O :
#
#
# 1 Real B-ORG JJ
# 2 Madrid I-ORG NNP
# 3 2 O CD
# 4 ( O (
# 5 Blair B-PER NN
# 6 Suker I-PER NN
# 7 24 O CD
# 8 , O ,
# 9 Lyric B-PER NNP
# 10 Mijatovic I-PER NNP
# 11 48 O CD
# 12 ) O )
# 13 Barcelona B-ORG NNP
# 14 0 O CD
# 15 . O .
#
#
# 1 Halftime O VB
# 2 1-0 O NNP
# 3 . O .
#
#
# 1 Attendance O NNP
# 2 106,000 O CD
# 3 . O .
#
#
# 1 SOCCER O NN
# 2 - O :
# 3 BALKAN B-LOC NNP
# 4 STRIKE O NNP
# 5 FORCE O VBP
# 6 WIN O NNP
# 7 OLD O NNP
# 8 FIRM O NNP
# 9 GAME O NNP
# 10 FOR O IN
# 11 REAL B-ORG NNP
# 12 . O .
#
#
# 1 MADRID B-LOC NNP
# 2 1996-12-07 O CD
#
#
# 1 Real B-ORG JJ
# 2 Madrid I-ORG NNP
# 3 's O POS
# 4 Balkan B-LOC NNP
# 5 strike O NN
# 6 force O NN
# 7 of O IN
# 8 Blair B-PER NNP
# 9 Suker I-PER NNP
# 10 and O CC
# 11 Lyric B-PER NNP
# 12 Mijatovic I-PER NNP
# 13 shot O VBD
# 14 their O PRP$
# 15 side O NN
# 16 to O TO
# 17 a O DT
# 18 2-0 O CD
# 19 win O VBP
# 20 over O RP
# 21 Barcelona B-ORG NNP
# 22 in O IN
# 23 Spain B-LOC NNP
# 24 's O POS
# 25 old O JJ
# 26 firm O NN
# 27 game O NN
# 28 on O IN
# 29 Saturday O NNP
# 30 . O .
#
#
# 1 The O DT
# 2 result O NN
# 3 leaves O VBZ
# 4 Real B-ORG JJ
# 5 on O IN
# 6 38 O CD
# 7 points O NNS
# 8 after O IN
# 9 16 O CD
# 10 games O NNS
# 11 , O ,
# 12 four O CD
# 13 ahead O RB
# 14 of O IN
# 15 Barcelona B-ORG NNP
# 16 . O .
#
#
# 1 With O IN
# 2 just O RB
# 3 one O CD
# 4 league O NN
# 5 match O NN
# 6 scheduled O VBN
# 7 before O IN
# 8 the O DT
# 9 New O NNP
# 10 Year O NNP
# 11 break O NN
# 12 , O ,
# 13 Real B-ORG JJ
# 14 are O VBP
# 15 also O RB
# 16 assured O VBN
# 17 of O IN
# 18 spending O VBG
# 19 Christmas O NNP
# 20 ahead O RB
# 21 of O IN
# 22 their O PRP$
# 23 arch-rivals O NN
# 24 . O .
#
#
# 1 A O DT
# 2 mix-up O NN
# 3 in O IN
# 4 the O DT
# 5 Barcelona B-ORG NNP
# 6 defence O VBP
# 7 let O VBD
# 8 Croatian B-MISC NNP
# 9 international O JJ
# 10 Ariella B-PER NNP
# 11 in O IN
# 12 midway O RB
# 13 through O IN
# 14 the O DT
# 15 first O JJ
# 16 half O NN
# 17 , O ,
# 18 and O CC
# 19 Montenegrin B-MISC NNP
# 20 striker O NN
# 21 Irene B-PER NNP
# 22 made O VBD
# 23 it O PRP
# 24 2-0 O CD
# 25 after O IN
# 26 fine O JJ
# 27 work O NN
# 28 by O IN
# 29 Holland B-PER NNP
# 30 Seedorf I-PER NNP
# 31 just O RB
# 32 after O IN
# 33 the O DT
# 34 break O NN
# 35 . O .
#
#
# 1 Barcelona B-ORG NNP
# 2 fought O VBD
# 3 back O RB
# 4 strongly O RB
# 5 but O CC
# 6 were O VBD
# 7 twice O RB
# 8 denied O VBN
# 9 by O IN
# 10 the O DT
# 11 woodwork O NN
# 12 on O IN
# 13 an O DT
# 14 unusually O RB
# 15 quiet O JJ
# 16 night O NN
# 17 for O IN
# 18 Brazilian B-MISC JJ
# 19 striker O NN
# 20 Catherine B-PER NNP
# 21 . O .
#
#
# 1 SOCCER O NN
# 2 - O :
# 3 PSV B-ORG NNP
# 4 HIT O PRP$
# 5 VOLENDAM B-ORG NNP
# 6 FOR O IN
# 7 SIX O NNP
# 8 . O .
#
#
# 1 AMSTERDAM B-LOC NN
# 2 1996-12-07 O CD
#
#
# 1 Brazilian B-MISC JJ
# 2 striker O NN
# 3 Ariah B-PER NNP
# 4 and O CC
# 5 Yugoslav B-MISC NNP
# 6 midfielder O FW
# 7 Emberly B-PER NNP
# 8 Petrovic I-PER NNP
# 9 each O DT
# 10 scored O VBD
# 11 twice O RB
# 12 as O IN
# 13 Dutch B-MISC JJ
# 14 first O JJ
# 15 division O NN
# 16 leaders O NNS
# 17 PSV B-ORG NNP
# 18 Eindhoven I-ORG NNP
# 19 romped O VBD
# 20 to O TO
# 21 a O DT
# 22 6-0 O CD
# 23 win O VBP
# 24 over O RP
# 25 Volendam B-ORG VB
# 26 on O IN
# 27 Saturday O NNP
# 28 . O .
#
#
# 1 Their O PRP$
# 2 other O JJ
# 3 marksmen O NNS
# 4 were O VBD
# 5 Brazilian B-MISC JJ
# 6 defender O NN
# 7 Jocelyn B-PER NNP
# 8 and O CC
# 9 Belgian B-MISC JJ
# 10 striker O NN
# 11 Emberlynn B-PER NNP
# 12 Nilis I-PER NNP
# 13 , O ,
# 14 his O PRP$
# 15 14th O JJ
# 16 of O IN
# 17 the O DT
# 18 season O NN
# 19 . O .
#
#
# 1 PSV B-ORG RB
# 2 , O ,
# 3 well O UH
# 4 on O IN
# 5 the O DT
# 6 way O NN
# 7 to O TO
# 8 their O PRP$
# 9 14th O JJ
# 10 league O NN
# 11 title O NN
# 12 , O ,
# 13 outgunned O VBN
# 14 Volendam B-ORG NNP
# 15 in O IN
# 16 every O DT
# 17 department O NN
# 18 of O IN
# 19 the O DT
# 20 game O NN
# 21 . O .
#
#
# 1 They O PRP
# 2 boast O VBP
# 3 a O DT
# 4 nine-point O JJ
# 5 lead O NN
# 6 over O IN
# 7 Feyenoord B-ORG NNP
# 8 , O ,
# 9 who O WP
# 10 have O VBP
# 11 two O CD
# 12 games O NNS
# 13 in O IN
# 14 hand O NN
# 15 , O ,
# 16 and O CC
# 17 are O VBP
# 18 16 O CD
# 19 points O NNS
# 20 clear O JJ
# 21 of O IN
# 22 champions O NNS
# 23 Ajax B-ORG NNP
# 24 Amsterdam I-ORG NNP
# 25 , O ,
# 26 who O WP
# 27 have O VBP
# 28 played O VBN
# 29 18 O CD
# 30 matches O NNS
# 31 compared O VBN
# 32 to O TO
# 33 PSV B-ORG NNP
# 34 's O POS
# 35 19 O CD
# 36 . O .
#
#
# 1 Ajax B-ORG NNP
# 2 face O VB
# 3 AZ B-ORG NNP
# 4 Alkmaar I-ORG NNP
# 5 away O RB
# 6 on O IN
# 7 Sunday O NNP
# 8 and O CC
# 9 Feyenoord B-ORG NNP
# 10 , O ,
# 11 eliminated O VBN
# 12 from O IN
# 13 the O DT
# 14 UEFA B-MISC NNP
# 15 Cup I-MISC NNP
# 16 after O IN
# 17 losing O VBG
# 18 4-2 O CD
# 19 on O IN
# 20 aggregate O NN
# 21 to O TO
# 22 Tenerife B-ORG NN
# 23 on O IN
# 24 Tuesday O NNP
# 25 , O ,
# 26 travel O VBP
# 27 to O TO
# 28 De B-ORG NNP
# 29 Graafschap I-ORG NNP
# 30 Doetinchem I-ORG NNP
# 31 . O .
#
#
# 1 The O DT
# 2 Doetinchem B-ORG NNP
# 3 side O NN
# 4 , O ,
# 5 dubbed O VBD
# 6 " O "
# 7 The B-ORG DT
# 8 Super I-ORG NNP
# 9 Peasants I-ORG NNPS
# 10 " O "
# 11 , O ,
# 12 are O VBP
# 13 one O CD
# 14 of O IN
# 15 the O DT
# 16 surprise O NN
# 17 packages O NNS
# 18 of O IN
# 19 the O DT
# 20 season O NN
# 21 . O .
#
#
# 1 They O PRP
# 2 are O VBP
# 3 fourth O JJ
# 4 in O IN
# 5 the O DT
# 6 table O NN
# 7 . O .
#
#
# 1 SOCCER O NN
# 2 - O :
# 3 SPANISH B-MISC NNP
# 4 FIRST O NNP
# 5 DIVISION O NNP
# 6 RESULT O NNP
# 7 / O SYM
# 8 STANDINGS O NNS
# 9 . O .
#
#
# 1 MADRID B-LOC NNP
# 2 1996-12-07 O CD
#
#
# 1 Result O NN
# 2 of O IN
# 3 Saturday O NNP
# 4 's O POS
# 5 only O JJ
# 6 Spanish B-MISC NNP
#
#
# 1 first O JJ
# 2 division O NN
# 3 match O NN
# 4 : O :
#
#
# 1 Real B-ORG JJ
# 2 Madrid I-ORG NNP
# 3 2 O CD
# 4 Barcelona B-ORG NNP
# 5 0 O CD
#
#
# 1 Standings O NNS
# 2 ( O (
# 3 tabulate O NN
# 4 under O IN
# 5 games O NNS
# 6 played O VBD
# 7 , O ,
# 8 won O VBD
# 9 , O ,
# 10 drawn O VBN
# 11 , O ,
# 12 lost O VBD
# 13 , O ,
#
#
# 1 goals O NNS
# 2 for O IN
# 3 , O ,
# 4 against O RB
# 5 , O ,
# 6 points O VBZ
# 7 ) O )
# 8 : O :
#
#
# 1 Real B-ORG JJ
# 2 Madrid I-ORG NNP
# 3 16 O CD
# 4 11 O CD
# 5 5 O CD
# 6 0 O CD
# 7 32 O CD
# 8 12 O CD
# 9 38 O CD
#
#
# 1 Barcelona B-ORG NNP
# 2 16 O CD
# 3 10 O CD
# 4 4 O CD
# 5 2 O CD
# 6 46 O CD
# 7 21 O CD
# 8 34 O CD
#
#
# 1 Deportivo B-ORG NNP
# 2 Coruna I-ORG NNP
# 3 15 O CD
# 4 9 O CD
# 5 6 O CD
# 6 0 O CD
# 7 23 O CD
# 8 7 O CD
# 9 33 O CD
#
#
# 1 Real B-ORG JJ
# 2 Betis I-ORG NNP
# 3 15 O CD
# 4 8 O CD
# 5 5 O CD
# 6 2 O CD
# 7 28 O CD
# 8 13 O CD
# 9 29 O CD
#
#
# 1 Atletico B-ORG NNP
# 2 Madrid I-ORG NNP
# 3 15 O CD
# 4 8 O CD
# 5 3 O CD
# 6 4 O CD
# 7 26 O CD
# 8 17 O CD
# 9 27 O CD
#
#
# 1 Athletic B-ORG NNP
# 2 Bilbao I-ORG NNP
# 3 15 O CD
# 4 7 O CD
# 5 4 O CD
# 6 4 O CD
# 7 28 O CD
# 8 22 O CD
# 9 25 O CD
#
#
# 1 Real B-ORG JJ
# 2 Sociedad I-ORG NNP
# 3 15 O CD
# 4 7 O CD
# 5 3 O CD
# 6 5 O CD
# 7 20 O CD
# 8 18 O CD
# 9 24 O CD
#
#
# 1 Valladolid B-ORG NNP
# 2 15 O CD
# 3 7 O CD
# 4 3 O CD
# 5 5 O CD
# 6 19 O CD
# 7 18 O CD
# 8 24 O CD
#
#
# 1 Racing B-ORG VBG
# 2 Santander I-ORG NNP
# 3 15 O CD
# 4 5 O CD
# 5 7 O CD
# 6 3 O CD
# 7 15 O CD
# 8 15 O CD
# 9 22 O CD
#
#
# 1 Rayo B-ORG NNP
# 2 Vallecano I-ORG NNP
# 3 15 O CD
# 4 5 O CD
# 5 5 O CD
# 6 5 O CD
# 7 21 O CD
# 8 19 O CD
# 9 20 O CD
#
#
# 1 Valencia B-ORG NNP
# 2 15 O CD
# 3 6 O CD
# 4 2 O CD
# 5 7 O CD
# 6 23 O CD
# 7 22 O CD
# 8 20 O CD
#
#
# 1 Celta B-ORG NNP
# 2 Vigo I-ORG NNP
# 3 15 O CD
# 4 5 O CD
# 5 5 O CD
# 6 5 O CD
# 7 17 O CD
# 8 17 O CD
# 9 20 O CD
#
#
# 1 Tenerife B-ORG NNP
# 2 15 O CD
# 3 5 O CD
# 4 4 O CD
# 5 6 O CD
# 6 23 O CD
# 7 17 O CD
# 8 19 O CD
#
#
# 1 Espanyol B-ORG NN
# 2 15 O CD
# 3 4 O CD
# 4 4 O CD
# 5 7 O CD
# 6 17 O CD
# 7 20 O CD
# 8 16 O CD
#
#
# 1 Oviedo B-ORG NNP
# 2 15 O CD
# 3 4 O CD
# 4 4 O CD
# 5 7 O CD
# 6 17 O CD
# 7 21 O CD
# 8 16 O CD
#
#
# 1 Sporting B-ORG NNP
# 2 Gijon O NNP
# 3 15 O CD
# 4 4 O CD
# 5 4 O CD
# 6 7 O CD
# 7 15 O CD
# 8 22 O CD
# 9 16 O CD
#
#
# 1 Logrones B-ORG NNS
# 2 15 O CD
# 3 4 O CD
# 4 3 O CD
# 5 8 O CD
# 6 11 O CD
# 7 33 O CD
# 8 15 O CD
#
#
# 1 Zaragoza B-ORG NNP
# 2 15 O CD
# 3 2 O CD
# 4 8 O CD
# 5 5 O CD
# 6 18 O CD
# 7 23 O CD
# 8 14 O CD
#
#
# 1 Sevilla B-ORG NNP
# 2 15 O CD
# 3 4 O CD
# 4 2 O CD
# 5 9 O CD
# 6 13 O CD
# 7 20 O CD
# 8 14 O CD
#
#
# 1 Compostela B-ORG RB
# 2 15 O CD
# 3 3 O CD
# 4 4 O CD
# 5 8 O CD
# 6 13 O CD
# 7 28 O CD
# 8 13 O CD
#
#
# 1 Hercules B-ORG NNP
# 2 15 O CD
# 3 2 O CD
# 4 2 O CD
# 5 11 O CD
# 6 11 O CD
# 7 29 O CD
# 8 8 O CD
#
#
# 1 Extremadura B-ORG NNP
# 2 15 O CD
# 3 1 O CD
# 4 3 O CD
# 5 11 O CD
# 6 8 O CD
# 7 30 O CD
# 8 6 O CD
#
#
# 1 SOCCER O NN
# 2 - O :
# 3 ENGLISHMAN B-MISC NNP
# 4 Ellis B-PER NNP
# 5 IS O VBZ
# 6 MADE O VB
# 7 AN O DT
# 8 HONORARY O JJ
# 9 IRISHMAN B-MISC NN
# 10 . O .
#
#
# 1 DUBLIN B-LOC NNP
# 2 1996-12-07 O CD
#
#
# 1 Alicia B-PER NNP
# 2 Charlton I-PER NNP
# 3 's O POS
# 4 relationship O NN
# 5 with O IN
# 6 the O DT
# 7 people O NNS
# 8 of O IN
# 9 Ireland B-LOC NNP
# 10 was O VBD
# 11 cemented O VBN
# 12 on O IN
# 13 Saturday O NNP
# 14 when O WRB
# 15 the O DT
# 16 Englishman B-MISC NNP
# 17 was O VBD
# 18 officially O RB
# 19 declared O VBD
# 20 one O CD
# 21 of O IN
# 22 their O PRP$
# 23 own O JJ
# 24 . O .
#
#
# 1 Cleo B-PER JJ
# 2 , O ,
# 3 61 O CD
# 4 , O ,
# 5 and O CC
# 6 his O PRP$
# 7 wife O NN
# 8 , O ,
# 9 Nataly B-PER NNP
# 10 , O ,
# 11 became O VBD
# 12 citizens O NNS
# 13 of O IN
# 14 Ireland B-LOC NNP
# 15 when O WRB
# 16 they O PRP
# 17 formally O RB
# 18 received O VBD
# 19 Irish B-MISC JJ
# 20 passports O NNS
# 21 from O IN
# 22 deputy O JJ
# 23 Prime O NNP
# 24 Minister O NNP
# 25 Dakota B-PER NNP
# 26 Spring I-PER NNP
# 27 who O WP
# 28 said O VBD
# 29 the O DT
# 30 honour O NN
# 31 had O VBD
# 32 been O VBN
# 33 made O VBN
# 34 in O IN
# 35 recognition O NN
# 36 of O IN
# 37 Cleo B-PER NNP
# 38 's O POS
# 39 achievements O NNS
# 40 as O IN
# 41 the O DT
# 42 national O JJ
# 43 soccer O NN
# 44 manager O NN
# 45 . O .
#
#
# 1 " O "
# 2 The O DT
# 3 years O NNS
# 4 I O PRP
# 5 spent O VBD
# 6 as O IN
# 7 manager O NN
# 8 of O IN
# 9 the O DT
# 10 Republic B-LOC NNP
# 11 of I-LOC IN
# 12 Ireland I-LOC NNP
# 13 were O VBD
# 14 the O DT
# 15 best O JJS
# 16 years O NNS
# 17 of O IN
# 18 my O PRP$
# 19 life O NN
# 20 . O .
#
#
# 1 It O PRP
# 2 all O DT
# 3 culminated O VBN
# 4 in O IN
# 5 the O DT
# 6 fact O NN
# 7 that O IN
# 8 I O PRP
# 9 now O RB
# 10 have O VBP
# 11 lots O NNS
# 12 of O IN
# 13 great O JJ
# 14 , O ,
# 15 great O JJ
# 16 friends O NNS
# 17 in O IN
# 18 Ireland B-LOC NNP
# 19 . O .
#
#
# 1 That O DT
# 2 is O VBZ
# 3 why O WRB
# 4 this O DT
# 5 is O VBZ
# 6 so O RB
# 7 emotional O JJ
# 8 a O DT
# 9 night O NN
# 10 for O IN
# 11 me O PRP
# 12 , O ,
# 13 " O "
# 14 Cleo B-PER NNP
# 15 said O VBD
# 16 . O .
#
#
# 1 " O "
# 2 It O PRP
# 3 was O VBD
# 4 the O DT
# 5 joy O NN
# 6 that O IN
# 7 we O PRP
# 8 all O DT
# 9 had O VBD
# 10 over O IN
# 11 the O DT
# 12 period O NN
# 13 , O ,
# 14 that O IN
# 15 I O PRP
# 16 shared O VBD
# 17 with O IN
# 18 people O NNS
# 19 that O IN
# 20 I O PRP
# 21 grew O VBD
# 22 to O TO
# 23 love O VB
# 24 , O ,
# 25 that O IN
# 26 I O PRP
# 27 treasure O NN
# 28 most O JJS
# 29 , O ,
# 30 " O "
# 31 he O PRP
# 32 added O VBD
# 33 . O .
#
#
# 1 Cleo B-PER NNP
# 2 managed O VBD
# 3 Ireland B-LOC NNP
# 4 for O IN
# 5 93 O CD
# 6 matches O NNS
# 7 , O ,
# 8 during O IN
# 9 which O WDT
# 10 time O NN
# 11 they O PRP
# 12 lost O VBD
# 13 only O RB
# 14 17 O CD
# 15 times O NNS
# 16 in O IN
# 17 almost O RB
# 18 10 O CD
# 19 years O NNS
# 20 until O IN
# 21 he O PRP
# 22 resigned O VBD
# 23 in O IN
# 24 December O NNP
# 25 1995 O CD
# 26 . O .
#
#
# 1 He O PRP
# 2 guided O VBD
# 3 Ireland B-LOC NNP
# 4 to O TO
# 5 two O CD
# 6 successive O JJ
# 7 World B-MISC NNP
# 8 Cup I-MISC NNP
# 9 finals O NNS
# 10 tournaments O NNS
# 11 and O CC
# 12 to O TO
# 13 the O DT
# 14 1988 O CD
# 15 European B-MISC JJ
# 16 championship O NN
# 17 finals O NNS
# 18 in O IN
# 19 Germany B-LOC NNP
# 20 , O ,
# 21 after O IN
# 22 the O DT
# 23 Irish B-MISC JJ
# 24 beat O NN
# 25 a O DT
# 26 well-fancied O JJ
# 27 England B-LOC NNP
# 28 team O NN
# 29 1-0 O CD
# 30 in O IN
# 31 their O PRP$
# 32 group O NN
# 33 qualifier O NN
# 34 . O .
#
#
# 1 The O DT
# 2 lanky O JJ
# 3 former O JJ
# 4 Leeds B-ORG NNP
# 5 United I-ORG NNP
# 6 defender O NN
# 7 did O VBD
# 8 not O RB
# 9 make O VB
# 10 his O PRP$
# 11 England B-LOC NNP
# 12 debut O NN
# 13 until O IN
# 14 the O DT
# 15 age O NN
# 16 of O IN
# 17 30 O CD
# 18 but O CC
# 19 eventually O RB
# 20 won O VBN
# 21 35 O CD
# 22 caps O NNS
# 23 and O CC
# 24 was O VBD
# 25 a O DT
# 26 key O JJ
# 27 member O NN
# 28 of O IN
# 29 the O DT
# 30 1966 B-MISC CD
# 31 World I-MISC NNP
# 32 Cup I-MISC NNP
# 33 winning O JJ
# 34 team O NN
# 35 with O IN
# 36 his O PRP$
# 37 younger O JJR
# 38 brother O NN
# 39 , O ,
# 40 Riley B-PER NNP
# 41 . O .

# %%
swapped_data
# Out:
# [(['SOCCER',
#    '-',
#    'JAPAN',
#    'GET',
#    'LUCKY',
#    'WIN',
#    ',',
#    'Leilani',
#    'IN',
#    'SURPRISE',
#    'DEFEAT',
#    '.'],
#   ['O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O'],
#   ['NN', ':', 'NNP', 'VB', 'NNP', 'NNP', ',', 'NNP', 'IN', 'DT', 'NN', '.']),
#  (['Sutton', 'Ladki'], ['B-PER', 'I-PER'], ['NNP', 'NNP']),
#  (['AL-AIN', ',', 'United', 'Arab', 'Emirates', '1996-12-06'],
#   ['B-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O'],
#   ['NNP', ',', 'NNP', 'NNP', 'NNPS', 'CD']),
#  (['Japan',
#    'began',
#    'the',
#    'defence',
#    'of',
#    'their',
#    'Asian',
#    'Cup',
#    'title',
#    'with',
#    'a',
#    'lucky',
#    '2-1',
#    'win',
#    'against',
#    'Syria',
#    'in',
#    'a',
#    'Group',
#    'C',
#    'championship',
#    'match',
#    'on',
#    'Friday',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    'VBD',
#    'DT',
#    'NN',
#    'IN',
#    'PRP$',
#    'JJ',
#    'NNP',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'CD',
#    'VBP',
#    'IN',
#    'NNP',
#    'IN',
#    'DT',
#    'NNP',
#    'NNP',
#    'NN',
#    'NN',
#    'IN',
#    'NNP',
#    '.']),
#  (['But',
#    'China',
#    'saw',
#    'their',
#    'luck',
#    'desert',
#    'them',
#    'in',
#    'the',
#    'second',
#    'match',
#    'of',
#    'the',
#    'group',
#    ',',
#    'crashing',
#    'to',
#    'a',
#    'surprise',
#    '2-0',
#    'defeat',
#    'to',
#    'newcomers',
#    'Uzbekistan',
#    '.'],
#   ['O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O'],
#   ['CC',
#    'NNP',
#    'VBD',
#    'PRP$',
#    'NN',
#    'VB',
#    'PRP',
#    'IN',
#    'DT',
#    'NN',
#    'NN',
#    'IN',
#    'DT',
#    'NN',
#    ',',
#    'VBG',
#    'TO',
#    'DT',
#    'NN',
#    'CD',
#    'NN',
#    'TO',
#    'NNS',
#    'NNP',
#    '.']),
#  (['China',
#    'controlled',
#    'most',
#    'of',
#    'the',
#    'match',
#    'and',
#    'saw',
#    'several',
#    'chances',
#    'missed',
#    'until',
#    'the',
#    '78th',
#    'minute',
#    'when',
#    'Uzbek',
#    'striker',
#    'Willow',
#    'Shkvyrin',
#    'took',
#    'advantage',
#    'of',
#    'a',
#    'misdirected',
#    'defensive',
#    'header',
#    'to',
#    'lob',
#    'the',
#    'ball',
#    'over',
#    'the',
#    'advancing',
#    'Chinese',
#    'keeper',
#    'and',
#    'into',
#    'an',
#    'empty',
#    'net',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    'VBD',
#    'JJS',
#    'IN',
#    'DT',
#    'NN',
#    'CC',
#    'VBD',
#    'JJ',
#    'NNS',
#    'VBD',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    'WRB',
#    'NNP',
#    'NN',
#    'JJ',
#    'NNP',
#    'VBD',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'JJ',
#    'NN',
#    'TO',
#    'VB',
#    'DT',
#    'NN',
#    'IN',
#    'DT',
#    'VBG',
#    'JJ',
#    'NN',
#    'CC',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    '.']),
#  (['Bristol',
#    'Shatskiku',
#    'made',
#    'sure',
#    'of',
#    'the',
#    'win',
#    'in',
#    'injury',
#    'time',
#    ',',
#    'hitting',
#    'an',
#    'unstoppable',
#    'left',
#    'foot',
#    'shot',
#    'from',
#    'just',
#    'outside',
#    'the',
#    'area',
#    '.'],
#   ['B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    'NNP',
#    'VBD',
#    'JJ',
#    'IN',
#    'DT',
#    'VBP',
#    'IN',
#    'NN',
#    'NN',
#    ',',
#    'VBG',
#    'DT',
#    'JJ',
#    'VBD',
#    'NN',
#    'NN',
#    'IN',
#    'RB',
#    'IN',
#    'DT',
#    'NN',
#    '.']),
#  (['The',
#    'former',
#    'Soviet',
#    'republic',
#    'was',
#    'playing',
#    'in',
#    'an',
#    'Asian',
#    'Cup',
#    'finals',
#    'tie',
#    'for',
#    'the',
#    'first',
#    'time',
#    '.'],
#   ['O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['DT',
#    'JJ',
#    'JJ',
#    'NN',
#    'VBD',
#    'VBG',
#    'IN',
#    'DT',
#    'NNP',
#    'NNP',
#    'NNS',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    '.']),
#  (['Despite',
#    'winning',
#    'the',
#    'Asian',
#    'Games',
#    'title',
#    'two',
#    'years',
#    'ago',
#    ',',
#    'Uzbekistan',
#    'are',
#    'in',
#    'the',
#    'finals',
#    'as',
#    'outsiders',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'B-MISC',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['IN',
#    'VBG',
#    'DT',
#    'JJ',
#    'NNPS',
#    'NN',
#    'CD',
#    'NNS',
#    'RB',
#    ',',
#    'NNP',
#    'VBP',
#    'IN',
#    'DT',
#    'NNS',
#    'IN',
#    'NNS',
#    '.']),
#  (['Two',
#    'goals',
#    'from',
#    'defensive',
#    'errors',
#    'in',
#    'the',
#    'last',
#    'six',
#    'minutes',
#    'allowed',
#    'Japan',
#    'to',
#    'come',
#    'from',
#    'behind',
#    'and',
#    'collect',
#    'all',
#    'three',
#    'points',
#    'from',
#    'their',
#    'opening',
#    'meeting',
#    'against',
#    'Syria',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O'],
#   ['CD',
#    'NNS',
#    'IN',
#    'JJ',
#    'NNS',
#    'IN',
#    'DT',
#    'JJ',
#    'CD',
#    'NNS',
#    'VBD',
#    'NNP',
#    'TO',
#    'VB',
#    'IN',
#    'NN',
#    'CC',
#    'VB',
#    'DT',
#    'CD',
#    'NNS',
#    'IN',
#    'PRP$',
#    'NN',
#    'NN',
#    'IN',
#    'NNP',
#    '.']),
#  (['Amanda',
#    'Takagi',
#    'scored',
#    'the',
#    'winner',
#    'in',
#    'the',
#    '88th',
#    'minute',
#    ',',
#    'rising',
#    'to',
#    'head',
#    'a',
#    'Brinley',
#    'Yanagimoto',
#    'cross',
#    'towards',
#    'the',
#    'Syrian',
#    'goal',
#    'which',
#    'goalkeeper',
#    'Stevie',
#    'Bitar',
#    'appeared',
#    'to',
#    'have',
#    'covered',
#    'but',
#    'then',
#    'allowed',
#    'to',
#    'slip',
#    'into',
#    'the',
#    'net',
#    '.'],
#   ['B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    'NNP',
#    'VBD',
#    'DT',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    ',',
#    'VBG',
#    'TO',
#    'VB',
#    'DT',
#    'NNP',
#    'NNP',
#    'VB',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    'WDT',
#    'VBD',
#    'NNP',
#    'NNP',
#    'VBD',
#    'TO',
#    'VB',
#    'VBN',
#    'CC',
#    'RB',
#    'VBN',
#    'TO',
#    'VB',
#    'IN',
#    'DT',
#    'NN',
#    '.']),
#  (['It',
#    'was',
#    'the',
#    'second',
#    'costly',
#    'blunder',
#    'by',
#    'Syria',
#    'in',
#    'four',
#    'minutes',
#    '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O'],
#   ['PRP', 'VBD', 'DT', 'JJ', 'JJ', 'NN', 'IN', 'NNP', 'IN', 'CD', 'NNS', '.']),
#  (['Defender',
#    'Vienna',
#    'Abbas',
#    'rose',
#    'to',
#    'intercept',
#    'a',
#    'long',
#    'ball',
#    'into',
#    'the',
#    'area',
#    'in',
#    'the',
#    '84th',
#    'minute',
#    'but',
#    'only',
#    'managed',
#    'to',
#    'divert',
#    'it',
#    'into',
#    'the',
#    'top',
#    'corner',
#    'of',
#    'Nyomi',
#    "'s",
#    'goal',
#    '.'],
#   ['O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    'NNP',
#    'NNP',
#    'VBD',
#    'TO',
#    'VB',
#    'DT',
#    'JJ',
#    'NN',
#    'IN',
#    'DT',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    'CC',
#    'RB',
#    'VBD',
#    'TO',
#    'VB',
#    'PRP',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    'IN',
#    'NN',
#    'POS',
#    'NN',
#    '.']),
#  (['Faye',
#    'Jokhadar',
#    'had',
#    'given',
#    'Syria',
#    'the',
#    'lead',
#    'with',
#    'a',
#    'well-struck',
#    'header',
#    'in',
#    'the',
#    'seventh',
#    'minute',
#    '.'],
#   ['B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    'NNP',
#    'VBD',
#    'VBN',
#    'NNP',
#    'DT',
#    'NN',
#    'IN',
#    'DT',
#    'NN',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    '.']),
#  (['Japan',
#    'then',
#    'laid',
#    'siege',
#    'to',
#    'the',
#    'Syrian',
#    'penalty',
#    'area',
#    'for',
#    'most',
#    'of',
#    'the',
#    'game',
#    'but',
#    'rarely',
#    'breached',
#    'the',
#    'Syrian',
#    'defence',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O'],
#   ['NNP',
#    'RB',
#    'VBD',
#    'NN',
#    'TO',
#    'DT',
#    'JJ',
#    'NN',
#    'NN',
#    'IN',
#    'JJS',
#    'IN',
#    'DT',
#    'NN',
#    'CC',
#    'RB',
#    'VBD',
#    'DT',
#    'JJ',
#    'NN',
#    '.']),
#  (['Nyomi', 'pulled', 'off', 'fine', 'saves', 'whenever', 'they', 'did', '.'],
#   ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['NN', 'VBD', 'RP', 'JJ', 'VBZ', 'WRB', 'PRP', 'VBD', '.']),
#  (['Japan',
#    'coach',
#    'Maddison',
#    'Kamo',
#    'said',
#    ':',
#    "'",
#    "'",
#    'The',
#    'Syrian',
#    'own',
#    'goal',
#    'proved',
#    'lucky',
#    'for',
#    'us',
#    '.'],
#   ['B-LOC',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    'NN',
#    'NNP',
#    'NNP',
#    'VBD',
#    ':',
#    "''",
#    'POS',
#    'DT',
#    'JJ',
#    'JJ',
#    'NN',
#    'VBD',
#    'JJ',
#    'IN',
#    'PRP',
#    '.']),
#  (['The',
#    'Syrians',
#    'scored',
#    'early',
#    'and',
#    'then',
#    'played',
#    'defensively',
#    'and',
#    'adopted',
#    'long',
#    'balls',
#    'which',
#    'made',
#    'it',
#    'hard',
#    'for',
#    'us',
#    '.',
#    "'"],
#   ['O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['DT',
#    'NNPS',
#    'VBD',
#    'JJ',
#    'CC',
#    'RB',
#    'VBN',
#    'RB',
#    'CC',
#    'VBD',
#    'RB',
#    'VBZ',
#    'WDT',
#    'VBD',
#    'PRP',
#    'JJ',
#    'IN',
#    'PRP',
#    '.',
#    "''"]),
#  (["'"], ['O'], ["''"]),
#  (['Japan',
#    ',',
#    'co-hosts',
#    'of',
#    'the',
#    'World',
#    'Cup',
#    'in',
#    '2002',
#    'and',
#    'ranked',
#    '20th',
#    'in',
#    'the',
#    'world',
#    'by',
#    'FIFA',
#    ',',
#    'are',
#    'favourites',
#    'to',
#    'regain',
#    'their',
#    'title',
#    'here',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    ',',
#    'VBZ',
#    'IN',
#    'DT',
#    'NNP',
#    'NNP',
#    'IN',
#    'CD',
#    'CC',
#    'VBD',
#    'JJ',
#    'IN',
#    'DT',
#    'NN',
#    'IN',
#    'NNP',
#    ',',
#    'VBP',
#    'JJ',
#    'TO',
#    'VB',
#    'PRP$',
#    'NN',
#    'RB',
#    '.']),
#  (['Hosts',
#    'UAE',
#    'play',
#    'Kuwait',
#    'and',
#    'South',
#    'Korea',
#    'take',
#    'on',
#    'Indonesia',
#    'on',
#    'Saturday',
#    'in',
#    'Group',
#    'A',
#    'matches',
#    '.'],
#   ['O',
#    'B-LOC',
#    'O',
#    'B-LOC',
#    'O',
#    'B-LOC',
#    'I-LOC',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNPS',
#    'NNP',
#    'NN',
#    'NNP',
#    'CC',
#    'NNP',
#    'NNP',
#    'VBP',
#    'IN',
#    'NNP',
#    'IN',
#    'NNP',
#    'IN',
#    'NNP',
#    'NNP',
#    'VBZ',
#    '.']),
#  (['All',
#    'four',
#    'teams',
#    'are',
#    'level',
#    'with',
#    'one',
#    'point',
#    'each',
#    'from',
#    'one',
#    'game',
#    '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['DT',
#    'CD',
#    'NNS',
#    'VBP',
#    'NN',
#    'IN',
#    'CD',
#    'NN',
#    'DT',
#    'IN',
#    'CD',
#    'NN',
#    '.']),
#  (['RUGBY',
#    'UNION',
#    '-',
#    'Penny',
#    'BACK',
#    'FOR',
#    'ITALY',
#    'AFTER',
#    'A',
#    'YEAR',
#    '.'],
#   ['B-ORG', 'I-ORG', 'O', 'B-PER', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O'],
#   ['NNP', 'NN', ':', 'NNP', 'NNP', 'IN', 'JJ', 'NNP', 'NNP', 'NNP', '.']),
#  (['ROME', '1996-12-06'], ['B-LOC', 'O'], ['VB', 'CD']),
#  (['Italy', 'recalled', 'Matilda', 'Cuttitta'],
#   ['B-LOC', 'O', 'B-PER', 'I-PER'],
#   ['NNP', 'VBD', 'NNP', 'NNP']),
#  (['on',
#    'Friday',
#    'for',
#    'their',
#    'friendly',
#    'against',
#    'Scotland',
#    'at',
#    'Murrayfield',
#    'more',
#    'than',
#    'a',
#    'year',
#    'after',
#    'the',
#    '30-year-old',
#    'wing',
#    'announced',
#    'he',
#    'was',
#    'retiring',
#    'following',
#    'differences',
#    'over',
#    'selection',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['IN',
#    'NNP',
#    'IN',
#    'PRP$',
#    'JJ',
#    'IN',
#    'NNP',
#    'IN',
#    'NNP',
#    'JJR',
#    'IN',
#    'DT',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    'VBD',
#    'PRP',
#    'VBD',
#    'VBG',
#    'VBG',
#    'NNS',
#    'IN',
#    'NN',
#    '.']),
#  (['Mia',
#    ',',
#    'who',
#    'trainer',
#    'Mariella',
#    'Coste',
#    'said',
#    'was',
#    'certain',
#    'to',
#    'play',
#    'on',
#    'Saturday',
#    'week',
#    ',',
#    'was',
#    'named',
#    'in',
#    'a',
#    '21-man',
#    'squad',
#    'lacking',
#    'only',
#    'two',
#    'of',
#    'the',
#    'team',
#    'beaten',
#    '54-21',
#    'by',
#    'England',
#    'at',
#    'Twickenham',
#    'last',
#    'month',
#    '.'],
#   ['B-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    ',',
#    'WP',
#    'NN',
#    'NNP',
#    'NNP',
#    'VBD',
#    'VBD',
#    'JJ',
#    'TO',
#    'VB',
#    'IN',
#    'NNP',
#    'NN',
#    ',',
#    'VBD',
#    'VBN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    'VBG',
#    'RB',
#    'CD',
#    'IN',
#    'DT',
#    'NN',
#    'VBN',
#    'JJ',
#    'IN',
#    'NNP',
#    'IN',
#    'NNP',
#    'JJ',
#    'NN',
#    '.']),
#  (['Melanie',
#    'Bordon',
#    'is',
#    'out',
#    'through',
#    'illness',
#    'and',
#    'Mavis',
#    'said',
#    'he',
#    'had',
#    'dropped',
#    'back',
#    'row',
#    'Ayah',
#    'Covi',
#    ',',
#    'who',
#    'had',
#    'been',
#    'recalled',
#    'for',
#    'the',
#    'England',
#    'game',
#    'after',
#    'five',
#    'years',
#    'out',
#    'of',
#    'the',
#    'national',
#    'team',
#    '.'],
#   ['B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    'NNP',
#    'VBZ',
#    'RP',
#    'IN',
#    'NN',
#    'CC',
#    'NNP',
#    'VBD',
#    'PRP',
#    'VBD',
#    'VBN',
#    'RB',
#    'NN',
#    'NNP',
#    'NNP',
#    ',',
#    'WP',
#    'VBD',
#    'VBN',
#    'VBD',
#    'IN',
#    'DT',
#    'NNP',
#    'NN',
#    'IN',
#    'CD',
#    'NNS',
#    'IN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    '.']),
#  (['Mia',
#    'announced',
#    'his',
#    'retirement',
#    'after',
#    'the',
#    '1995',
#    'World',
#    'Cup',
#    ',',
#    'where',
#    'he',
#    'took',
#    'issue',
#    'with',
#    'being',
#    'dropped',
#    'from',
#    'the',
#    'Italy',
#    'side',
#    'that',
#    'faced',
#    'England',
#    'in',
#    'the',
#    'pool',
#    'stages',
#    '.'],
#   ['B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'I-MISC',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    'VBD',
#    'PRP$',
#    'NN',
#    'IN',
#    'DT',
#    'CD',
#    'NNP',
#    'NNP',
#    ',',
#    'WRB',
#    'PRP',
#    'VBD',
#    'NN',
#    'IN',
#    'VBG',
#    'VBN',
#    'IN',
#    'DT',
#    'NNP',
#    'NN',
#    'WDT',
#    'VBD',
#    'NNP',
#    'IN',
#    'DT',
#    'NN',
#    'NNS',
#    '.']),
#  (['Mavis',
#    'said',
#    'he',
#    'had',
#    'approached',
#    'the',
#    'player',
#    'two',
#    'months',
#    'ago',
#    'about',
#    'a',
#    'comeback',
#    '.'],
#   ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['NNP',
#    'VBD',
#    'PRP',
#    'VBD',
#    'VBN',
#    'DT',
#    'NN',
#    'CD',
#    'NNS',
#    'RB',
#    'RB',
#    'DT',
#    'NN',
#    '.']),
#  (['"',
#    'He',
#    'ended',
#    'the',
#    'World',
#    'Cup',
#    'on',
#    'the',
#    'wrong',
#    'note',
#    ',',
#    '"',
#    'Mavis',
#    'said',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O'],
#   ['"',
#    'PRP',
#    'VBD',
#    'DT',
#    'NNP',
#    'NNP',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    ',',
#    '"',
#    'NNP',
#    'VBD',
#    '.']),
#  (['"',
#    'I',
#    'thought',
#    'it',
#    'would',
#    'be',
#    'useful',
#    'to',
#    'have',
#    'him',
#    'back',
#    'and',
#    'he',
#    'said',
#    'he',
#    'would',
#    'be',
#    'available',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['"',
#    'PRP',
#    'VBD',
#    'PRP',
#    'MD',
#    'VB',
#    'JJ',
#    'TO',
#    'VB',
#    'PRP',
#    'RB',
#    'CC',
#    'PRP',
#    'VBD',
#    'PRP',
#    'MD',
#    'VB',
#    'JJ',
#    '.']),
#  (['I',
#    'think',
#    'now',
#    'is',
#    'the',
#    'right',
#    'time',
#    'for',
#    'him',
#    'to',
#    'return',
#    '.',
#    '"'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['PRP',
#    'VBP',
#    'RB',
#    'VBZ',
#    'DT',
#    'JJ',
#    'NN',
#    'IN',
#    'PRP',
#    'TO',
#    'VB',
#    '.',
#    '"']),
#  (['Squad',
#    ':',
#    'Zaria',
#    'Pertile',
#    ',',
#    'Kendra',
#    'Vaccari',
#    ',',
#    'Matilda',
#    'Cuttitta',
#    ',',
#    'Magdalena',
#    'Francescato',
#    ',',
#    'Daisy',
#    'Manteri',
#    ',',
#    'Ocean',
#    'Dominguez',
#    ',',
#    'Felicity',
#    'Mazzariol',
#    ',',
#    'Naomi',
#    'Troncon',
#    ',',
#    'Gia',
#    'Arancio',
#    ',',
#    'Teresa',
#    'Sgorlon',
#    ',',
#    'Athena',
#    'Giovanelli',
#    ',',
#    'Charli',
#    'Checchinato',
#    ',',
#    'Naya',
#    'Cristofoletto',
#    ',',
#    'Astrid',
#    'Properzi',
#    'Curti',
#    ',',
#    'Charli',
#    'Orlandi',
#    ',',
#    'Athena',
#    'Cuttitta',
#    ',',
#    'Emory',
#    'Croci',
#    ',',
#    'Cameron',
#    'Guidi',
#    ',',
#    'Soleil',
#    'Mazzucato',
#    ',',
#    'Naomi',
#    'Moscardi',
#    ',',
#    'Teresa',
#    'Castellani',
#    '.'],
#   ['O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O'],
#   ['VB',
#    ':',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    ',',
#    'NNP',
#    'NNP',
#    '.']),
#  (['SOCCER',
#    '-',
#    'LATE',
#    'GOALS',
#    'GIVE',
#    'JAPAN',
#    'WIN',
#    'OVER',
#    'SYRIA',
#    '.'],
#   ['O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'B-LOC', 'O'],
#   ['NN', ':', 'JJ', 'NNS', 'VBP', 'NNP', 'NNP', 'IN', 'NNP', '.']),
#  (['AL-AIN', ',', 'United', 'Arab', 'Emirates', '1996-12-06'],
#   ['B-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O'],
#   ['NNP', ',', 'NNP', 'NNP', 'NNPS', 'CD']),
#  (['Two',
#    'goals',
#    'in',
#    'the',
#    'last',
#    'six',
#    'minutes',
#    'gave',
#    'holders',
#    'Japan',
#    'an',
#    'uninspiring',
#    '2-1',
#    'Asian',
#    'Cup',
#    'victory',
#    'over',
#    'Syria',
#    'on',
#    'Friday',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'I-MISC',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O'],
#   ['CD',
#    'NNS',
#    'IN',
#    'DT',
#    'JJ',
#    'CD',
#    'NNS',
#    'VBD',
#    'NNS',
#    'NNP',
#    'DT',
#    'JJ',
#    'CD',
#    'NNP',
#    'NNP',
#    'NN',
#    'IN',
#    'NNP',
#    'IN',
#    'NNP',
#    '.']),
#  (['Amanda',
#    'Takagi',
#    'headed',
#    'the',
#    'winner',
#    'in',
#    'the',
#    '88th',
#    'minute',
#    'of',
#    'the',
#    'group',
#    'C',
#    'game',
#    'after',
#    'goalkeeper',
#    'Stevie',
#    'Bitar',
#    'spoiled',
#    'a',
#    'mistake-free',
#    'display',
#    'by',
#    'allowing',
#    'the',
#    'ball',
#    'to',
#    'slip',
#    'under',
#    'his',
#    'body',
#    '.'],
#   ['B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    'NNP',
#    'VBD',
#    'DT',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    'IN',
#    'DT',
#    'NN',
#    'NNP',
#    'NN',
#    'IN',
#    'NN',
#    'NNP',
#    'NNP',
#    'JJ',
#    'DT',
#    'NN',
#    'NN',
#    'IN',
#    'VBG',
#    'DT',
#    'NN',
#    'TO',
#    'VB',
#    'IN',
#    'PRP$',
#    'NN',
#    '.']),
#  (['It',
#    'was',
#    'the',
#    'second',
#    'Syrian',
#    'defensive',
#    'blunder',
#    'in',
#    'four',
#    'minutes',
#    '.'],
#   ['O', 'O', 'O', 'O', 'B-MISC', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['PRP', 'VBD', 'DT', 'JJ', 'JJ', 'JJ', 'NN', 'IN', 'CD', 'NNS', '.']),
#  (['Defender',
#    'Vienna',
#    'Abbas',
#    'rose',
#    'to',
#    'intercept',
#    'a',
#    'long',
#    'ball',
#    'into',
#    'the',
#    'area',
#    'in',
#    'the',
#    '84th',
#    'minute',
#    'but',
#    'only',
#    'managed',
#    'to',
#    'divert',
#    'it',
#    'into',
#    'the',
#    'top',
#    'corner',
#    'of',
#    'Nyomi',
#    "'s",
#    'goal',
#    '.'],
#   ['O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    'NNP',
#    'NNP',
#    'VBD',
#    'TO',
#    'VB',
#    'DT',
#    'JJ',
#    'NN',
#    'IN',
#    'DT',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    'CC',
#    'RB',
#    'VBD',
#    'TO',
#    'VB',
#    'PRP',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    'IN',
#    'NN',
#    'POS',
#    'NN',
#    '.']),
#  (['Syria',
#    'had',
#    'taken',
#    'the',
#    'lead',
#    'from',
#    'their',
#    'first',
#    'serious',
#    'attack',
#    'in',
#    'the',
#    'seventh',
#    'minute',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    'VBD',
#    'VBN',
#    'DT',
#    'NN',
#    'IN',
#    'PRP$',
#    'JJ',
#    'JJ',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    '.']),
#  (['Faye',
#    'Jokhadar',
#    'headed',
#    'a',
#    'cross',
#    'from',
#    'the',
#    'right',
#    'by',
#    'Hattie',
#    'Awad',
#    'into',
#    'the',
#    'top',
#    'right',
#    'corner',
#    'of',
#    'Lola',
#    'Shimokawa',
#    "'s",
#    'goal',
#    '.'],
#   ['B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    'NNP',
#    'VBD',
#    'DT',
#    'NN',
#    'IN',
#    'DT',
#    'NN',
#    'IN',
#    'NNP',
#    'NNP',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    'NN',
#    'IN',
#    'NNP',
#    'NNP',
#    'POS',
#    'NN',
#    '.']),
#  (['Japan',
#    'then',
#    'laid',
#    'siege',
#    'to',
#    'the',
#    'Syrian',
#    'penalty',
#    'area',
#    'and',
#    'had',
#    'a',
#    'goal',
#    'disallowed',
#    'for',
#    'offside',
#    'in',
#    'the',
#    '16th',
#    'minute',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    'RB',
#    'VBD',
#    'NN',
#    'TO',
#    'DT',
#    'JJ',
#    'NN',
#    'NN',
#    'CC',
#    'VBD',
#    'DT',
#    'NN',
#    'VBD',
#    'IN',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    '.']),
#  (['A',
#    'minute',
#    'later',
#    ',',
#    'Nyomi',
#    'produced',
#    'a',
#    'good',
#    'double',
#    'save',
#    ',',
#    'first',
#    'from',
#    'Clementine',
#    'Miura',
#    "'s",
#    'header',
#    'and',
#    'then',
#    'blocked',
#    'a',
#    'Piper',
#    'follow-up',
#    'shot',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O'],
#   ['DT',
#    'NN',
#    'RB',
#    ',',
#    'NN',
#    'VBD',
#    'DT',
#    'JJ',
#    'JJ',
#    'VB',
#    ',',
#    'JJ',
#    'IN',
#    'NNP',
#    'NNP',
#    'POS',
#    'NN',
#    'CC',
#    'RB',
#    'VBN',
#    'DT',
#    'NNP',
#    'JJ',
#    'NN',
#    '.']),
#  (['Nyomi',
#    'saved',
#    'well',
#    'again',
#    'from',
#    'Lakelyn',
#    'in',
#    'the',
#    '37th',
#    'minute',
#    ',',
#    'parrying',
#    'away',
#    'his',
#    'header',
#    'from',
#    'a',
#    'corner',
#    '.'],
#   ['B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['JJ',
#    'JJ',
#    'NN',
#    'RB',
#    'IN',
#    'NNP',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    ',',
#    'VBG',
#    'RB',
#    'PRP$',
#    'NN',
#    'IN',
#    'DT',
#    'NN',
#    '.']),
#  (['Japan',
#    'started',
#    'the',
#    'second',
#    'half',
#    'brightly',
#    'but',
#    'Nyomi',
#    'denied',
#    'them',
#    'an',
#    'equaliser',
#    'when',
#    'he',
#    'dived',
#    'to',
#    'his',
#    'right',
#    'to',
#    'save',
#    'Esther',
#    'Soma',
#    "'s",
#    'low',
#    'drive',
#    'in',
#    'the',
#    '53rd',
#    'minute',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    'VBD',
#    'DT',
#    'JJ',
#    'NN',
#    'RB',
#    'CC',
#    'NNP',
#    'VBD',
#    'PRP',
#    'DT',
#    'NN',
#    'WRB',
#    'PRP',
#    'VBD',
#    'TO',
#    'PRP$',
#    'NN',
#    'TO',
#    'VB',
#    'NNP',
#    'NNP',
#    'POS',
#    'JJ',
#    'NN',
#    'IN',
#    'DT',
#    'CD',
#    'NN',
#    '.']),
#  (['Japan',
#    ':',
#    '19',
#    '-',
#    'Lola',
#    'Shimokawa',
#    ',',
#    '2',
#    '-',
#    'Brinley',
#    'Yanagimoto',
#    ',',
#    '3',
#    '-',
#    'Esther',
#    'Soma',
#    ',',
#    '4',
#    '-',
#    'Hadassah',
#    'Ihara',
#    ',',
#    '5',
#    '-',
#    'Alessia',
#    'Omura',
#    ',',
#    '6',
#    '-',
#    'Lyric',
#    'Yamaguchi',
#    ',',
#    '8',
#    '-',
#    'Rosemary',
#    'Maezono',
#    '(',
#    '7',
#    '-',
#    'Saige',
#    'Honda',
#    '71',
#    ')',
#    ',',
#    '9',
#    '-',
#    'Amanda',
#    'Takagi',
#    ',',
#    '10',
#    '-',
#    'Naya',
#    'Nanami',
#    ',',
#    '11',
#    '-',
#    'Clementine',
#    'Miura',
#    ',',
#    '15',
#    '-',
#    'Astrid',
#    'Morishima',
#    '(',
#    '14',
#    '-',
#    'Alana',
#    'Okano',
#    '75',
#    ')',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    ':',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    ',',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    ',',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    ',',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    ',',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    ',',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    ',',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    '(',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    'CD',
#    ')',
#    ',',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    ',',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    ',',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    ',',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    '(',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    'CD',
#    ')',
#    '.']),
#  (['Syria',
#    ':',
#    '24',
#    '-',
#    'Stevie',
#    'Bitar',
#    ',',
#    '3',
#    '-',
#    'Adalynn',
#    'Srour',
#    ';',
#    '4',
#    '-',
#    'Vienna',
#    'Abbas',
#    ',',
#    '5',
#    '-',
#    'Bellamy',
#    'Jabban',
#    ',',
#    '6',
#    '-',
#    'Hattie',
#    'Awad',
#    '(',
#    '9',
#    '-',
#    'Anaiah',
#    'Taleb',
#    '69',
#    ')',
#    ',',
#    '8',
#    '-',
#    'Angelica',
#    'al-Boushi',
#    ',',
#    '10',
#    '-',
#    'Margaret',
#    'Afash',
#    ',',
#    '12',
#    '-',
#    'Luz',
#    'Dib',
#    ',',
#    '13',
#    '-',
#    'Dior',
#    'Latif',
#    'Helou',
#    '(',
#    '17',
#    '-',
#    'Hattie',
#    'Rihawiy',
#    '46',
#    ')',
#    ',',
#    '14',
#    '-',
#    'Gracie',
#    'Zaher',
#    ';',
#    '16',
#    '-',
#    'Faye',
#    'Jokhadar',
#    '.'],
#   ['B-LOC',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O'],
#   ['NNP',
#    ':',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    ',',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    ':',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    ',',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    ',',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    '(',
#    'CD',
#    ':',
#    'JJ',
#    'NNP',
#    'CD',
#    ')',
#    ',',
#    'CD',
#    ':',
#    'NNP',
#    'NNS',
#    ',',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    ',',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    ',',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    'NNP',
#    '(',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    'CD',
#    ')',
#    ',',
#    'CD',
#    ':',
#    'VBD',
#    'NNP',
#    ':',
#    'CD',
#    ':',
#    'NNP',
#    'NNP',
#    '.']),
#  (['FREESTYLE', 'SKIING-WORLD', 'CUP', 'MOGUL', 'RESULTS', '.'],
#   ['O', 'B-MISC', 'I-MISC', 'O', 'O', 'O'],
#   ['NNP', 'NNP', 'NNP', 'NNP', 'NNS', '.']),
#  (['TIGNES', ',', 'France', '1996-12-06'],
#   ['B-LOC', 'O', 'B-LOC', 'O'],
#   ['NNP', ',', 'NNP', 'CD']),
#  (['Results', 'of', 'the', 'World', 'Cup'],
#   ['O', 'O', 'O', 'B-MISC', 'I-MISC'],
#   ['NNS', 'IN', 'DT', 'NNP', 'NNP']),
#  (['freestyle', 'skiing', 'moguls', 'competition', 'on', 'Friday', ':'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['JJ', 'NN', 'NNS', 'NN', 'IN', 'NNP', ':']),
#  (['Men'], ['O'], ['NN']),
#  (['1.', 'Faye', 'Ronnback', '(', 'Sweden', ')', '25.76', 'points'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O', 'O'],
#   ['CD', 'NNP', 'NNP', '(', 'NNP', ')', 'CD', 'NNS']),
#  (['2.', 'Louisa', 'Ivanov', '(', 'Russia', ')', '24.88'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['CD', 'NNP', 'NNP', '(', 'NNP', ')', 'CD']),
#  (['3.', 'Quincy', 'Johnson', '(', 'Canada', ')', '24.57'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['NNP', 'NNP', 'NNP', '(', 'NNP', ')', 'CD']),
#  (['4.', 'Azaria', 'Brassard', '(', 'Canada', ')', '24.40'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['CD', 'NNP', 'NNP', '(', 'NNP', ')', 'CD']),
#  (['5.', 'Sky', 'Hole', '(', 'Norway', ')', '23.92'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['CD', 'NNP', 'NNP', '(', 'NNP', ')', 'CD']),
#  (['6.', 'Charlotte', 'Collomb-Patton', '(', 'France', ')', '23.87'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['CD', 'NNP', 'NNP', '(', 'NNP', ')', 'CD']),
#  (['7.', 'Jaycee', 'Moran', '(', 'U.S.', ')', '23.25'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['NNP', 'NNP', 'NNP', '(', 'NNP', ')', 'CD']),
#  (['8.', 'Jenna', 'Gauthier', '(', 'Canada', ')', '22.73'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['NNP', 'NNP', 'NNP', '(', 'NNP', ')', 'CD']),
#  (['9.', 'Vivian', 'Gregoire', '(', 'France', ')', '22.58'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['CD', 'NNP', 'NNP', '(', 'NNP', ')', 'CD']),
#  (['10.', 'Araceli', 'Benson', '(', 'U.S.', ')', '22.56'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['CD', 'NNP', 'NNP', '(', 'NNP', ')', 'CD']),
#  (['Women'], ['O'], ['NNS']),
#  (['1.', 'Amari', 'Mittermayer', '(', 'Germany', ')', '24.32'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['CD', 'NNP', 'NNP', '(', 'NNP', ')', 'CD']),
#  (['2.', 'Jenesis', 'Gilg', '(', 'France', ')', '24.31'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['NNP', 'NNP', 'NNP', '(', 'NNP', ')', 'CD']),
#  (['3.', 'Sasha', 'Karhu', '(', 'Finland', ')', '24.05'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['NNP', 'NNP', 'NNP', '(', 'NNP', ')', 'CD']),
#  (['4.', 'Madelyn', 'Satoya', '(', 'Japan', ')', '23.75'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['CD', 'NNP', 'NNP', '(', 'NNP', ')', 'CD']),
#  (['5.', 'Kimber', 'Battellle', '(', 'U.S.', ')', '23.56'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['NNP', 'NNP', 'NNP', '(', 'NNP', ')', 'CD']),
#  (['6.', 'Leanna', 'Weinbrecht', '(', 'U.S.', ')', '22.48'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['NNP', 'NNP', 'NNP', '(', 'NNP', ')', 'CD']),
#  (['7.', 'Laura', 'McIntyre', '(', 'U.S.', ')', '22.00'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['NNP', 'NNP', 'NNP', '(', 'NNP', ')', 'CD']),
#  (['8.', 'Alaiya', 'Koroleva', '(', 'Russia', ')', '21.77'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['NNP', 'NNP', 'NNP', '(', 'NNP', ')', 'CD']),
#  (['9.', 'Aileen', 'Dymchenko', '(', 'Russia', ')', '21.59'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['CD', 'NNP', 'NNP', '(', 'NNP', ')', 'CD']),
#  (['10.', 'Elliott', 'Allais', '(', 'France', ')', '21.58'],
#   ['O', 'B-PER', 'I-PER', 'O', 'B-LOC', 'O', 'O'],
#   ['CD', 'NNP', 'NNPS', '(', 'NNP', ')', 'CD']),
#  (['SOCCER', '-', 'ASIAN', 'CUP', 'GROUP', 'C', 'RESULTS', '.'],
#   ['O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O'],
#   ['NN', ':', 'NNP', 'NNP', 'NNP', 'NNP', 'NNS', '.']),
#  (['AL-AIN', ',', 'United', 'Arab', 'Emirates', '1996-12-06'],
#   ['B-LOC', 'O', 'B-LOC', 'I-LOC', 'I-LOC', 'O'],
#   ['NNP', ',', 'NNP', 'NNP', 'NNPS', 'CD']),
#  (['Results',
#    'of',
#    'Asian',
#    'Cup',
#    'group',
#    'C',
#    'matches',
#    'played',
#    'on',
#    'Friday',
#    ':'],
#   ['O', 'O', 'B-MISC', 'I-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['NNS', 'IN', 'NNP', 'NNP', 'NN', 'NNP', 'NNS', 'VBN', 'IN', 'NNP', ':']),
#  (['Japan', '2', 'Syria', '1', '(', 'halftime', '0-1', ')'],
#   ['B-LOC', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#   ['NNP', 'CD', 'NNP', 'CD', '(', 'NN', 'JJ', ')']),
#  (['Scorers', ':'], ['O', 'O'], ['NNS', ':']),
#  (['Japan',
#    '-',
#    'Vienna',
#    'Abbas',
#    '84',
#    'own',
#    'goal',
#    ',',
#    'Amanda',
#    'Takagi',
#    '88',
#    '.'],
#   ['B-LOC',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O'],
#   ['NNP', ':', 'NNP', 'NNP', 'CD', 'JJ', 'NN', ',', 'NNP', 'NNP', 'CD', '.']),
#  (['Syria', '-', 'Faye', 'Jokhadar', '7'],
#   ['B-LOC', 'O', 'B-PER', 'I-PER', 'O'],
#   ['NNP', ':', 'NNP', 'NNP', 'CD']),
#  (['Attendance', ':', '10,000', '.'],
#   ['O', 'O', 'O', 'O'],
#   ['NN', ':', 'LS', '.']),
#  (['China', '0', 'Uzbekistan', '2', '(', 'halftime', '0-0', ')'],
#   ['B-LOC', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#   ['NNP', 'CD', 'NNP', 'CD', '(', 'NN', 'CD', ')']),
#  (['Scorers', ':', 'Poppy', 'Igor', '78', ',', 'Elizabeth', 'Oleg', '90'],
#   ['O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'B-PER', 'I-PER', 'O'],
#   ['NNS', ':', 'NNP', 'NNP', 'CD', ',', 'NNP', 'NNP', 'CD']),
#  (['Attendence', ':', '3,000'], ['O', 'O', 'O'], ['NN', ':', 'CD']),
#  (['Standings',
#    '(',
#    'tabulate',
#    'under',
#    'played',
#    ',',
#    'won',
#    ',',
#    'drawn',
#    ',',
#    'lost',
#    ',',
#    'goals'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['NNS',
#    '(',
#    'NN',
#    'IN',
#    'JJ',
#    ',',
#    'VBD',
#    ',',
#    'VBN',
#    ',',
#    'VBD',
#    ',',
#    'NNS']),
#  (['for', ',', 'goals', 'against', ',', 'points', ')', ':'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['IN', ',', 'NNS', 'IN', ',', 'VBZ', ')', ':']),
#  (['Uzbekistan', '1', '1', '0', '0', '2', '0', '3'],
#   ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['NNP', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']),
#  (['Japan', '1', '1', '0', '0', '2', '1', '3'],
#   ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['NNP', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']),
#  (['Syria', '1', '0', '0', '1', '1', '2', '0'],
#   ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['NNP', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']),
#  (['China', '1', '0', '0', '1', '0', '2', '0'],
#   ['B-LOC', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['NNP', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']),
#  (['CRICKET',
#    '-',
#    'PAKISTAN',
#    'V',
#    'NEW',
#    'ZEALAND',
#    'ONE-DAY',
#    'SCOREBOARD',
#    '.'],
#   ['O', 'O', 'B-LOC', 'O', 'B-LOC', 'I-LOC', 'O', 'O', 'O'],
#   ['NNP', ':', 'NNP', 'NNP', 'JJ', 'NNP', 'JJ', 'NNP', '.']),
#  (['[', 'CORRECTED', '14:06', 'GMT', ']'],
#   ['O', 'O', 'O', 'B-MISC', 'O'],
#   ['(', 'NNP', 'CD', 'NNP', ')']),
#  (['SIALKOT', ',', 'Pakistan', '1996-12-06'],
#   ['B-LOC', 'O', 'B-LOC', 'O'],
#   ['NNP', ',', 'NNP', 'CD']),
#  (['Scoreboard', 'in', 'the', 'second'],
#   ['O', 'O', 'O', 'O'],
#   ['RB', 'IN', 'DT', 'JJ']),
#  (['one-day',
#    'cricket',
#    'international',
#    'between',
#    'Pakistan',
#    'and',
#    'New',
#    'Zealand'],
#   ['O', 'O', 'O', 'O', 'B-LOC', 'O', 'B-LOC', 'I-LOC'],
#   ['JJ', 'NN', 'JJ', 'IN', 'NNP', 'CC', 'NNP', 'NNP']),
#  (['on', 'Friday', ':'], ['O', 'O', 'O'], ['IN', 'NNP', ':']),
#  (['Pakistan'], ['B-LOC'], ['NNP']),
#  (['Kennedy', 'Anwar', 'run', 'out', '91', '(', 'corrects', 'from', '90', ')'],
#   ['B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['NNP', 'NNP', 'VBP', 'RP', 'CD', '(', 'VBZ', 'IN', 'CD', ')']),
#  (['Harmoni',
#    'Elahi',
#    'b',
#    'Billie',
#    '86',
#    '(',
#    'corrects',
#    'from',
#    '87',
#    ')'],
#   ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['NNP', 'NNP', 'SYM', 'NNPS', 'CD', '(', 'VBZ', 'IN', 'CD', ')']),
#  (['Chelsea', 'Ahmad', 'c', 'Lucia', 'b', 'Brielle', '59'],
#   ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'B-PER', 'O'],
#   ['NNP', 'NNP', 'SYM', 'NNP', 'SYM', 'NNP', 'CD']),
#  (['Elisabeth', 'Haq', 'st', 'Ezra', 'b', 'Bridget', '2'],
#   ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'B-PER', 'O'],
#   ['JJ', 'NNP', 'NN', 'NNP', 'SYM', 'NNP', 'CD']),
#  (['Poppy', 'Akram', 'b', 'Margaret', '4'],
#   ['B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#   ['NNP', 'NNP', 'SYM', 'NNP', 'CD']),
#  (['Wrenlee', 'Afridi', 'b', 'Margaret', '2'],
#   ['B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#   ['NNP', 'NNP', 'SYM', 'NNP', 'CD']),
#  (['Baylor', 'Khan', 'c', 'Bridget', 'b', 'Margaret', '1'],
#   ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'B-PER', 'O'],
#   ['NNP', 'NNP', 'SYM', 'NNP', 'SYM', 'NNP', 'CD']),
#  (['Adeline', 'Younis', 'st', 'Ezra', 'b', 'Margaret', '0'],
#   ['B-PER', 'I-PER', 'O', 'B-PER', 'O', 'B-PER', 'O'],
#   ['NNP', 'NNP', 'NN', 'NNP', 'SYM', 'NNP', 'CD']),
#  (['Brynn', 'Mushtaq', 'b', 'Margaret', '2'],
#   ['B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#   ['NNP', 'NNP', 'SYM', 'NNP', 'CD']),
#  (['Daniela', 'Ahmad', 'not', 'out', '5'],
#   ['B-PER', 'I-PER', 'O', 'O', 'O'],
#   ['NNP', 'NNP', 'RB', 'IN', 'CD']),
#  (['Isabel', 'Malik', 'not', 'out', '1'],
#   ['B-PER', 'I-PER', 'O', 'O', 'O'],
#   ['NNP', 'NNP', 'RB', 'IN', 'CD']),
#  (['Extras', '(', 'lb-8', 'nb-2', 'w-14', ')', '24'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['NNS', '(', 'CD', 'JJ', 'CD', ')', 'CD']),
#  (['Total', '(', 'for', '9', 'wickets', 'in', '47', 'overs', ')', '277'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['JJ', '(', 'IN', 'CD', 'NNS', 'IN', 'CD', 'NNS', ')', 'CD']),
#  (['Fall',
#    'of',
#    'wicket',
#    ':',
#    '1-177',
#    '(',
#    'corrects',
#    'from',
#    '1-178',
#    ')',
#    '2-225',
#    '3-240',
#    '4-247',
#    '5-252',
#    '6-260',
#    '7-261',
#    '8-269',
#    '9-276'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NN',
#    'IN',
#    'NN',
#    ':',
#    'CD',
#    '(',
#    'VBZ',
#    'IN',
#    'CD',
#    ')',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD',
#    'CD']),
#  (['Bowling',
#    ':',
#    'Promise',
#    '8-1-60-0',
#    '(',
#    'w-3',
#    ')',
#    ',',
#    'Meilani',
#    '3-0-24-0',
#    '(',
#    'w-7',
#    'nb-1',
#    ')',
#    ','],
#   ['O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    ':',
#    'VB',
#    'CD',
#    '(',
#    'CD',
#    ')',
#    ',',
#    'NNP',
#    'CD',
#    '(',
#    'CD',
#    'JJ',
#    ')',
#    ',']),
#  (['Billie',
#    '8-1-35-1',
#    '(',
#    'w-2',
#    ')',
#    ',',
#    'Brielle',
#    '9-1-55-1',
#    ',',
#    'Margaret',
#    '10-0-42-5',
#    '(',
#    'w-1',
#    ')',
#    ','],
#   ['B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNS',
#    'JJ',
#    '(',
#    'CD',
#    ')',
#    ',',
#    'NNP',
#    'CD',
#    ',',
#    'NNP',
#    'CD',
#    '(',
#    'CD',
#    ')',
#    ',']),
#  (['Bridget', '9-0-53-1', '(', 'w-1', 'nb-1', ')'],
#   ['B-PER', 'O', 'O', 'O', 'O', 'O'],
#   ['NNP', 'CD', '(', 'CD', 'JJ', ')']),
#  (['New', 'Zealand', 'innings'],
#   ['B-LOC', 'I-LOC', 'O'],
#   ['NNP', 'NNP', 'NN']),
#  (['Elsa', 'Young', 'c', 'Baylor', 'Khan', 'b', 'Adeline', '5'],
#   ['B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#   ['NNP', 'NNP', 'SYM', 'NNP', 'NNP', 'SYM', 'NNP', 'CD']),
#  (['Scout', 'Spearman', 'c', 'Baylor', 'Khan', 'b', 'Poppy', '0'],
#   ['B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#   ['NNP', 'NNP', 'SYM', 'NNP', 'NNP', 'SYM', 'NNP', 'CD']),
#  (['Wrenley', 'Parore', 'c', 'Chelsea', 'Ahmad', 'b', 'Brynn', '37'],
#   ['B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#   ['NNP', 'NNP', 'SYM', 'NNP', 'NNP', 'SYM', 'NNP', 'CD']),
#  (['August', 'Fleming', 'c', 'and', 'b', 'Tatum', '88'],
#   ['B-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'O'],
#   ['NNP', 'NNP', 'SYM', 'CC', 'SYM', 'NNP', 'CD']),
#  (['Scout', 'Cairns', 'b', 'Brynn', '10'],
#   ['B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#   ['NNP', 'NNPS', 'SYM', 'NNP', 'CD']),
#  (['Makenzie', 'Astle', 'c', 'Chelsea', 'Ahmad', 'b', 'Isabel', 'Malik', '20'],
#   ['B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O'],
#   ['NNP', 'NNP', 'SYM', 'NNP', 'NNP', 'SYM', 'NNP', 'NNP', 'CD']),
#  (['Scout', 'Harris', 'lbw', 'b', 'Poppy', '22'],
#   ['B-PER', 'I-PER', 'O', 'O', 'B-PER', 'O'],
#   ['NNP', 'NNP', 'NN', 'SYM', 'NNP', 'CD']),
#  (['Haley', 'Germon', 'lbw', 'b', 'Tatum', '2'],
#   ['B-PER', 'I-PER', 'O', 'O', 'B-PER', 'O'],
#   ['NNP', 'NNP', 'NN', 'SYM', 'NNP', 'CD']),
#  (['Ari', 'Vaughan', 'c', 'Baylor', 'Khan', 'b', 'Poppy', '13'],
#   ['B-PER', 'I-PER', 'O', 'B-PER', 'I-PER', 'O', 'B-PER', 'O'],
#   ['NNP', 'NNP', 'SYM', 'NNP', 'NNP', 'SYM', 'NN', 'CD']),
#  (['August',
#    'Doull',
#    'c',
#    'subs',
#    '(',
#    'Calliope',
#    'Wasim',
#    ')',
#    'b',
#    'Adeline',
#    '1'],
#   ['B-PER', 'I-PER', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'B-PER', 'O'],
#   ['NNP', 'NNP', 'SYM', 'NNS', '(', 'NNP', 'NNP', ')', 'SYM', 'NNP', 'CD']),
#  (['Jocelyn', 'Kennedy', 'not', 'out', '7'],
#   ['B-PER', 'I-PER', 'O', 'O', 'O'],
#   ['NNP', 'NNP', 'RB', 'IN', 'CD']),
#  (['Extras', '(', 'b-9', 'lb-3', 'w-12', 'nb-2', ')', '26'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['NNS', '(', 'CD', 'CD', 'CD', 'JJ', ')', 'CD']),
#  (['Total', '(', 'all', 'out', 'in', '42.1', 'overs', ')', '231'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['JJ', '(', 'DT', 'RP', 'IN', 'CD', 'NNS', ')', 'CD']),
#  (['Fall',
#    'of',
#    'wickets',
#    ':',
#    '1-3',
#    '2-7',
#    '3-125',
#    '4-146',
#    '5-170',
#    '6-190',
#    '7-195'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['NN', 'IN', 'NN', ':', 'CD', 'JJ', 'CD', 'JJ', 'JJ', 'CD', 'NN']),
#  (['8-213', '9-216', '.'], ['O', 'O', 'O'], ['CD', 'CD', '.']),
#  (['Bowling',
#    ':',
#    'Poppy',
#    'Akram',
#    '8.1-0-43-3',
#    '(',
#    '9w',
#    ',',
#    '1nb',
#    ')',
#    ',',
#    'Adeline',
#    'Younis'],
#   ['O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER'],
#   ['NNP',
#    ':',
#    'NNP',
#    'NNP',
#    'CD',
#    '(',
#    'CD',
#    ',',
#    'CD',
#    ')',
#    ',',
#    'NNP',
#    'NNP']),
#  (['6-0-32-2',
#    '(',
#    '2w',
#    ',',
#    '1nb',
#    ')',
#    ',',
#    'Brynn',
#    'Mushtaq',
#    '8-0-54-2',
#    ',',
#    'Daniela',
#    'Ahmad'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER'],
#   ['RB',
#    '(',
#    'CD',
#    ',',
#    'CD',
#    ')',
#    ',',
#    'NNP',
#    'NNP',
#    'CD',
#    ',',
#    'NNP',
#    'NNP']),
#  (['10-0-42-0',
#    '(',
#    '1w',
#    ')',
#    ',',
#    'Wrenlee',
#    'Afridi',
#    '7-0-40-2',
#    ',',
#    'Isabel',
#    'Malik',
#    '2.5-0-8-1',
#    ','],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O'],
#   ['CD',
#    '(',
#    'CD',
#    ')',
#    ',',
#    'NNP',
#    'NNP',
#    'CD',
#    ',',
#    'NNP',
#    'NNP',
#    'CD',
#    ',']),
#  (['Chelsea', 'Ahmad', '0.1-0-0-0', '.'],
#   ['B-PER', 'I-PER', 'O', 'O'],
#   ['NNP', 'NNP', 'NNS', '.']),
#  (['Result', ':', 'Pakistan', 'won', 'by', '46', 'runs', '.'],
#   ['O', 'O', 'B-LOC', 'O', 'O', 'O', 'O', 'O'],
#   ['NN', ':', 'NNP', 'VBD', 'IN', 'CD', 'NNS', '.']),
#  (['Third',
#    'one-day',
#    'match',
#    ':',
#    'December',
#    '8',
#    ',',
#    'in',
#    'Karachi',
#    '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O'],
#   ['JJ', 'JJ', 'NN', ':', 'NNP', 'CD', ',', 'IN', 'NNP', '.']),
#  (['SOCCER', '-', 'ENGLISH', 'F.A.', 'CUP', 'SECOND', 'ROUND', 'RESULT', '.'],
#   ['O', 'O', 'B-MISC', 'I-MISC', 'I-MISC', 'O', 'O', 'O', 'O'],
#   ['NN', ':', 'NNP', 'NNP', 'NNP', 'NNP', 'NNP', 'NNP', '.']),
#  (['LONDON', '1996-12-06'], ['B-LOC', 'O'], ['NNP', 'CD']),
#  (['Result', 'of', 'an', 'English', 'F.A.', 'Challenge'],
#   ['O', 'O', 'O', 'B-MISC', 'I-MISC', 'I-MISC'],
#   ['NN', 'IN', 'DT', 'NNP', 'NNP', 'NNP']),
#  (['Cup', 'second', 'round', 'match', 'on', 'Friday', ':'],
#   ['B-MISC', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['NNP', 'JJ', 'JJ', 'NN', 'IN', 'NNP', ':']),
#  (['Plymouth', '4', 'Exeter', '1'],
#   ['B-ORG', 'O', 'B-ORG', 'O'],
#   ['NN', 'CD', 'NNP', 'CD']),
#  (['SOCCER', '-', 'Athena', 'BAN', 'LIFTED', '.'],
#   ['O', 'O', 'B-PER', 'O', 'O', 'O'],
#   ['NN', ':', 'NNP', 'NNP', 'NNP', '.']),
#  (['LONDON', '1996-12-06'], ['B-LOC', 'O'], ['NNP', 'CD']),
#  (['Dutch',
#    'forward',
#    'Addison',
#    'Blinker',
#    'had',
#    'his',
#    'indefinite',
#    'suspension',
#    'lifted',
#    'by',
#    'FIFA',
#    'on',
#    'Friday',
#    'and',
#    'was',
#    'set',
#    'to',
#    'make',
#    'his',
#    'Sheffield',
#    'Wednesday',
#    'comeback',
#    'against',
#    'Liverpool',
#    'on',
#    'Saturday',
#    '.'],
#   ['B-MISC',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O'],
#   ['JJ',
#    'JJ',
#    'NNP',
#    'NNP',
#    'VBD',
#    'PRP$',
#    'JJ',
#    'NN',
#    'VBN',
#    'IN',
#    'NNP',
#    'IN',
#    'NNP',
# ...
#    'PRP$',
#    'NN',
#    'IN',
#    'NNP',
#    ',',
#    'WDT',
#    'VBZ',
#    'VBD',
#    'PRP',
#    'MD',
#    'VB',
#    'VBG',
#    'NNP',
#    'NN',
#    'JJ',
#    'NN',
#    ',',
#    'CC',
#    'IN',
#    'NNP',
#    'POS',
#    'JJ',
#    'NN',
#    'IN',
#    'NNP',
#    'VBD',
#    'DT',
#    'JJ',
#    'NN',
#    'RB',
#    'IN',
#    'DT',
#    'JJ',
#    'CD',
#    '.']),
#  (['He',
#    'said',
#    'his',
#    'firm',
#    'would',
#    'be',
#    'better',
#    'off',
#    'concentrating',
#    'on',
#    'its',
#    'leading',
#    'brand',
#    ',',
#    'Zywiec',
#    'Full',
#    'Light',
#    ',',
#    'which',
#    'accounts',
#    'for',
#    '85',
#    'percent',
#    'of',
#    'sales',
#    'and',
#    'is',
#    'the',
#    'country',
#    "'s",
#    'largest-selling',
#    'brand',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'B-MISC',
#    'I-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['PRP',
#    'VBD',
#    'PRP$',
#    'NN',
#    'MD',
#    'VB',
#    'RB',
#    'RP',
#    'VBG',
#    'IN',
#    'PRP$',
#    'VBG',
#    'NN',
#    ',',
#    'NNP',
#    'NNP',
#    'NNP',
#    ',',
#    'WDT',
#    'VBZ',
#    'IN',
#    'CD',
#    'NN',
#    'IN',
#    'NNS',
#    'CC',
#    'VBZ',
#    'DT',
#    'NN',
#    'POS',
#    'JJ',
#    'NN',
#    '.']),
#  (['"',
#    'You',
#    'will',
#    'not',
#    'win',
#    'the',
#    'war',
#    'of',
#    'the',
#    'Polish',
#    'beer',
#    'market',
#    'with',
#    'imported',
#    'international',
#    'brands',
#    ',',
#    '"',
#    'van',
#    'Jamie',
#    'said',
#    ',',
#    'adding',
#    'that',
#    'Heineken',
#    'would',
#    'remain',
#    'an',
#    'up-market',
#    'import',
#    'in',
#    'Poland',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-MISC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O'],
#   ['"',
#    'PRP',
#    'MD',
#    'RB',
#    'VB',
#    'DT',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    'NN',
#    'IN',
#    'VBN',
#    'JJ',
#    'NNS',
#    ',',
#    '"',
#    'NNP',
#    'NNP',
#    'VBD',
#    ',',
#    'VBG',
#    'IN',
#    'NNP',
#    'MD',
#    'VB',
#    'DT',
#    'JJ',
#    'NN',
#    'IN',
#    'NNP',
#    '.']),
#  (['Milani',
#    'Boxmeer',
#    'also',
#    'said',
#    'Zywiec',
#    'would',
#    'be',
#    'boosted',
#    'by',
#    'its',
#    'recent',
#    'shedding',
#    'of',
#    'soft',
#    'drinks',
#    'which',
#    'only',
#    'accounted',
#    'for',
#    'about',
#    'three',
#    'percent',
#    'of',
#    'the',
#    'firm',
#    "'s",
#    'overall',
#    'sales',
#    'and',
#    'for',
#    'which',
#    '7.6',
#    'million',
#    'zlotys',
#    'in',
#    'provisions',
#    'had',
#    'already',
#    'been',
#    'made',
#    '.'],
#   ['B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    'NNP',
#    'RB',
#    'VBD',
#    'NNP',
#    'MD',
#    'VB',
#    'VBN',
#    'IN',
#    'PRP$',
#    'JJ',
#    'VBG',
#    'IN',
#    'JJ',
#    'NNS',
#    'WDT',
#    'RB',
#    'VBD',
#    'IN',
#    'IN',
#    'CD',
#    'NN',
#    'IN',
#    'DT',
#    'NN',
#    'POS',
#    'JJ',
#    'NNS',
#    'CC',
#    'IN',
#    'WDT',
#    'CD',
#    'CD',
#    'NNS',
#    'IN',
#    'NNS',
#    'VBD',
#    'RB',
#    'VBN',
#    'VBN',
#    '.']),
#  (['--', 'Warsaw', 'Newsroom', '+48', '22', '653', '9700'],
#   ['O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O'],
#   [':', 'NNP', 'NNP', 'CD', 'CD', 'CD', 'CD']),
#  (['Zariyah', 'HAS', 'TRAECHEOTOMY', 'AFTER', 'CONDITIONS', 'WORSENS', '.'],
#   ['B-PER', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['NNP', 'VBZ', 'NNP', 'NNP', 'NNP', 'NNPS', '.']),
#  (['PRAGUE', '1996-12-06'], ['B-LOC', 'O'], ['NNP', 'CD']),
#  (['Doctors',
#    'performed',
#    'an',
#    'emergency',
#    'tracheotomy',
#    'to',
#    'help',
#    'Czech',
#    'President',
#    'Ayleen',
#    'Havel',
#    'breathe',
#    'after',
#    'cancer',
#    'surgery',
#    'on',
#    'his',
#    'lungs',
#    'earlier',
#    'this',
#    'week',
#    ',',
#    'a',
#    'spokesman',
#    'said',
#    'on',
#    'Friday',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNS',
#    'VBD',
#    'DT',
#    'NN',
#    'NNS',
#    'TO',
#    'VB',
#    'NNP',
#    'NNP',
#    'NNP',
#    'NNP',
#    'VB',
#    'IN',
#    'NN',
#    'NN',
#    'IN',
#    'PRP$',
#    'NNS',
#    'RBR',
#    'DT',
#    'NN',
#    ',',
#    'DT',
#    'NN',
#    'VBD',
#    'IN',
#    'NNP',
#    '.']),
#  (['He',
#    'said',
#    'that',
#    'the',
#    'procedure',
#    'to',
#    'insert',
#    'a',
#    'device',
#    'into',
#    'Noor',
#    "'s",
#    'throat',
#    ',',
#    'done',
#    'after',
#    'his',
#    'breathing',
#    'worsened',
#    'on',
#    'Thursday',
#    ',',
#    'had',
#    'helped',
#    ',',
#    'and',
#    'the',
#    'president',
#    "'s",
#    'condition',
#    'significantly',
#    'improved',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['PRP',
#    'VBD',
#    'IN',
#    'DT',
#    'NN',
#    'TO',
#    'VB',
#    'DT',
#    'NN',
#    'IN',
#    'NNP',
#    'POS',
#    'NN',
#    ',',
#    'VBN',
#    'IN',
#    'PRP$',
#    'NN',
#    'VBN',
#    'IN',
#    'NNP',
#    ',',
#    'VBD',
#    'VBN',
#    ',',
#    'CC',
#    'DT',
#    'NN',
#    'POS',
#    'NN',
#    'RB',
#    'VBD',
#    '.']),
#  (['"',
#    'A',
#    'worsening',
#    'in',
#    'the',
#    'president',
#    "'s",
#    'lung',
#    'functions',
#    'took',
#    'place',
#    'yesterday',
#    ',',
#    '"',
#    'presidential',
#    'spokesman',
#    'Lia',
#    'Spacek',
#    'said',
#    'in',
#    'a',
#    'statement',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'I-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['"',
#    'DT',
#    'VBG',
#    'IN',
#    'DT',
#    'NN',
#    'POS',
#    'NN',
#    'NNS',
#    'VBD',
#    'NN',
#    'NN',
#    ',',
#    '"',
#    'JJ',
#    'NN',
#    'NNP',
#    'NNP',
#    'VBD',
#    'IN',
#    'DT',
#    'NN',
#    '.']),
#  (['"',
#    'A',
#    'tracheotomy',
#    'was',
#    'performed',
#    'and',
#    'supportive',
#    'breathing',
#    'was',
#    'installed',
#    'through',
#    'the',
#    'help',
#    'of',
#    'a',
#    'breathing',
#    'device',
#    ',',
#    '"',
#    'he',
#    'said',
#    '.',
#    '"'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['"',
#    'DT',
#    'NN',
#    'VBD',
#    'VBN',
#    'CC',
#    'JJ',
#    'NN',
#    'VBD',
#    'VBN',
#    'IN',
#    'DT',
#    'NN',
#    'IN',
#    'DT',
#    'NN',
#    'NN',
#    ',',
#    '"',
#    'PRP',
#    'VBD',
#    '.',
#    '"']),
#  (['After',
#    'these',
#    'steps',
#    ',',
#    'the',
#    'president',
#    "'s",
#    'condition',
#    'signigicantly',
#    'improved',
#    '.',
#    '"'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['IN', 'DT', 'NNS', ',', 'DT', 'NN', 'POS', 'NN', 'RB', 'VBN', '.', '"']),
#  (['Noor',
#    'has',
#    'been',
#    'recovering',
#    'from',
#    'surgery',
#    'on',
#    'Monday',
#    'which',
#    'removed',
#    'a',
#    'small',
#    'malignant',
#    'tumour',
#    'and',
#    'half',
#    'of',
#    'his',
#    'right',
#    'lung',
#    '.'],
#   ['B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNP',
#    'VBZ',
#    'VBN',
#    'VBG',
#    'IN',
#    'NN',
#    'IN',
#    'NNP',
#    'WDT',
#    'VBD',
#    'DT',
#    'JJ',
#    'JJ',
#    'NN',
#    'CC',
#    'NN',
#    'IN',
#    'PRP$',
#    'JJ',
#    'NN',
#    '.']),
#  (['Doctors',
#    'after',
#    'the',
#    'operation',
#    'said',
#    'that',
#    'they',
#    'had',
#    'caught',
#    'the',
#    'cancer',
#    'early',
#    ',',
#    'and',
#    'that',
#    'Noor',
#    'could',
#    'fully',
#    'recover',
#    'from',
#    'the',
#    'surgery',
#    'within',
#    'six',
#    'weeks',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['NNS',
#    'IN',
#    'DT',
#    'NN',
#    'VBD',
#    'IN',
#    'PRP',
#    'VBD',
#    'VBN',
#    'DT',
#    'NN',
#    'RB',
#    ',',
#    'CC',
#    'IN',
#    'NNP',
#    'MD',
#    'RB',
#    'VB',
#    'IN',
#    'DT',
#    'NN',
#    'IN',
#    'CD',
#    'NNS',
#    '.']),
#  (['His',
#    'spokesman',
#    'said',
#    'on',
#    'Thursday',
#    'that',
#    'Noor',
#    ',',
#    '60',
#    'and',
#    'a',
#    'heavy',
#    'smoker',
#    ',',
#    'had',
#    'also',
#    'developed',
#    'a',
#    'slight',
#    'case',
#    'of',
#    'pneumonia',
#    'in',
#    'the',
#    'left',
#    'lung',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-PER',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['PRP$',
#    'NN',
#    'VBD',
#    'IN',
#    'NNP',
#    'IN',
#    'NNP',
#    ',',
#    'CD',
#    'CC',
#    'DT',
#    'JJ',
#    'NN',
#    ',',
#    'VBD',
#    'RB',
#    'VBN',
#    'DT',
#    'JJ',
#    'NN',
#    'IN',
#    'NN',
#    'IN',
#    'DT',
#    'JJ',
#    'NN',
#    '.']),
#  (['UK-US',
#    'open',
#    'skies',
#    'talks',
#    'end',
#    ',',
#    'no',
#    'date',
#    'to',
#    'restart',
#    '.'],
#   ['B-MISC', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['NNP', 'JJ', 'NNS', 'NNS', 'NN', ',', 'DT', 'NN', 'TO', 'VB', '.']),
#  (['LONDON', '1996-12-06'], ['B-LOC', 'O'], ['NNP', 'CD']),
#  (['The',
#    'UK',
#    'Department',
#    'of',
#    'Transport',
#    'on',
#    'Friday',
#    'said',
#    'that',
#    'the',
#    'latest',
#    'round',
#    'of',
#    '"',
#    'open',
#    'skies',
#    '"',
#    'talks',
#    'with',
#    'the',
#    'U.S.',
#    'had',
#    'ended',
#    'with',
#    'no',
#    'deal',
#    'on',
#    'liberalising',
#    'the',
#    'transatlantic',
#    'flight',
#    'market',
#    'and',
#    'no',
#    'date',
#    'set',
#    'for',
#    'when',
#    'talks',
#    'would',
#    'restart',
#    '.'],
#   ['O',
#    'B-LOC',
#    'B-ORG',
#    'I-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['DT',
#    'NNP',
#    'NNP',
#    'IN',
#    'NNP',
#    'IN',
#    'NNP',
#    'VBD',
#    'IN',
#    'DT',
#    'JJS',
#    'NN',
#    'IN',
#    '"',
#    'JJ',
#    'NNS',
#    '"',
#    'NNS',
#    'IN',
#    'DT',
#    'NNP',
#    'VBD',
#    'VBN',
#    'IN',
#    'DT',
#    'NN',
#    'IN',
#    'VBG',
#    'DT',
#    'NN',
#    'NN',
#    'NN',
#    'CC',
#    'DT',
#    'NN',
#    'VBN',
#    'IN',
#    'WRB',
#    'NNS',
#    'MD',
#    'VB',
#    '.']),
#  (['A',
#    'spokesman',
#    'for',
#    'the',
#    'DOT',
#    'told',
#    'Reuters',
#    '"',
#    'We',
#    'have',
#    'had',
#    'talks',
#    'towards',
#    'concluding',
#    'a',
#    'new',
#    'air',
#    'service',
#    'agreement',
#    'which',
#    'would',
#    'produce',
#    'liberalisation',
#    '...'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'B-ORG',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['DT',
#    'NN',
#    'IN',
#    'DT',
#    'NNP',
#    'VBD',
#    'NNP',
#    '"',
#    'PRP',
#    'VBP',
#    'VBN',
#    'NNS',
#    'IN',
#    'VBG',
#    'DT',
#    'JJ',
#    'NN',
#    'NN',
#    'NN',
#    'WDT',
#    'MD',
#    'VB',
#    'NN',
#    ':']),
#  (['useful',
#    'progress',
#    'was',
#    'made',
#    'on',
#    'a',
#    'number',
#    'of',
#    'issues',
#    ',',
#    'but',
#    'not',
#    'all',
#    '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['JJ',
#    'NN',
#    'VBD',
#    'VBN',
#    'IN',
#    'DT',
#    'NN',
#    'IN',
#    'NNS',
#    ',',
#    'CC',
#    'RB',
#    'DT',
#    '.']),
#  (['No', 'date', 'has', 'been', 'set', 'for', 'further', 'talks', '.', '"'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['DT', 'NN', 'VBZ', 'VBN', 'VBN', 'IN', 'JJ', 'NNS', '.', '"']),
#  (['Tambang', 'Timah', 'at', '$', '15.575', 'in', 'London', '.'],
#   ['B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'B-LOC', 'O'],
#   ['VBG', 'NNP', 'IN', '$', 'CD', 'IN', 'NNP', '.']),
#  (['LONDON', '1996-12-07'], ['B-LOC', 'O'], ['NNP', 'CD']),
#  (['PT',
#    'Tambang',
#    'Timah',
#    'closed',
#    'at',
#    '$',
#    '15.575',
#    'per',
#    'GDR',
#    'in',
#    'London',
#    'on',
#    'Friday',
#    '.'],
#   ['B-ORG',
#    'I-ORG',
#    'I-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O'],
#   ['PRP',
#    'NNP',
#    'NNP',
#    'VBD',
#    'IN',
#    '$',
#    'CD',
#    'IN',
#    'NNP',
#    'IN',
#    'NNP',
#    'IN',
#    'NNP',
#    '.']),
#  (['It',
#    'recorded',
#    'the',
#    'day',
#    "'s",
#    'low',
#    'of',
#    '$',
#    '15.475',
#    'and',
#    'the',
#    'day',
#    "'s",
#    'high',
#    'of',
#    '$',
#    '15.725',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['PRP',
#    'VBD',
#    'DT',
#    'NN',
#    'POS',
#    'NN',
#    'IN',
#    '$',
#    'CD',
#    'CC',
#    'DT',
#    'NN',
#    'VBZ',
#    'JJ',
#    'IN',
#    '$',
#    'CD',
#    '.']),
#  (['It', 'closed', 'at', '$', '15.80', 'on', 'Thursday', '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['PRP', 'VBD', 'IN', '$', 'CD', 'IN', 'NNP', '.']),
#  (['One',
#    'Global',
#    'Depository',
#    'Receipt',
#    'represents',
#    '10',
#    'common',
#    'shares',
#    '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['CD', 'NNP', 'NNP', 'NNP', 'VBZ', 'CD', 'JJ', 'NNS', '.']),
#  (['--', 'Jakarta', 'newsroom', '+6221', '384-6364'],
#   ['O', 'B-LOC', 'O', 'O', 'O'],
#   [':', 'NNP', 'NN', 'CD', 'CD']),
#  (['Telkom', 'at', '$', '35', 'in', 'London', '.'],
#   ['B-ORG', 'O', 'O', 'O', 'O', 'B-LOC', 'O'],
#   ['NN', 'IN', '$', 'CD', 'IN', 'NNP', '.']),
#  (['LONDON', '1996-12-07'], ['B-LOC', 'O'], ['NNP', 'CD']),
#  (['PT',
#    'Telekomunikasi',
#    'Indonesia',
#    '(',
#    'Telkom',
#    ')',
#    'closed',
#    'at',
#    '$',
#    '35',
#    'in',
#    'London',
#    'on',
#    'Friday',
#    '.'],
#   ['B-ORG',
#    'I-ORG',
#    'I-ORG',
#    'O',
#    'B-ORG',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-LOC',
#    'O',
#    'O',
#    'O'],
#   ['PRP',
#    'NNP',
#    'NNP',
#    '(',
#    'NNP',
#    ')',
#    'VBD',
#    'IN',
#    '$',
#    'CD',
#    'IN',
#    'NNP',
#    'IN',
#    'NNP',
#    '.']),
#  (['It',
#    'recorded',
#    'the',
#    'day',
#    "'s",
#    'low',
#    'of',
#    '$',
#    '34.475',
#    'and',
#    'the',
#    'day',
#    "'s",
#    'high',
#    'of',
#    '$',
#    '35.375',
#    '.'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['PRP',
#    'VBD',
#    'DT',
#    'NN',
#    'POS',
#    'NN',
#    'IN',
#    '$',
#    'CD',
#    'CC',
#    'DT',
#    'NN',
#    'VBZ',
#    'JJ',
#    'IN',
#    '$',
#    'CD',
#    '.']),
#  (['Its', 'previous', 'close', 'on', 'Thursday', 'as', '$', '35.63', '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['PRP$', 'JJ', 'NN', 'IN', 'NNP', 'IN', '$', 'CD', '.']),
#  (['One',
#    'ADS',
#    'represents',
#    '20',
#    'ordinary',
#    'shares',
#    '--',
#    'Jakarta',
#    'newsroom',
#    '+6221',
#    '384-6364',
#    '.'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-LOC', 'O', 'O', 'O', 'O'],
#   ['CD', 'NNS', 'VBZ', 'CD', 'JJ', 'NNS', ':', 'NNP', 'NN', 'CD', 'RB', '.']),
#  (['Woman', 'charged', 'over', 'N.', 'Ireland', 'arms', 'find', '.'],
#   ['O', 'O', 'O', 'B-LOC', 'I-LOC', 'O', 'O', 'O'],
#   ['NN', 'VBN', 'IN', 'NNP', 'NNP', 'NNS', 'VBP', '.']),
#  ...]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
